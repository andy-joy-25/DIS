# %% [markdown]
# ## 📚 Exercise: Latent Semantic Indexing
# In this exercise we would learn about Latent Semantic Indexing (LSI) based retrieval models.
#
# ### Goal:
# - Implement a search engine using LSI
# - Visualize the LSI concepts
# - Compare the retrieval results with scikit vector space retrieval method (as an oracle)
#
# ### What you are learning in this exercise:
# 1. Learn more about LSI approach
# 2. How retrieval results can be different in LSI and vector space retrieval models

# %% [markdown]
# ## Part1: Implement Latent Semantic Indexing (LSI)
# ### 1.1 Read the corpus data

# %%
#Required libraries.
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import math
from nltk.stem import PorterStemmer, WordNetLemmatizer
import os
import string
import numpy as np
from collections import Counter
from nltk.tokenize import word_tokenize, TweetTokenizer
from nltk.corpus import stopwords
from collections import Counter
from operator import itemgetter
from pprint import pprint
import nltk
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english')).union(set(stopwords.words('french')))
# Out:
# [nltk_data] Downloading package punkt to /Users/romanou/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/romanou/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open("epfldocs.txt", encoding = "utf-8") as f:
    content = f.read().splitlines() 
content
# Out:
# ['Congrats to @ETH_en (5th place) and @EPFL_en (10th place)! https://t.co/8RLp0zZhyb',
#  "If that's not a standing ovation at @EPFL_en ... 🏆🙃😜👾🚀🎉 https://t.co/23kjIG8Pxt",
#  "Time for Open Farm's pitch #openfood #Opendata #EPFL https://t.co/7lKKao5780",
#  'Good opportunity for @ETH_en  @EPFL_en  @EPFL_Park @uzh_news_en https://t.co/v3tOjTYjQD',
#  'Exciting News: "World University Rankings 2016-2017 by subject: computer science" No1 @ETH &amp; @EPFL on No8. Congrats https://t.co/ARSlXZoShQ',
#  '@EPFL  crypto-tokenize FREE ENERGY https://t.co/vH9qgLoqrr https://t.co/6uTnJ68pSC https://t.co/GTXLhI6LTE https://t.co/ZYenRAsEIr GET RICH',
#  'Scientists discover hidden patterns of brain activity https://t.co/HBLRYtdMtT #epfl',
#  '@EdacyHQ  With #EDACY Invest in yourself https://t.co/X2Y212DKUP',
#  'Deadline 19.05.2017 - AGAINST BREAST CANCER I RESEARCH FUNDING https://t.co/l4mhQA7upb #epfl @againstbc',
#  'Robots #transform #into #furniture #at #EPFL #November #KamiAhok https://t.co/jjpc1PuYUm',
#  "Microsoft President @BradSmi and @EPFL's @ebugnion at #WEF18 on #DigitalGenevaConvention and #DigitalTrust. Important topics! @ETH_Rat @EPFL_en https://t.co/xG2Cmw3SzM",
#  'Atelier de travail sur la future traversée de la rade à #Geneve avec @CantonGeneve @EPFL @hslu , etc. et la @hes_so #HEI #hepia #heia-fr https://t.co/2vQQGQhAct',
#  "Formidable ! Je suis fan du projet de la Time machine :-)  Il sera donc possible de revoir la conférence sur votre chaîne Youtube si j'ai bien lu les précédents commentaires ? Merci de signaler quand cette dernière sera en ligne ! #archives #numerique https://t.co/RTxwaV5pAN",
#  "The 27 members of the @wef's Global University Leaders Forum - including Switzerland's @ETH_en and @EPFL_en - are responsible for a large proportion of the world’s scientific publications, a new study reveals\xa0https://t.co/n2Fe3bxFZH https://t.co/KpG9gTYLSq",
#  '"Switzerland is working hard to keep up with the best" @_BR_JSA #Robotics #SRIndustryDay https://t.co/joSUpJdG7K',
#  'FREE #yoga event Hosted by Indian students of EPFL, Lausanne Ambassador Gill of @CDMissionIndia will attend @unil @MySwitzerland_f @EPFL_en https://t.co/XncIWuQCXw',
#  'Aviation: la #Suisse a désormais son centre de recherche aéronautique ! @ZHAW @HSGStGallen @EPFL via @swissinfo_fr https://t.co/YrV8tYeLk7',
#  '.@SciRobotics is now LIVE on #Facebook! Watch @EPFL_en engineers show off their versatile, vacuum-powered #robots https://t.co/fzP3zsAqYn',
#  '“For EU countries, Switzerland is an interesting laboratory” https://t.co/94KL7dMd6z #epfl',
#  'Fantastic explanation of Blockchain #blockchain #fintech #startup @EPFL_en @swissborg @cltucci https://t.co/ovrHo1wVS6',
#  'Présentation du nouveau guide robotique en éducation au cours de la formation @ThymioII @hep  https://t.co/5tAMwdMSpA @FMondada @EPFL https://t.co/JB7mKKVqDd',
#  '"I would trust an #AI doctor more than a human one," -@marcelsalathe (@EPFL_en) "It listens 24/7. How can humans compete?" #AIhealth #swsx',
#  'Nice @BBCRadio4 animation on #FourthRevolution by Luciano @Floridi from @UniofOxford https://t.co/9oQ2y42CoX @agepoly @epfl_en @epfl https://t.co/jR2Dh5KoFq',
#  '#EPFL MOOCs now have over two million registered users #Switzerland https://t.co/T528zfgTMN',
#  'Traces of possible Martian biological activity inside a #meteorite https://t.co/pzu3Ng1Vmp @_OScience @EPFL_en #Mars https://t.co/4L1koD6RGM',
#  'Ehre für Schweizer #VMware-Mitgründer @ebugnion https://t.co/ANCM3qlidO Herzliche Gratulation @EPFL',
#  'Etre bien positionné au départ sera la clef 🇨🇭Merci et bravo à @EPFL qui ne ménage pas ses efforts en la matière, contribuant à la prospérité, à la compétitivité et à la modernité du pays sur le long terme https://t.co/FIUP9zpHwo',
#  'Join the MediaRoad team and talk Media Innovation with the experts on 2 March 2018 in Geneva! The upcoming event is organized by @EPFL and takes on #AI #fakenews #socialmedia #data https://t.co/x8uurri5OY',
#  '#EPFL SV - BMS2018 - Brain Mind Institute Symposium - Summer 2018 - Stress in Health and Disease #Switzerland https://t.co/LmiVlnO9zR',
#  'Cyclometalated Ruthenium Complexes for Dye-Sensitized Solar Cells https://t.co/5T7EGH0qUw #epfl',
#  'New at @epfl_en Life Sciences @epflSV: "From PhD directly to Independent Group Leader" #ELFIR_EPFL:  Early Independence Research Scholars. See https://t.co/evqyqD7FFl, also for computational biology #compbio https://t.co/e3pDCg6NVb Deadline April 1 2018 at https://t.co/mJqcrfIqkb',
#  '@ecoRobotix presents the development of its weeding robot at EPFL. Start of the conference at 11am! https://t.co/Bvfd0Ag6BG #epfl',
#  'Douglas Hanahan from #ISREC @epfl giving the final closing lecture on ‘Microenvironmental determinants of invasion &amp; Metastasts’ at @LorneCancer 2018 #lcc2018 #cancer #metastasis #nottheashleydunnoration https://t.co/0iqT3k8fKQ',
#  'Applied Machine Learning Days main event kicking off at @EPFL   1200 practitioners in the house   @Cisco proud sponsor #AMLD2018 https://t.co/HqeP6ODMnw',
#  'ML Tutorial for TimeSeries and Sequence Data in #ApacheMXNet #Gluon https://t.co/oJFrwO2glW with plenty of introductory materials #DeepLearning #TimeSeries presented @appliedmldays #EPFL',
#  'Sestrin1 identified by @EPFL_en researchers as a #gene frequently missing or mutated in follicular #lymphoma: https://t.co/VEig9f8bpL https://t.co/Jqle5peXA4',
#  'Color-selective &amp; versatile light steering w/ up-scalable subwavelength planar optics. @CSEMInfo @EPFL_en https://t.co/ZtBmsxxp3X https://t.co/zL8ig3VBAu',
#  'Mobile crowdsourcing @EPFL_en campus https://t.co/NCTmPw0ba3',
#  '@paulg Come to @EPFL_en for hardworking students :)',
#  "March 9, #Geneve #smart city aujourd'hui et demain, at @UNIGEnews with @SIG_Geneve @EPFL_en @SecheronSA @plrge https://t.co/Tqwfwbeq8c https://t.co/xng9DhjI4e",
#  "@JimHarris EPFL's campus has the world's first solar window https://t.co/VNM71Za5m0 #epfl",
#  'Enroll now for the free  @EPFL_en / @IUCN #MOOC on "Ecological Monitoring", essential for Protected Areas https://t.co/ePj0ZoEiiZ #Ecology',
#  'Celebrating @NobelPrize winner Jaques Dubochet @unil . Lausanne, Vaud, and are all so proud! @heclausanne @EPFL https://t.co/Tu6j8j44kl',
#  '#EPFL Valais: une bourse de trois millions pour étudier les AVC #Switzerland https://t.co/vNV2LDpOsJ',
#  'It’s possible to film quantum mechanics – and its paradoxical nature – directly. Here is light photographed as a Wave &amp; as a Particle for the first time via @EPFL_en @EPFL https://t.co/m3h6iyAV3K',
#  'Researchers have observed a weather process that was previously not known to occur in Antarctica.  https://t.co/MDaNih1v5H via @EPFL_en',
#  'ICT4Development Conf in 2018 in Lausanne. Join us "ICT4DEV by Rural Circular digital platforms". https://t.co/NF1gERZfUN #epfl #epflcampus',
#  "L'EPFL sera la capitale des drones début septembre https://t.co/QdxCmZa3bV #epfl",
#  '📍HANNOVER MESSE 2017 #HM17 ✊📰 #MECHATRONIK (be-)greifbar am Messestand von @KUKA_RoboticsDE MANCHU @EPFL_en | #KUKA Innovation Award 2017 https://t.co/ofMFG5uWFs',
#  '@MartinVetterli @EPFL setzt sich für open science ein. Wissen teilen für mehr Wirkung. https://t.co/4hMAZtA9Qa',
#  '.@marcelsalathe @EPFL_en @michielrauws2 @X2_AI "If you (personify) an AI, are you deceiving yourself into trusting it?" - @EffyVayena (@uzh_news) asks. #AIhealth #SXSW #SXSWiss',
#  'Nous aussi on sait faire en France de la façade solaire https://t.co/kF6E0Am2Kb',
#  'I am in #SWITZERLAND @_BR_JSA @unil @EPFL @swisssporttv @remnantnews @jesusmessiah7   https://t.co/FHTmluNaCk  @EtatdeVaud @communelausanne https://t.co/4AGkUwotHi',
#  'Congrats! Sensima Inspection granted  CHF 3 Million Loan by SGS https://t.co/LmDqYOvvL9 #VDtech cc @EPFL_en https://t.co/gbdmfiztSK',
#  'Swiss Federal Institutes of Technology @ETH_en  @EPFL_en  open national center for  #DataScience: https://t.co/dOSw7tTZM0',
#  'Aziz Heddi- dynamics/mechanisms of weevil-sodalis interaction over lifespan. Highlights continuum of symbiont-host interaction. #FEMS2017',
#  "Bienvenue à Arielle, Mahamadou, Eddy et Mactar, de la 1ère cohorte du programme @EDACYHQ, qui débutent leur stage aujourd'hui 😊💪 https://t.co/VSh31G6vpl",
#  'Launch of the IMD-EPFL TransformTech program! Welcome to all participants!! @MartinVetterli @EPFL @IMD https://t.co/ZNphy0ralC',
#  '@MrHiura @marcelsalathe @EPFL_en @ForumEPFL It’s one thing to censor, it’s another to avoid promoting their agenda :/ tbh as a student this is really confusing https://t.co/856YHgI74j',
#  'Just @EffyVayena and me from @eth, everyone else is from @epfl.... https://t.co/06jmXdae2H',
#  'ETH board releases new gender strategy. At Applied Machine Learning Days, we’re excited to offer childcare with the help of such support! @EPFL @trekkinglemon @MartinVetterli https://t.co/Ho0yHH1i4b https://t.co/7vF2txCuIO',
#  '@rlerignier @EPFL la norme 690 est théorique. En pratique, si @LextensoEtudian fait 1 #csl #zotero sur une norme proprio, je la prendrai.',
#  'Connected Event #SConnectE @EPFL | Urs Lehner Swisscom: Les défis et les enjeux d’intelligence artificielle sont considérables #VDtech https://t.co/eRqA06qoIY',
#  'Bravo à tous les membres du think tank IOT pour tout le travail fourni en 2017, découvrez le livre de restitution avec une citation de Didier Mesnier, notre secrétaire exécutif!  @Micronarc @CSEMInfo @hes_so @EPFL https://t.co/K7yXC6cHt5',
#  'Less than 30 universities produce more #research than entire industrial nations! Proud that @EPFL_en and @ETH_en are part of this GULF group at #WEF18 https://t.co/bCUmzs50WO https://t.co/RmXjlczif6 @ETH_Rat @EPFL @Davos https://t.co/oYgUVk0lE4',
#  '@dtsbourg @MrHiura @marcelsalathe @EPFL_en @ForumEPFL no confusion, @EPFL_en has indeed a clear responsibility towards Swiss society, but we need to be informed and hear the various voices, and we need to provide our input to the debates',
#  'Nucleosomes engage in short-lived (micro- to milliseconds) stacking interactions with one of their neighbors --&gt; tetranucleosome units. HP1a engages methylated histone tails and thereby transiently stabilizes stacked nucleosomes. This compacted state nevertheless remains dynamic https://t.co/1ulB3GwmfP',
#  'Traces of possible Martian biological activity inside a #meteorite https://t.co/pzu3Ng1Vmp @_OScience @EPFL_en #Mars https://t.co/4L1koD6RGM',
#  'Workshop on "Decentralization and Messaging" by @nextleap2020 at @EPFL (Lausanne) tomorrow (Jan 17) with @carmelatroncoso, @hpk42, @GDanezis, @trevp__ and more! Come by if you have time: Talks and small group discussion for existing and new protocols.',
#  '“Artificial intelligence has the potential to revolutionize transportation" interview of Alexandre Alahi, new professor of Transportation Engineering @EPFL https://t.co/S8ZKRIAHbq RT @Trace_EPFL https://t.co/PQqkRY5ny9',
#  "Les physiciens de l' @EPFL peuvent lire à travers un livre sans l'ouvrir ! Le testament scellé de Catharuçia Savonario Rivoalti n'a plus de secret pour eux... https://t.co/SoiIIcTQNR Via @ArchimagRedac https://t.co/QVsXCAyny7",
#  'Improving  cooperation between universities &amp; businesses is one of the main   challenges for #EU R&amp;D policy according to @EU_ScienceHub https://t.co/eDKaC9gUL3 #Innovation @TUeindhoven @TU_Muenchen @EPFL_en @DTUtweet',
#  '#GEWCH2017 kicks in tomorrow @EPFL_en!   https://t.co/4Rh442x4Q1',
#  'New study into leukemia offers clearer understanding of its biology https://t.co/MgXBFxvk1j via @EPFL_en https://t.co/P7T3KZDyEr',
#  '@webots simulations used by @EPFL researchers to simulate insect walk in @NatureComms article: https://t.co/GLEzs0JT7P https://t.co/vHV9ame2i2',
#  'Make your own gigantic soap bubbles with this tutorial made by EPFL experts! https://t.co/SkukeUexPm',
#  'Woop,woop!Super happy+looking forward to working hand in hand with @CovestroGroup @IMDEA_Nano @EPFL_en @UJI_noticias @imperialcollege etc https://t.co/6lmGbKcSDB',
#  '🙌 Congrats to IBM scientist Irem\u200b Boybat for winning the best poster award on synaptic architecture last week @IEEEorg NVMTS @NJIT @EPFL https://t.co/q0oikdrFGg',
#  'Stay tuned! We will be announcing our @EPFL_en #OpenScience summer school next week! Fantastic speakers and great workshops! https://t.co/zeu9qTtTA7',
#  'Deep/hot #geothermal energy: New experimental paper in @SciReports with @EPFL_en about high-enthalpy geothermal!  https://t.co/ptjUKXxkk4 https://t.co/uriY2wnEPi',
#  "@dn_mason @ViolaineSee @CCI_liv Any chance the images, psf and/or acquisition meta data can be made publicly available??  I'd like to test that the imagej-ops deconvolution algorithms and deconvolutionlab2 are producing equivalent results?? btw how did you measure/compute the PSF??",
#  'Les vélos des étudiants en vacances, bien en sécurité dans la Vélostation @EPFL https://t.co/eitUeNfoax',
#  'Act global, think campus!  @EPFL_en  @EPFLdurable  @MartinVetterli https://t.co/4vUYimVGjS',
#  'Students from #EPFL #UniFr design self-sufficient home with integrated #solar panels. Good luck at #SolarDecathlon  https://t.co/cuixEAJYDH',
#  'Scientists at @EPFL_en were able to watch the human Brain Rewire Itself to Adjust to Advanced Prostheses #neuroscience #medtech #digitalhealth https://t.co/8staQsmKnh',
#  'Is it just me? Or is @EPFL BadCompany these days? :p https://t.co/ITNDNG8wSf https://t.co/xnufE4mmWC',
#  "Measuring water quality with 'snake' robot and biosensors! Cool work by @DMF_UNIL JR vd Meer &amp; @EPFL ht @f_p_bock  https://t.co/VPzbEkaNay",
#  '#Water is surprisingly ordered at the surface of nano droplets https://t.co/kXjjLGWmy5 @EPFL https://t.co/YJkJnlqNYW',
#  'Ran into ex-@UT_CAEE student @ a Gordon Research Conf. Worked w/ me as undergrad. Satoshi Takahama now a successful faculty member @ #EPFL. https://t.co/pHSuxdC7hP',
#  'Video of Nicola Marzari from @EPFL_en  on Computational Discovery in the 21st Century during #PASC17 now online: https://t.co/tfCkEvYKtq https://t.co/httPdHcK9W',
#  'After jet lag, before forgetting: HK–CHIC, episode 6 @chic_community #epfl #voyage #hongkong https://t.co/3LNG5suuw8 …',
#  "It's Tomorrow #SwissEdTechCollider ! - keep an eye on it ! #EdTech https://t.co/pHZ8WpVtN0",
#  'Spaceship #epfl #lausanne https://t.co/Lb223yT804',
#  "top architect: Travail de fin d'année #exhibition  #exposition  #EPFL #architectureschool  #SEOUL MÉTRO LINE PROJE… https://t.co/ZdVoWdckrx https://t.co/CmOOWb3eH6",
#  'Et des super-pouvoirs des bibliothécaires de la BCU alors ? https://t.co/jOYiUOrOHe',
#  'Meet the Ijspeert Lab of @EPFL_en - the lab that @pleurobot lives in - see the whole video at https://t.co/S0ZdUIF3K2 https://t.co/1fGGgsnRKL',
#  'Pas mal les soirées-bibliothèque au #RolexLearningCenter #EPFL 📚📝 https://t.co/8oWqIB0Csc',
#  'Constructive ML posters #creativeAI #musictech #nips2016 #AI https://t.co/iXjNhrirWy',
#  'We are looking forward to the Swiss #Cytometry Meeting @ the Ecole Polytechnique Fédérale de #Lausanne  7-9 Feb - Drop by for top tips on streamlining operations in your #research facility! https://t.co/2BBTinGzuP #corefacility #ROI @EPFL @epflSV @SwissCytometry @Swiss_Cytometry https://t.co/Lcs564YAvr',
#  'Watch video by my #knight who supports #FlatEarth #View @_BR_JSA📀 of #AugustePiccard @ericdubay   💡👉https://t.co/GZ0y5VtRIJ  @HolyGhostAlice',
#  'Some nice day 1 #spheroids from @ViolaineSee lab imaged for size @CCI_liv.  Good opportunity to play with some #deconvolution algorithms in DeconvolutionLab2:  https://t.co/OtrXA96Zfu https://t.co/BkLIEWFCRO',
#  '"A parametric tool to evaluate the environmental and economic feasibility of decentralized energy systems." - https://t.co/mC2D0L1xRW',
#  '📆 Our spin-off @fhaptics will be attending #erf2018 | 13-15th March in #finland  ▶️Want to know more about Foldaway Haptics? https://t.co/VzvmpcJ3Hv #robotics #virtualreality #robots #joystick #vr #rrl #EPFL #swissstartups #roboticists #haptics',
#  '“Strong and robust negative relation between the length of the title of an article and its scientific quality.” Worried here for a moment, but this is about economics articles… https://t.co/5MF6XxCaih',
#  'After years of reiterating that safe navigation in populated, indoor environments by mobile #robotics has largely been solved, @EPFL ‘s Alex Alahi has demonstrated to me that "safe" is not the same as "natural" or "normal". My bad. #a3forum @AlexAlahi',
#  'Dieser Dr. Michael #Gonin ist wirklich gut! Er bringt Geschichte, Unternehmertum und soziale Verantwortung zusammen. #EPFL #HybridesDenken https://t.co/boReQiEXiT',
#  'So excited to see @EPFL among the inaugural partners @GIX_edu (Global Innovation Exchange) w/ @UW &amp; @Tsinghua_Uni!  https://t.co/C9C96WEe6b',
#  "FIFEL PANEL 10.12 -Prof Yunus discussion with Prof F. Vuille (EPFL CEN director) during HRFF Zurich 'Access to Energy: a Human right' - 1.5billion people have still no access to electricity ! Following day, Prof. Yunus’ public lecture at EPFL https://t.co/hXSoVlrnGb via @YouTube https://t.co/04A2xIJk2f",
#  'Thankfully our next plane is also delayed and now @jen_mccutcheon also got through security and on the plane; I also met Henrik from #epfl and shortly we should be on the way on the next leg to Cape Town- our halfway point to #Antarctica  @AntarcticBase @PolarFoundation',
#  'RX Solutions CT system UltraTom helps to read books without open them, and read the unreadable ! #sciences #CT #3D #tomography  @lemondefr @EPFL @EPFL_en   More information : https://t.co/0WHOx0aKTR',
#  'New evidence for dark matter makes it even more exotic   https://t.co/5TMQYjEKIh via @EPFL_en  #VDtech #research https://t.co/9kYVTdE4Qa',
#  'Dark matter even darker than once thought https://t.co/ZtOtOP5A2o @_OScience @EPFL_en #DarkMatter #hubble #astronomy https://t.co/Em60qbAHty',
#  'According to #EPFL study, butterflies living in urban areas face  threat of consanguinity and potential extinction. https://t.co/9KCJ2kfaEk',
#  'Ultrafast processors thanks to #plasmons https://t.co/iHD8nqH1u9 @EPFL_en #Quantum #NanoStructures https://t.co/AE68fLyVS5',
#  "Fantastic multimedia presentation on solving paralysis by @EPFL_en 's Gregoire Courtine. Great to see 1st human steps #wysssupport #INS2017",
#  'Installation of all metal #ITER-like first wall in #fusion reactor JET has made it more difficult to operate https://t.co/0RyRa559N0 #epfl',
#  '@chr_lovis @Hopitaux_unige @UNIGEnews @PlaneteSante @EPFL all these careers need strong health informatics training and use of standards',
#  'New perovskite for next generation data storage https://t.co/doFVlXOv71 @EPFL @EPFL_en  #EnergyStorage',
#  "#FranceIA - Aude Billard Professeur @EPFL : l'Intelligence (comprendre pour s'adapter) a besoin de la Connaissance (apprendre et extrapoler) https://t.co/SnRTupk8po",
#  '#EHMicrobiomes2017 Prof Tom Battin @EPFL_en presents on an ocean of streams @NTUsg @NatureConf @Nature_NPJ Assoc Ed https://t.co/6F6pmTUKz2',
#  'Great talk &amp; discussion with @MindMazeSA CEO @TejTadi &amp; @venturelab_ch  @JordiMontserrat  #champsnight @EPFL_en  #VDtech https://t.co/wn528CRdWT',
#  'The @timeshighered ranks @ETH and @EPFL_en #1 and #2 international universities 2017! #swissuniversities #highered  https://t.co/yyfHSR2qSB https://t.co/WvJRzXAjGI',
#  'I have to wonder, how many innocent people have Swiss police raped &amp; tortured? 72% prison population foreign, how many tortured to confess?',
#  'Un laboratoire pour sauver l’architecture du XXe siècle. @EPFL @24heuresch #LeCorbusier https://t.co/oEEY3VEEb4',
#  '#Drone of the week 2 -  @EPFL Lausanne origami-inspired VTOL cargo drone with folding protective cage so it can fly and deliver safely https://t.co/nZ9KIgFBn2',
#  'For the very first time, #EPFL #Library takes part to Love #Data Week! Find all program details below and stay tuned for a week dedicated to #researchdata #openscience #lovedata18 https://t.co/chiBNcEiwj',
#  'The 1st presentation is held by Prof #DominiqueForay about evidence-based #S3 and its future in the post-2020🇪🇺R&amp;I #policy landscape. He says one of the S3 goals is finding new combinations between regional-specific capacities and regional-specific opportunities. @EPFL @EPFL_en https://t.co/SktacgRUkW',
#  'Financial predictions @appliedmldays @stefanotempesta @EPFL_en  #AMLD2018 #MachineLearning #Future #fintech #DataScience https://t.co/fcLZitSweo',
#  '@UEFA @UEFAEURO Anyway @EPFL_en students can enter? :D',
#  'Des opportunités à saisir! "Les technologies développées en laboratoire profitent aux sportifs" https://t.co/qFzdFOHgpP  via @EPFL https://t.co/5QiIWLrWqJ',
#  "A Sion, on construit un campus d'enfer... @hessovalais @thearkvalais @epfl valais, vu depuis @esr_officiel https://t.co/m4tVqnlCnm",
#  "#sleep #neuroscience #Neurosciences #science Healthy mitochondria could stop Alzheimer's https://t.co/rioZv4axxN #epfl",
#  'EPFL scientists developed self-healing materials inspired by plants. https://t.co/siauNzx3F8  via @EPFL_en #VDtech https://t.co/RyQo5Z3jhK',
#  'Database clarifies bottom-up design of cement https://t.co/ebJLvaLhZZ #epfl',
#  "Someone explores why Wikipedia is often the first stop when we start searching for information on a topic (even if we don't admit it) https://t.co/XwvnxYfUnq",
#  'Shape the future of neuromodulation research with world-leading scientists! Register now for NM2 - https://t.co/rBHLtiqx8A #nm2conf #epfl https://t.co/VNYNwsdB9f',
#  'A Swiss library that has revolutionized the concept of #library https://t.co/00OmLlVtO8  #travel #epfl #traveltuesday #switzerland',
#  'Thomas Knecht @ventureoffice announces that the Award ceremony 2018 will take place at EPFL https://t.co/nB3AmxXO6z',
#  'For space enthusiasts: EPFL offers a #MOOC about Space mission design and operations, w/ astronaut Claude Nicollier https://t.co/xFN5AbbRit',
#  'What are the most #international #universities in the world? @ETH_en and @EPFL_en lead in @timeshighered report! https://t.co/8Hh2xACpdn https://t.co/xaaPGIcVA3',
#  '@immersiatv,part of t/ future of European #media according to @tech_eu  @DSMeu  @EU_Commission #research #innovation https://t.co/PEMe43MDFn',
#  'Your Mozz, dropping the @GitHubEducation ✨ at the @EPFL MOOC Factory 🎥 https://t.co/ZmVFHhyHLi',
#  'Amin did all his studies @EPFL_en our thoughts with him and his family. This madness has to stop. https://t.co/NhSvJdPA0W',
#  '"How to become a growth hacker?" Great meeting today!! #BeSmart #Education #BeObsessive #Passion #Technology  @SwissEdtechCollider #Innovaud #EPFL #MassChallengeCH #ForbesUnder30 #swissnexindia  #UNICEF https://t.co/b4QWCQ4Hda',
#  'J’aimerai juste vous donnez une information,  Japan Impact aura lieux le 17 et 18 fev. 2018 #japanimpact https://t.co/JKUKX2kE3r https://t.co/nS9D2v1Vba #EPFL #Lausanne #nobillag #NEINzuNoBillag #rts #srg #RTSI',
#  'envirobot eel by #EPFL locates sources of water pollution #Switzerland https://t.co/u1oTTqcvLU',
#  'Invest invest invest in research... https://t.co/h3t8onSboe',
#  'Have a great week!! https://t.co/jS4tEWsGuH',
#  'First workshop for the #vleadersFintech with Curtis Giesen:How to Pitch in New York @dgt_switzerland @PostFinance @Innovaud @SFS_CH @EPFL_en https://t.co/A0fSbkkMWN',
#  '#Alzheimer: la #vitamine #B3 et un #antibiotique améliorent la santé des #mitochondries et réduisent ainsi les dommages de la maladie sur modèle #animal https://t.co/Gp8mbyxEqt via @EPFL https://t.co/xwNSG7VceI',
#  '⚠️CAUTION⚠️: critical avalanche danger in the Swiss (up to 4/5) but also in the French (up to 5/5) Alps due to heavy snowfalls and strong winds. Read the full bulletin on https://t.co/kBirk356nn - #snow #neige #snowscience #slf #avalanche #danger #swiss #france #alps #epfl https://t.co/lYyuK5w3yp',
#  'Highly Appreciated this work on #Sensors https://t.co/pYBCdHK9Rp',
#  '#Danish #school installs world’s largest #solar #façade: https://t.co/i7GsR6qW1m @EPFL_en #Copenhagen #Switzerland #Clean #Energy #Green https://t.co/5mVDxw3Ofn',
#  'Traces of possible Martian biological activity inside a #meteorite https://t.co/pzu3Ng1Vmp @_OScience @EPFL_en #Mars https://t.co/4L1koD6RGM',
#  'Presenting our last #vleadersLifeScience 2017 today, Mattias Larsson, founder of the @EPFL startup SUINCoL https://t.co/hDf05qrhIU https://t.co/NhpahRiSGp',
#  'A self-sufficient home with #solarpanels installed only on its #facade https://t.co/DRtXjxjdzd @epfl_en',
#  '#seednight tomorrow @EPFL_en come see PB&amp;B : Innovative Aesthetics &amp; Anti-aging medicine | https://t.co/Un7WLRhkna  #VDTech https://t.co/KMp1UrXPuO',
#  'Les polycopiés #EPFL, support de cours conçus par les profs., sont disponibles à la Bibliothèque et empruntables. https://t.co/baneVQtrxF https://t.co/cFIgqtYncp',
#  'Food, one of the largest industries in the world, enormous potential for new models. Great Challenge #OpenFood Hackdays @EPFL @marcelsalathe https://t.co/2sDCrePbwJ',
#  '@EPFL_en scientists developed a novel #DNA_sequencing technique suitable for DNA-binding proteins characterization. https://t.co/YX312G9r4i https://t.co/QYgDqTLVgt',
#  "@EPFL Retrouvez votre 1er tweet sélectionné par L'important https://t.co/B2tCt924Cp",
#  "Les cours finissent aujourd'hui et je souhaite de bonnes révisions aux 7047 étudiant/es inscrit/es aux examens! @agepoly @EPFL @EPFL_en https://t.co/RMj8q7ZfkL",
#  'Environnement, un marché en pleine croissance https://t.co/ThTcYLrMtn Avec Philippe Thalmann @EPFL',
#  '@CousinJimmy2 I made up a series of slides to tell my story about #torture &amp; #SexualHarassment  #SexualAbuse by #Swiss police inspector #FabienFontannaz public prosecitor #FredericGisler Dr of Law #unifr #epfl https://t.co/hWpUUidYd5 https://t.co/DFtDrCeTRL',
#  'New version of the @EPFL MOOC on plasmas available any time on @edXOnline Follow lectures on plasma medicine, superconductivity for fusion, and laser-plasma interaction, taught by experts from @Sorbonne_Univ_ &amp; @Polytechnique https://t.co/jgFKUMDVYI',
#  '[D] #DeepLearning Course | #EPFL : MachineLearning #deeplearning #ANN #AI #IA #machinelearning #BigData #DataScience https://t.co/ntpLsNraFN',
#  'MOOC on household level water treatment methods &amp; successful implementation strategies and assessing impact thereof. Part of “Sanitation, Water &amp; Solid Waste for Development” MOOC series. Free and running continuously. https://t.co/2ibzrsPR4b @EawagResearch @EPFL https://t.co/bH4l44ZsMN',
#  'Das neue Programm für praxis-orientierte #Eawag Kurse (PEAK) ist jetzt online: https://t.co/6HOuuYcWaB Der nächste Kurs «Relevé écomorphologique et évaluation des rives lacustres» findet am 7. Februar an der @EPFL statt : https://t.co/nW0iMiHxpb https://t.co/Rf4pSlGGAB',
#  'RAPPEL : la #bibliotheque @EPFL recherche encore des étudiant-e-s motivé-e-s pour aider à organiser une #SilentParty et faire danser le #RolexLearningCenter en 2018 🎧  #silentdisco #epfl Merci à ceux qui se sont déjà manifestés et bon weekend à tous ! https://t.co/Sx2WYOzLpj',
#  'Developing #robots that can walk more naturally https://t.co/A1Y1StV0lB #robotics @EPFL_en #Biorobotics https://t.co/oe6JHUUlM9',
#  '#SMiLE-seq identifies #binding #motifs of single and dimeric #transcription factors. #NGS #SLims @EPFL_en https://t.co/gdce6nyj6Y',
#  "EPFL's expansion towards green chemistry, alpine and extreme environments  https://t.co/OU16d36It9 #epfl https://t.co/MgstnsL32X",
#  "Belle leçon de technologie dans @RTScqfd avec l'exosquelette @twiice_official testé par Silke Pan. https://t.co/4uIdXckvaq #RTScqfd #EPFL",
#  'Portable probes hunt down cancer cells during surgery https://t.co/3qHw8vh9iL   via @EPFL_en https://t.co/lMaAhZ5YBR',
#  '"Noir, c\'est noir ?" dites vous ? #ARTLAB @pierresoulages @EPFL @EPFLculture #EPFL #neige #expo https://t.co/rolwlcNFEW',
#  '6 points last night for the Blues in the #EPFL after 2-0 &amp; 12-0 wins against Whipton and St Nicholas C! ⚽️🔵',
#  'Learning and adapting to different #materialities #temporalities of #biomedia at #colab workshop @EPFL @hackuarium @ossparis https://t.co/RPG0YTEMSU',
#  'EPFL embarks on new horizons in continuing education https://t.co/Os7mFKm1eH #VDtech cc @EPFL_en @Logitech https://t.co/D2oi9INPTX',
#  '#EPFL #CNBI 2016 Highlights(12/12): Our team won the first ever #Cybathlon #BCI race https://t.co/tAViRRWpkc Happy 2017 everybody!! https://t.co/QZV4sAErZq',
#  "I'm organizing a conference on Neuromodulation! Travel awards are available! https://t.co/rBHLtiqx8A #nm2conf @BlueBrainPjt @EPFL_en https://t.co/kggCYNsMWa",
#  'Last days to register for the next Startup Champions event "The multiple lives of entrepreneurs" at @EPFL https://t.co/YQ7UMJzvIn #Suchamps https://t.co/IhIHUJKfEK',
#  "#AIGS2017 #Ia #Ai interview @marcelsalathe @EPFL #DigitalHealth #Epidemiology @campusbiotech : L'importance des alertes précoses (resumé) https://t.co/arbZ9t2dzx",
#  "L'#EPFL crée un centre pour la #cybersécurité avec directeur académique du centre Jean-Pierre Hubaux #DigitalTrust https://t.co/qkYsnjcSKW #SECURITY https://t.co/RkCVWo6k2P",
#  "Très bel exemple d'une collaboration interdisciplinaire : quand les sciences humaines ont recours à la physique https://t.co/EHgKcHYUD6 @EPFL @frederickaplan #archivCH #archimag",
#  'New perovskite aging measurements offered for standardization by #EPFL | PV #Tech #Switzerland https://t.co/0acWalWs6Q',
#  'Caution ⚠️: Extreme avalanche danger in Wallis and in some French Massifs (Savoie) due to heavy snowfalls. Full belletin here: https://t.co/kBirk356nn  #avalanche #snow #snowscience #slf #extreme #danger #hazard #caution #prudence #neige #risque #switzerland #france #epfl https://t.co/cujSqv4kfD',
#  'Standardizing #perovskite aging measurements https://t.co/j25LlLqMTO @epfl_en',
#  '@kevinschawinski most influencing prof. in the ETH-Domain. Congrats! @EPFL_en strong in the top ten. https://t.co/YRndlr6ZH0 https://t.co/7ZGBR0eoTc',
#  'Die Onlineschule der @EPFL hat mit dem «Certificate of Open Studies» einen neuen akademischen Diplomtypus ins Leben gerufen | EPFL https://t.co/WzVUFMYxID #Weiterbildung #Diplom #COS',
#  'Ready for some Coltrane at Enoch Pratt Loch Raven branch. Free show. Kudos @WEAA_FM for the tip. https://t.co/6JEHTK8Y7i @epfl',
#  'Many congrats Stew! Great alumni @EPFL And good luck- #LaVieParisienne https://t.co/sJ0n2CDqW4',
#  'Today, we are witnessing the graduation of 994 new EPFL Ambassadors  Congratulations to the students and @EPFL #Magistrale2017 @EPFLevents https://t.co/3jD6FF6a9Z',
#  'Wonderful teashop in Nyon ! https://t.co/eOzeYPyI68 @leCercleduThe (also FB) @unil @EPFL @unige_en @LifeinNyon @MyNyonRegion @LemanTourisme',
#  'Significantly speeding up 3D STEM imaging of nanostructures by Emad Oveisi and colleagues @EPFL https://t.co/fQKnAEMwGU',
#  "#cyclobiblio #EPFL Espace d'expo au Learning Center https://t.co/HYAKwDur3O",
#  '#MuslimBan Amin Karbasi is a Professor at Yale University,  his wife and daughter are stuck outside the U.S. https://t.co/rqftymktm9',
#  'BSc&amp;master students: apply for the #nanotechnologies #summerschool by @GrenobleINP w/ partners @EPFL_en @PoliTOnews https://t.co/8JDuui0oiU https://t.co/ZSY1CshedK',
#  'La #Bibliothèque de l’EPFL recherche des étudiants @EPFL motivés pour aider à organiser une #SilentParty et faire danser le #RolexLearningCenter en 2018 🎧 Vous êtes intéressés par une collaboration avec nous, écrivez-nous avant le 21.01 à l’adresse : aurore.granval@epfl.ch 📧 https://t.co/gJfGWn1GcQ',
#  'Is it unethical to build an #AI that humans trust too much, asks @j2bryson - #AIhealth #swsx #sxswiss',
#  '@rlerignier @SNEedition désolé, je suis juriste, je ne connais pas la norme ISO 690!',
#  'Register to our #training  on Writing Successful #H2020 #proposals - 2 February #Zurich https://t.co/4opdWRQfn8 @heigvd @hes_so @hessovalais @bfh_hesb @ZHAW @uzh_news_en @ETH_en @dgt_switzerland @venturelab_ch @fsrmch @unifr @SwissEuresearch @snf_ch @SBFI_CH @EPFL_Park @EPFL_en https://t.co/0Wb6aE4GoX',
#  'New report on risk of misuse of life science research https://t.co/6HaoSkJTmZ #epfl  @ScnatCH https://t.co/VmkwW0Q2Gq',
#  "«La photographie d'archive à l'âge numérique» bientôt à sa 3ème édition au Tessin, SUPSI, Campus Trevano, 9 avril-4 mai 2018! @EPFL @epflENAC https://t.co/p0Ir0PifT3",
#  'We are on our way to the first @SwissCytometry meeting @EPFL in #Lausanne!  https://t.co/GAHnNOS8eu @LHW_Stratocore #SCM2018 #corefacility #cytometry #flowcytometry #winterwonderland',
#  'What? https://t.co/ruvegs5EGz',
#  'Une future ingénieure explique son projet @epfl @hessovalais https://t.co/Lbd4stAUnA',
#  "Two's company when it comes to 3D mapping  #mapKITE https://t.co/5hWWdcAhXR via @EPFL_en  #VDtech https://t.co/6Yp1YWa7Ww",
#  "Pause déjeuner , moment de convivialité en plein coeur de #Portivechju avant de reprendre les travaux de l'AG de #Association des #EPFL https://t.co/NZhkFZTpxe",
#  'Quand le «deep learning» confond une cafetière avec un cobra https://t.co/D7isVDVpnF @EPFL #robot',
#  '@RueeggThurgau @ewz_energie @mway_online @fairpower_ch Ein Stimmungsbild für Marco Rüegg 😉 #Tesla Parking @ #EPFL https://t.co/T31ekFPQ93',
#  '"Art and science collisions" - A presentation of art residence @CERN with Yunchul Kim and Helga Timko at @EPFL ----&gt; https://t.co/GT73OAEVOH',
#  'Anti-cancer drug gets a boost when combined with antirheumatic @EPFL_en @NTUsg in @NatureComms via @EurekAlert https://t.co/NR6UdhtjMs',
#  'Ypsomed is the first industrial partner at “5G for Switzerland” #Swisscomm #Ericsson #EPFL  https://t.co/6niXgyXGBX',
#  'Philipp Jovanovic @Daeinar, crypto-security researcher at @EPFL will be giving a talk at @dotsecurityio https://t.co/B1rCNGnBLz https://t.co/IKlrkSjQn5',
#  '@EPFL_en is it available on platforms other than edX?',
#  '"If you don\'t know @EPFL, it\'s the @Stanford of Switzerland" :-) says @ukn_is in Texas at @sxsw @swissnexSF @EPFL_en https://t.co/C8SSuIxMmg',
#  'Robo-reptiles spy on their flesh-and-blood counterparts https://t.co/CbwpArMemb #bbc #epfl',
#  'An effective and low-cost solution for storing #solarenergy @EPFL   https://t.co/BSZu1Pc7YK via @TechnologistEU https://t.co/qklwLQjIfD',
#  'The latest Dhums - CARLO! https://t.co/39TYlUIj9Y Thanks to @EPFL #hackdisrupt',
#  'Discovering https://t.co/Dgxoj2DAfK with Adrian Holzer @EPFL_en DH pedagogical day @unil @LADHUL @dariahTeach https://t.co/CGupOkY9bs',
#  'International ranking: #ETH and #EPFL are top institutes',
#  'Music of the Spheres https://t.co/XWOYpksLrI Aristotle says we were born hearing noise, without silence to compare. Meditate: music returns',
#  'Call for #EdTech startups: Get funding, mentoring &amp; more at @EPFL_en Apply by July 10 https://t.co/SrAXlq5VCe @ks_accelerator #EdTechAccelCH https://t.co/YNVYV7eNUK',
#  'We are happy that Prof. Thomas Nevian from #unibern will deliver the final #lecture in the afternoon session on Sept., 18. #nm2conf https://t.co/sNVhxo1QGG',
#  "#actuallyworking  They don't call it #funprog for nothing :p https://t.co/LqTQQYT5mx",
#  '@FEMTOprint at the 18th CMi Annual Review Meeting in #Lausanne @EPFL @EPFL_en presenting FEMTOPRINT® technology #3Dprinting #glass https://t.co/CJNAK2wC0p',
#  'Advances in (digital) #single-photon detectors for #PET with Dr Claudio Bruschini @EPFL #digitalimaging https://t.co/s3J7VXdGy9',
#  'Jordi Montserrat from @venturelab_ch talks at @EPFL_en #champsnight https://t.co/iewA0fhU09',
#  'The proteins that domesticated our genomes https://t.co/npGbUKJhBl  via @EPFL_en #VDtech https://t.co/It0SBqlKQc',
#  'Learn how to use technology innovation as a tool to fight poverty and enable sustainable development @EPFL https://t.co/MRCYgXna6G',
#  '@MarcAbrahams starts off the #IgNobel Award Tour Show! @improbresearch @EPFL https://t.co/pOI6gL8IYv',
#  'Julio Salgado  Born to Learn &amp; Teach is out! https://t.co/gGjxQOKINp Stories via @EPFL @IBMResearch @superglaze #theworldin #function',
#  'The latest The #Architecture Free Press! https://t.co/TLIeAHZlsD Thanks to @divisare_ @jorgensundberg @EPFL #interiordesign',
#  'Encouragements @CarinaDjey @edacyhq lancement programme FAST formation codeurs Dakar @esp_dakar @UCAD_Senegal @EPFL #Code #AfricanGeek #MOOC https://t.co/k7nDMJyQbi',
#  'Retina Projection. Nice. "Intel made smart glasses that look normal https://t.co/JtNNxaYhRL "via @verge',
#  '#SAVMAP Namibian semi-arid savanna images available for analysis at  https://t.co/5t4as0ueI1 @heluc @SDSCdatascience #DataJamDays #OpenData https://t.co/vHF2QDgetX',
#  "Let's be real: No one reads internet privacy policies. This AI can interpret the inscrutable legalese, helping you become a more informed user https://t.co/e2DCSOafRj",
#  'ICIQ leads A-LEAF, a collaborative project awarded with €8m by the @EU_Commission. Towards the artificial leaf! https://t.co/t9zId3kv0c https://t.co/0kFlweZ4eq',
#  'Official ceremony for @NobelPrize winner Jacques #Dubochet at @unil in presence of BR Guy #Parmelin! #OpenScience #Society #Rabelais @EPFL @EPFL_en @EPFLevents https://t.co/8HjddRIfxy',
#  'Bikes by night #epflcampus @EPFL https://t.co/Nt7v9hkz3o',
#  '@ericdubay   #Valentina @Madonna = #FakePussy @RealBaphomet. #KingConrad @BaychimoKin tortures me with this cheat 👹 👉https://t.co/WGAlJI7h0G',
#  '@Dedux @verge Der Miniprojektor stammt übrigens von Lemoptix, einem @EPFL (🇨🇭) spin-off, dass Intel 2015 übernommen hat #innovation #AR @venturelab_ch @swissnexSF @swissnexBoston',
#  'A step forward! Targeting #cancer cells by measuring electric currents https://t.co/iHyJn6az2y   via @EPFL_en #VDtech https://t.co/P91QRjK7Zg',
#  'Notre conférence au Musée d’art et d’histoire à #Genève aura lieu demain, mardi 30/01 à 10h @MAHgeneve @EPFL @UNOSAT Venez nombreux ! #patrimoine #numérique #drones #innovation Plus d’info: https://t.co/NJOVod2dSN &amp; découvrez un article https://t.co/SJ1ZR4XD52 du @bilanmagazine. https://t.co/AodXrEKiH3',
#  'Reportage sur @TF1LeJT "Les étudiants français se tournent davantage vers la Suisse pour leurs formations professionnelles" #Lausanne https://t.co/TJQhmYUZ6Y @EHLnews @EPFL https://t.co/UauwsmL5oR',
#  'A warm thank you to the visitors who joined us inside the EPFL+ECAL Lab during the Open Days. #epflecallab #ecal #epfl #designresearch #digitalinnovation https://t.co/pxrAzr8xO1',
#  'Now @EPFL offers @MScRobotics Join a long list of brillant minds @robotics @epflPhD https://t.co/mSnLgmpaoL https://t.co/C0VPVlzRBv',
#  'From @EPFL spin-off to @sundancefest sensation in a few months: we made it to @TechCrunch front page! https://t.co/RAG69bzVks Thanks to @JoshConstine @DARTseventeen @Fongit1 @swissnexSF @venturekick @MassChallengeCH @prohelvetia @WorldVRforum #LNCO #CNP #MarkBoulos #ElasticTime',
#  'Camille’s first paper @EPFL is now officially online @EnvSciTech: Kinetics of Inactivation of Waterborne Enteric Viruses by Ozone https://t.co/kJfcbBihjp',
#  "#EPFL's imposter #Robotic fish infiltrates a school of zebrafish #Switzerland https://t.co/J8TP5su3HT",
#  'Data Science and Mobility Conference is co-organized by EPFL and SBB CFF FFS. 31 JANV 2018 https://t.co/PNAm80x8Tn - @EPFL https://t.co/4ldolDo6UW',
#  '@dgt_switzerland @lereseau @EPFL_en #CybersecurityDay : les #objetsconnectés #IntelligenceArtificielle #réalitéaugmentée sont les points sensibles de #cybersécurité https://t.co/ELpyoRrS7S',
#  'Le nouveau programme des cours #Eawag axés sur la pratique (PEAK) est en ligne : https://t.co/CvHref9Yhb Le prochain cours « Relevé écomorphologique et évaluation des rives lacustres » aura lieu le 7 février @EPFL : https://t.co/CbsxY8WDUh https://t.co/R14LLnHB2w',
#  'Chocolate &amp; berries #vegan cheesecake for my @EPFL coworkers! ✌🏽🌱 #veganfood #EPFLfood https://t.co/wPlLsIt0KD',
#  'A robotic spy among the #fish https://t.co/G09yB45HzQ @epfl_en',
#  'Waiting for the ceremony to start! #epflalumnigala #epfl  @epfl https://t.co/ucZjZmNfYF',
#  'Impressive! Carving diamonds for optical components https://t.co/iVlpjAiMhi  via @EPFL_en #VDtech https://t.co/SXE1fctdY4',
#  'A great day to graduate! The Magistrale starts at 10:30, live on https://t.co/vH8Rzk17P4. Congratulations to the 994 new Alumni @EPFL_en https://t.co/SI9sz9CXpV',
#  'Today is lab day: great honor to welcome @NobelPrize winner Jacques Dubochet and talk about #serendipity! @unil @EPFL @EPFL_en @EPFLevents https://t.co/wiRwfHoU4I',
#  'Special thanks to @esp_dakar and @EPFL for enabling young students with quality content that will guide them to become game-changers. https://t.co/Qb95jqTuVD',
#  'Design thinking:   “Unlike other approaches, design does not try to apply well defined existing formula to a well defined problem.   You really start by questioning the problem with a very open mind.  This allows you to free yourself from any constraints.”  — Jeffrey Huang, @EPFL https://t.co/dpEmD35x1R',
#  'Nouveau #MAS dédié aux professionnels en #urbanisme et aménagement territorial proposé par @UNIGEnews et @EPFL https://t.co/LURaA7Vj2C https://t.co/WuUPLby1uj',
#  "Actually, I've read a great many privacy policies and there are some real gems (I'm 🧐 you, Relevant Knowledge/ComScore...). Great work here by @EPFL @EPFL_en https://t.co/Xv6bg2vfq4",
#  'Merry Xmas and happy new year to you too @MartinVetterli May 2018 be a year of peace, love and success for all of us! @Martel_Innovate @DSMeu @dgt_switzerland https://t.co/xdDm5pf3de',
#  "We are proud of our 12 years collaborations with AC immune; first in the field of Alzheimer's disease and now in ALS. Prof. Andrea Pfeifer is a source of pride &amp; inspiration for all of us &amp; has been an excellent role model &amp; supporter of our @EPFL students &amp; young scientists https://t.co/KFT1W7G4LU",
#  "Demain 24 personnes (bah oui, seulement, c'est cosy à L'éprouvette, mais on vous prépare un atelier permanent !) feront Ah ah ?! avec Jacques #dubochet, #NobelPrize de Chimie 2017 ! Rencontre suivie d'un atelier pratique de microscopie électronique. @unil @epfl @EPFLevents https://t.co/kjZgNSs9y0",
#  '#ETUDESANTEDUSOIR Découverte de 16 repères génétiques associés à 1 durée de vie diminuée https://t.co/kJPoGu24IT @CHUVLausanne @EPFL @ISBSIB',
#  "Congrats to @ETH_en for winning this year's #Challenge! We'll be back next year :-) @EPFL @agepoly https://t.co/2BYW3asuc2",
#  "Des cellules solaires en perovskite stables pendant plus d'un an https://t.co/iv291Y1AIU #epfl",
#  "Amazing! So glad to have been part of the 1st @EDACYHQ bootcamp and to have met these stellar students. They'll shine at @GROUPECOFINA. https://t.co/f9bWoyTwVG",
#  "Follow FoE's @shada_islam today as she chairs a roundtable discussion at @EPFL_en in Lausanne on the 'Asia meets Europe Day' #ASEMday https://t.co/t3v91hJq8m",
#  "Bhutan's happiness stems from its hydropower too https://t.co/tmtdSTsjZH  via @EPFL_en https://t.co/qJrbJbDrv0",
#  'Another 6 points for the blues in the #EPFL after 3-1 &amp; 5-1 wins against St Nicholas and Ladysmith! ⚽️🔵',
#  'This Thursday! Swiss EdTech Collider Inauguration @EPFL https://t.co/nSYlBisZna #EdTech #SwissEdTechCollider #Innovation @coorpacademy https://t.co/bEZXs7dnvG',
#  '@EuroSys2018 PC meeting about to start @EPFL ! https://t.co/mkMcVI1dkl',
#  'The Grid to Mobility concept explained to @EPFL chemistry students by Prof. @GiraultHubert. Good introduction before @Electromobilis visit https://t.co/qLhytdTUY3',
#  '@petewarden from @Google #TensorFlow team at the @appliedmldays in @EPFL https://t.co/ctX6uusYoG',
#  'Pour vous détendre après les fêtes :-) Les ondes cérébrales et l intention... inscription obligatoire.  Best wishes for 2018 ! https://t.co/JYucag59jQ',
#  '@ShameTorturers What is this? Are you in Australia saying Police rapists! My bloody god what? The more I read the more I don’t believe why people are even on here.',
#  '+ 1000, Un mouvement en ce sens ferait gagner un temps précieux à de nombreuses personnes https://t.co/zi0uRmuTL5',
#  'size matters! https://t.co/MTL9l8RNeV #titlelength #impact #scientificquality @EPFL_en @EPFL via @JamesLarus https://t.co/m2MwuQ78mG',
#  '#ScarletYohansson is a #DISGRACE LOOKING LIKE a BOY @womensmarch  👉https://t.co/pLgg4cfE4T  WE DONT WANT NWO TRANSGENDER ANTICHRIST BAPHOMET',
#  '«Nous ouvrons l’#EPFL à ceux qui n’ont pas fait d’études» https://t.co/moWbfuCy7i via @24heuresch @EBorloz #CDFdanslapresse #CDF',
#  '"Ce #biociment peut être produit sur place, à moindre coût, à température ambiante et avec un besoin en énergie limité" #Innovation @EPFL https://t.co/HOcwLVUMq1',
#  "Leprosy's drug resistance and origin revealed by genome analysis https://t.co/JdRe4qvhvJ #epfl",
#  '#SwitzerlandHasTalent. Congratulations to Jacques Dubochet. https://t.co/OrUD3ekBuT',
#  'FIT supports Alogo Analysis et Viventis Microscopy (post in French). Welcome to both ventures! https://t.co/c1EIcMVNiQ via @startuptickerCH #startupfit #VDtech @alogoanalysis @EPFL_en https://t.co/eUeJ1RPwuJ',
#  "Chuis à un talk de Google à la fac IC @EPFL et j'ai l'impression qu'il y a aucun étudiant Bachelor",
#  'The Latsis prize ceremony is about to start with Prof. Xile Hu @EPFL_en @snsf_ch #scientistswhoselfie https://t.co/7bQ0irdDSS',
#  'A bacterial powder for quickly stabilizing soils https://t.co/PQSLFAjACE #epfl',
#  'Shameless plug: Audio-tactile and peripersonal space processing around the trunk in human parietal and temporal cortex: an intracranial EEG study https://t.co/laKV7L5BrM @BernasconiFosco @n_faivre @royesal @biorxiv_neursci @EPFL',
#  '#UEFA Professional Football Strategy Council discuss Financial Fair Play and new rules - https://t.co/1IsMYa7E0p via @SportsCrunchIND #ECA #EPFL #FIFA #FIFPro #PFSC https://t.co/MSdk9VYgCj',
#  'Excellent point by @EPFL ‘s Alex Alahi at #a3forum – #ArtificialIntelligence based perception for mobile #robotics and #autonomous cars in human populated environments must incorporate “social intelligence”. Understanding of etiquette and social norms critical. @AlexAlahi',
#  'Deputy Director Doug Stone is presenting the very first YQI Distinguished Lecturer Award to Tobias Kippenberg of @EPFL_en https://t.co/JqyDAbXWF7',
#  'ITFA @itfaconference session @ASSAMeeting #ASSA2018 : «\xa0The Benefits of Labor Mobility in a Currency Union » by Linda L. Tesar @CES_Michigan University of Michigan @nberpubs with C. House @nberpubs and C. Proesbting @EPFL_en https://t.co/aa0crtMGNF',
#  'Congrats @OsaeKomi for making the list! #DigitalShapers #DataScience @EPFL_en @ETH_en @Bilanz @letemps @SDSCdatascience https://t.co/PQipGcl9wC',
#  'Prof. Gratzel @EPFL speaks on the past, present and future opportunities of solar cell research.(Check out his early work @notredamescience) https://t.co/gDDWYWAhp4',
#  "Un incubateur dédié aux technologies de l'éducation en Suisse https://t.co/uwfYkMcZ5P v/ @BrigittePierrat #epfl",
#  'Unveiling the biology behind nonalcoholic fatty #liver disease https://t.co/t1G10gVbTe via @EPFL_en @EurekAlertAAAS #NAFLD',
#  'Reconciling solar energy and heritage preservation, via @leso_epfl https://t.co/81JoJEIdzx #epfl #epflENAC https://t.co/XVeVAMgJGI',
#  'Le mystère Soulages éblouit la science @EPFL  https://t.co/u3uNICyAdi',
#  'Tomorrow is THE day! #expscifilm17 talented participants will have 72 hrs to produce short films communicating science. Come and watch their works at the public screening on Wed 6th Dec at Cinema City Club in Pully! #scicomm @unil @EPFL @LettresUNIL @cuso_phd @EPFL_en',
#  'Reportage de @TF1LeJT sur @EPFL et @EHLnews: https://t.co/7p7b964Hq3',
#  '#Pentacene excitons are investigated by using a molecular-scale approach, focusing on the generation of #electroluminescence by local charge injection from an STM tip into individual pentacene nanocrystallites @maxplanckpress @UCL @EPFL https://t.co/scnZxhPtgU https://t.co/gOs2E6k7BA',
#  'Ce matin, Comité directeur du collegium franco-Suisse SMYLE. Au menu: projets collaboratifs, cours partagés et innovation croisée entre @epfl et @Univ_BFC: du concret entre la France et la Suisse! @insis_cnrs @CNRS_Centre_Est @ENSMMOfficiel @ufc_univ. https://t.co/HpfQgy1YuF',
#  "let's meet there ;-) https://t.co/z2JNFClvGK",
#  'The meeting of the Program Committee of @EuroSys2018 is happening now at @EPFL! #eurosys2018 #conference #Porto https://t.co/fNU3WQtNd3',
#  '#Infoscience is currently down for maintenance 🔧 We thank you for your understanding and wish you a very good weekend! #EPFL https://t.co/VKMbzf7Wc0',
#  'Childcare at conferences! Most excellent. Hopefully qualified and vetted persons only. https://t.co/bdOWQOqXer',
# ...
#  'Congratulations! @GamayaNews #VDtech #startupfit cc @FIT_fund https://t.co/JPWhjdPxSu',
#  '#Sécurité #aérienne: une caméra peut suffire à détecter et suivre un drone, montre une recherche @EPFL https://t.co/ITu0SSEbug https://t.co/3BJTbR7d5l',
#  'Les jeux vidéos connaissent une nouvelle jeunesse ! @EPFL l\'étudie même à travers son "gameLab"🕹#RTStribu  https://t.co/bPsQ6UQC26 https://t.co/Zg9E18bG21',
#  "Du 30 mars - 1er avril: Assistez au SMILE ➡ 3 jours d'improvisation de folie à la salle polyvalente de l' @EPFL https://t.co/sRfCMYSSVn https://t.co/58hOXS4WcO",
#  "Découverte de l'exposition #PierreSoulages. Merci @LucMeier pour la visite passionnante du #Artlab @EPFL https://t.co/SnElwPUby7",
#  'Un livre pour réussir ses études @EPFL et ailleurs. https://t.co/oPWuhvzS5d https://t.co/r5vo6FUYlG',
#  'Researchers at @EPFL_en are working on edible robots to improve healthcare. More via @businessinsider… https://t.co/JkEuFAeYDp',
#  '@JimStolze @aigency_com and Yves Perriard @EPFL_en are the two keynote speakers at High-Tech Systems 2018! Visitor registration is open: https://t.co/uBW87pOuAn #hts18 #22March #Eindhoven https://t.co/sMknizEYIp',
#  'Attending the 2nd applied machine learning days @EPFL #AMLD2018 To address fear of #ml #ai they had a weekend of workshops; hundreds took them, but hundreds more on waiting lists. Will probably livetweet over on @j2blather. https://t.co/0bgdAVIpyo online extension school, has ML.',
#  'Les émissions de #CO2 en hausse après trois ans de stabilité https://t.co/HpzaNZZkzi Avec Marc Laperrouza @heclausanne @EPFL',
#  '#Tech: L’#EPFL sera la capitale des drones début septembre -   High-Tech - lematin.ch #Switzerland https://t.co/fmF9gEd4kM',
#  "A ne pas manquer! La 5ème édition du STIL - Salon des Technologies de l'Innovation de Lausanne aura lieu le 1er mars @SwissTech_EPFL https://t.co/XxTF4AgbQB   #VDtech @EPFL @STIL_officiel https://t.co/gXYA6bRhFl",
#  "Prof Haenni is presenting at @epfl the current research in electronic voting. Lots of fascinating math, which is currently being deployed!  In particular, Geneva probably has one of today's most advanced e-voting systems. Though it's not operational yet. https://t.co/JovwCjqzEH",
#  'Its about Energy &amp; People ! Blue Brain Nexus: an open-source tool for data-driven science https://t.co/1kTFeYqZe6 #epfl',
#  'Interesting article in @Ageficom today (French): Switzerland, talent pool for robotics, featuring an interview with the @nccrrobotics director @DFloreano @nccrrobotics is @snsf_ch  funded, constituted of groups from #EPFL #ETHZ #UZH and #IDSIA https://t.co/39URk8ZHu9',
#  'Corse design workshop at #MOOC camp #EPFL https://t.co/bEXn0kdFLf',
#  'Kiss your chronic pain goodbye with #virtual #reality! See how @EPFL is using VR to reduce #pain in #paraplegics. https://t.co/V9RRdrV5JZ https://t.co/S6uSZEUCPM',
#  'The first ever photograph of light as both a particle and wave https://t.co/9oxZ0xpeBg #epfl',
#  '@suhaibfahmy @EPFL_en "we have demonstrated that FPGAs can be virtualised with limited overhead"   Lots of parts are still missing for this.',
#  'Yosef Akthman: "I never planned to become an entrepreuner, but the entrepreneurial community @EPFL_en encouraged me to start @GamayaNews" https://t.co/BMJ2ym1mdY',
#  'Energy Focus: A Conversation with Michael Grätzel (open access) @EPFL https://t.co/tOdcUwv0E7 https://t.co/Wj0GLSts7w',
#  "Reuters has ranked @EPFL_en as Europe's 4th most innovative university (after Imperial + Cambridge University) https://t.co/8Ov83oQaH8",
#  'Une école qui arbore la plus grande façade #solaire au monde https://t.co/t84i2MbIUN #PV #EnR #solar v/ @epfl https://t.co/1RC2EDm3bC',
#  'Archival photos offer research value, an exhibition @AcmEpfl @EPFL_en https://t.co/LNjbG0CMNE https://t.co/i5LwEFylXM',
#  'Why Innovation needs to be Sustainable? with Prof. Chris. Tucci, Jos Verbeek, Rajiv Srivastava @EPFL @WorldBank @GoodPowWow OnlyTheGood https://t.co/Jt7HMcgNYE',
#  '#Cryogenic #fab on a #chip https://t.co/HMtp66wT6W @acsnano - Matthias Imboden @EPFL_en @WPDL &amp; David Bishop @BU_ece @BU_Tweets /PSW #nano https://t.co/uuI9TmgNXt',
#  'Paper with collaborators at @EPFL_en on Virtualized FPGA Runtime for the Cloud published in IEEE Access https://t.co/BiQCjZRjl8',
#  'The first low-cost system for splitting carbon dioxide https://t.co/nhAX6iRAI5 @epfl_en',
#  'Sarah Perrin @EPFL quitte Punta Arenas pour la haute mer. Stormy Weather expected in the next hours 😷😝 #ACEexpedition https://t.co/Km1P7dnpr4',
#  "@BonnardV @EPFL C'est pour vous !",
#  'Les #GAFA sont-ils devenus trop puissants? https://t.co/9F9q98oXPE Avec Charles Wyplosz @IHEID et Denis Gillet @EPFL',
#  'Gros plan sur les infections graves chez les nouveau-nés https://t.co/BMpoZyOu0X Avec J.Fellay @EPFL @ISBSIB  E.Giannoni @CHUVLausanne',
#  'Propriété intellectuelle: La Suisse championne du monde des brevets -   Suisse via @EPFL https://t.co/7zwhP1J03t',
#  'Les #Robots du futur auront des yeux suisses https://t.co/LRVirfNYWc via ictjournal.ch #vision #startup #Switzerland #innovation #gafam #epfl https://t.co/JLGbaXvTKj',
#  "@aurelberra @frederickaplan Sur le campus, les règles varient entre @EPFL et @unil, mais aussi au sein de chaque faculté de l'@unil !",
#  "#EPFL's #Robotic eel detects water pollutants | Internet of Business #Switzerland https://t.co/LuZVTvhQZM",
#  "lili bêche bien chez notre oncle Ferdinand Nestor  Napoleon mange allègrement six poulet sans claquer d'argent https://t.co/N2E6P5LUUW",
#  'Talk on "sex and power" by @JohnAntonakis at @EPFL https://t.co/XzOgADBp4d',
#  'La newsletter robotique #epfl - septembre 2017 - est là, inscrivez-vous et profitez des activites https://t.co/JoKzxOveRH',
#  'O(Oblivious)Ride: An encryption system that hides your travel data from Uber https://t.co/RCxH00Hmqi #epfl HT @r0xanaradu',
#  '@MSCActions @EU_H2020 #ESR Imane &amp; Bartek @EPFL presented their research work during the 2017 Research Day @epflENAC #ENACResearchDay 😀👍👏 https://t.co/PIufk3cdnA',
#  'Traces of possible Martian biological activity inside a #meteorite https://t.co/pzu3Ng1Vmp @_OScience @EPFL_en #Mars https://t.co/4L1koD6RGM',
#  '@lore25n @CovestroGroup @IMDEA_Nano @EPFL_en @UJI_noticias @imperialcollege A lot of european institutions and industries, indeed! Congrats!',
#  'Proud to see @EPFL_en at the top of Most International Universities 2017 with @ETH_en https://t.co/xxXszgeJWT via @Phil_Baty @timeshighered',
#  'Why We Read Wikipedia: Leila Zia on joint work in progress with @gesis_org @EPFL @Stanford on Wikipedia’s readership https://t.co/OcKxedDTcN https://t.co/15wpb7M1Bb',
#  '#Rosicrucio_PROTESTANT @CardinalDolan TOOK The PISS on 1 #TraditionalCatholic @fatherjenkins   💡👉https://t.co/oBWvlksO6f  #TrumpInauguration',
#  'Here are some practical steps your institution can take to make progress on the #openaccess journey https://t.co/518lM0YmsN https://t.co/Y8lnj3lGov',
#  "@marcelsalathe A while back they tried to recruit me and I said 'thanks, but no thanks'. Maybe it was a hasty analysis but the puzzled 'are you sure?' reply I got led me think the employee didn't really understood what it meant to work for them.",
#  '@rlerignier @SNEedition il doit bien avoir des ressources quelque part pour un premier standard csl #zotero en droit français!',
#  '@MartinVetterli @EPFL_en @EPFL congratulations.  Wishing you much success!  @Martin_Dahinden',
#  'Get your hands dirty at our "Making Fast and Slow" workshop this Thursday! Just 2 spots left! #epfl https://t.co/DP3fdXFP3Z',
#  "Lorsque l'intelligence artificielle compose des mélodies authentiques https://t.co/4qQQKsoAFM @EPFL #robot",
#  'The gene behind #follicularlymphoma https://t.co/s48GvdsTQA @epfl_en @sciencetm',
#  'University #cargobike sharing in Lausanne, at the @EPFL https://t.co/VcQxJWcrFr https://t.co/vhHNID4xQM',
#  '31.05.2017 - M. J. FOX FOUNDATION I RESEARCH FUNDING https://t.co/pZhX72Iq33 #epfl @MichaelJFoxOrg',
#  'This Tuesday - Join us for a free MFE Practitioner Seminar #EPFL InvestGlass https://t.co/R7mL9nj9Lo #ai #bigdata #roboadvisor @EPFL',
#  'Impressionnante présentation des activités du centre de Neuroprothèses de l @EPFL https://t.co/3Wjjjpb40a',
#  'Rewards after the long reviewing process, Bürgi et al. @EPFL has helped to understand a #raredisease, well done! https://t.co/FTCNK40ssm',
#  '@SwissLitho &amp; @EPFL_en make #nanopatterns in silicon with  thermal scanning probe #lithography #nanofabrication https://t.co/0XcZHD4Kon https://t.co/PTubxyMEbP',
#  'The Board of the Swiss Federal Institutes of Technology has announced the appointment of three professors at #EPFL. https://t.co/u8sf3qyYqC',
#  'Just arrived #seedstarssummit @EPFL - salad &amp; #Nespresso = Disruptive or disconcerting coffee break?! Look fwd to plenary excitement... https://t.co/RkCrHmVit4',
#  "The latest L'îlot d'ashdawai! https://t.co/d76bUIfpKW #epfl",
#  'EN DIRECT sur #Periscope : Getting kicked by @Jordimontserrat #AITcamp #epfl https://t.co/JOgVKdfElN',
#  '@andrisilbi_ ich würde meinen Exzellenz zahlt sich aus. Glückwunsch an @ETH Félicitations au @EPFL',
#  'Migration vers #SAPHANA  @EPFL Projet réussi et accompagné par TeamWork #casestudy #témoignage https://t.co/QdHJD4aOYE',
#  'But what a woman! @samsam_86 #EPFL   https://t.co/hM1ccY2plN',
#  'The last thing I would want is Palantir, a private SV data mining corporation owned by Peter Thiel, anywhere near even just a single bit about my digital identity. https://t.co/rSSXorVWmg',
#  'Le 16 janvier aura lieu à l\'#Enssib la conférence "L’Europe doit construire la première Time Machine" de @frederickaplan (professeur en Humanités numériques @EPFL et directeur du Digital Humanities Lab) ➡ Programme &amp; inscription en ligne : https://t.co/EaLK3tVseM #numérique',
#  'Check out our new paper: The internal structure and dynamics of chromatin fibers revealed by single-molecule FRET (modulated by HP1a) in @NatureComms https://t.co/6oNRmEWcnB @EPFL',
#  'PRZEMEK Kornatowski on sharing his experience and good practices in opening a #Startup while still working in #academia #drones @EPFL https://t.co/tW2m5h2Tnt',
#  'Les lauréats du prix Durabilis, le concours de travaux sur la durabilité des étudiant.e.s @UNIL @EPFL #UNILDurable https://t.co/Az7xlFK3dA',
#  "Comment les vaches s'adapteront-elles au changement climatique? https://t.co/OXYrJRouDp Avec Stéphane Joost @EPFL",
#  "We are very proud to announce that our startup has been chosen to take part in the @_Innosuisse Winter '18 Startup Camp Cohort in San Francisco USA. See you soon @swissnexSF! #swissnex #innosuisse #sanfrancisco #smartparking #smartmobility #SmartCity  #ethspinoff @SwissStartups https://t.co/t606fVEcBz",
#  'EPFL morning #epfl #lausanne #photography https://t.co/6IXddicblu',
#  'Calculating the CO2 Emissions of Biofuels is not Enough https://t.co/RvqUOKY5Tq             @EPFL_en #biofuels #eu #psd',
#  'Today in #OSA_OpEx, researchers from @EPFL_en develop #opticalfiber that could lead to using #3DPrinting to repair damaged tissue https://t.co/XLbSOH30IO via @opticalsociety @EurekAlert',
#  'Conférence: géothermie de surface et développements architecturaux et urbains du souterrain, 15 Juin 17h, @EPFL https://t.co/RzZ6B6Brrw https://t.co/1fat8DE575',
#  '#Danish #school installs world’s largest #solar #façade: https://t.co/vui3aaz3z6 @EPFL_en #Copenhagen #Switzerland #Clean #Energy #Green https://t.co/qEIn9qWqOl',
#  'Interessanter Artikel von @MirkoBischBerg @EPFL aus Texas. #virtualreality #science #arts. Evolution der Maschinen https://t.co/dNOt4OimmV',
#  'Fantastic! Primates Regain Control of Paralyzed Limb https://t.co/BtfMCSW0xP via @EPFL_en #VDtech https://t.co/EeK6g1Vnm5',
#  'Silent➕accurate, the 21st century MechanicClock of #EPFL unveiled in #Neuchatel city hall  https://t.co/ceUOg4mYQI',
#  'Therapeutic #Robots May Soon Assist Patients After Stroke https://t.co/kZBZzLzN5C via @RIA_robotics ft @MIT @EPFL_en https://t.co/fpKkYTcLIj',
#  'Great event and opportunity to network next week at the Rolex Center @EPFL_en . See you there. @meilleurduwebCH  – https://t.co/uMgKc3Ot0d https://t.co/UPvWgqkPEz',
#  'EPFL President @MartinVetterli   speaking tonight at #venture2017 Competition Kickoff @EPFL_en Rolex Learning Center https://t.co/WsOsmMrtbl',
#  '#Sandec’s @FabianSuter1 Next MOOC Public Health Engineering in Humanitarian Contexts starts 6 Nov 2017 @EPFL @ICRC https://t.co/TakzFGo7zX. https://t.co/09hXNyItyK',
#  '#Lausanne et la Riponne: comment valoriser au mieux les places dans les villes? https://t.co/KNbo1QjPfq Avec J.Chenal  @EPFL',
#  '#Lausanne et la Riponne: comment valoriser au mieux les places dans les villes? https://t.co/syqNwJmzZX Avec J.Chenal  @EPFL',
#  '"Effets des #nanoparticules sur les cellules immunitaires humaines". Se former pour mieux comprendre les enjeux liés à la sécurité des nano-objets/nanoparticules. Formation @epfl sur #Nanonmatériaux https://t.co/LD04JBXPSW https://t.co/27eNJyDfx9',
#  '@ElliottRHams @winstonmeiiis Send the envelope on to #Swiss @PoliceValais Help take out a racist, #torturing #sexual #pervert Like @OskarFreysinger whose police rape 7 year old boys Dont get investigated even when found with child porn On a police laptop no less! #Switzerland #nazis #epfl #unifr  #metoo https://t.co/HJBHWUl4Pv',
#  '#Footersis FHLL Lausanne End  SolutionsSolar  Lab  Development   With https://t.co/EFz6CwdB96',
#  '@EPFL go to https://t.co/go0ZwhqT8d … … … … … … … … and read my campaign for the 2020 election',
#  'Only a few spaces available! Sign up now for @SDSCdatascience and @EPFL_en #DataJamDays https://t.co/VP03plBbr7 #DataScience #OpenData https://t.co/XjKYkw636q',
#  "Jouer dans un musée...c'est nouveau ça! Venez découvrir les prototypes à 16 heures @EPFLArtLab @museomixCH @EPFL https://t.co/tcOVYTrn9i",
#  'Want an overview of the 1st eight @SDSCdatascience exciting projects starting this fall, in collaboration with ETH domain institutes @ETH_en @EPFL_en @Empa_CH @psich_en @WSL_research @EawagResearch? https://t.co/Nr5Ni3ChY4 #DataScience https://t.co/ktstR2m5Yi',
#  'EPFL students get hands-on experience with “Made in China” https://t.co/DKgMXia7tQ #epfl',
#  'New Article: @EPFL team systematically studies impact of operation conditions on degradation of #perovskite #solarcells. Read free at https://t.co/vbGwIfAseA https://t.co/pO2qUiakbH',
#  'I strongly encourage anyone at @EPFL_en to apply! PM me if you want info about the event. Went last year, was fantastic! ping @EPFLlibrary https://t.co/hWhYyeVln4',
#  '@EPFL Veuillez retirer ce zizi de ma vue où je vous dénonce à La Manif pour tous 😇 https://t.co/bVUygd07Tv',
#  'Le Président @JC_Angelini accueille les représentants des #EPFL à #Portivechju pour 3 jours https://t.co/gts6LU5TNR',
#  'Join us on April 26 at the Startup Champions Seed Night at @EPFL showcasing 24 world-class startups: https://t.co/89ZIiby5fs #ChampsNight https://t.co/u4FNMegdup',
#  'Final day of #FEMS2017, looking forward to the Insect-Microbe session.',
#  "The SwissTech Convention Center in Lausanne looking 👌☀️\xa0ahead of today's UEFA #NationsLeague draw. Watch live at https://t.co/XdBiSzjw1U from 12:00CET. https://t.co/e2ogm9Ze7V",
#  'Juristes, utilisez le Guide de citation des références juridiques Ref-Lex [@SNEedition] : https://t.co/XiizQTsr9Z #Références #Bibliographie https://t.co/Zjy1dEtlLS',
#  'Congrats to @EPFL_en https://t.co/FeR6wWR7fc',
#  'Still wondering what are best #Engineering Universities in the world? @ETH_en and @EPFL_en are top 10! #ThinkSwiss https://t.co/50AuCBAVCM https://t.co/3rjIIef5aG',
#  "Merci à @MartinVetterli pour son soutien dans la création d'un campus carbo-neutre à l'horizon 2020. Campus durable @EPFL est déjà au travail afin d'atteindre cet objectif très ambitieux. https://t.co/1KcnFc67xr",
#  "Healthy mitochondria could stop Alzheimer's https://t.co/s3GMGUc9Sf via @EPFL_en #VDtech #research https://t.co/t9oXZgtX4h",
#  'Soon starting ! https://t.co/eVlW3Kf6VE',
#  'This conference is going to be awesome! Really excited to teach during the workshop days. #ai #machinelearning #datascience https://t.co/nkj1g5q9rI',
#  ...]

# %%
def read_corpus():
    '''Reads corpus from files.'''
    
    documents = []
    orig_docs = []
    DIR = './'
    tknzr = TweetTokenizer()
    with open("epfldocs.txt", encoding = "utf-8") as f:
        content = f.readlines()
    for text in content:
        orig_docs.append(text)
        # split into words
        tokens = tknzr.tokenize(text)
        # convert to lower case
        tokens = [w.lower() for w in tokens]
        # remove punctuation from each word
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove remaining tokens that are not alphabetic
        words = [word for word in stripped if word.isalpha()]
        # filter out stop words
        words = [w for w in words if not w in stop_words]

        documents.append(' '.join(words))
    return documents, orig_docs

# %%
documents, orig_docs = read_corpus()

# %%
len(documents)
# Out:
# 1075

# %% [markdown]
# ### 1.2. Build the vocabulary by selecting top-k frequent words

# %%
def create_vocabulary_frequency(corpus, vocab_len):
    '''Select top-k (k = vocab_len) words in term of frequencies as vocabulary'''
    
    count = {}
    for document in corpus:
        for word in document.split():
            if word in count:
                count[word] += 1
            else:
                count[word] = 1
    
    sorted_count_by_freq = sorted(count.items(), key=lambda kv: kv[1], reverse=True)

    vocabulary = [x[0] for x in sorted_count_by_freq[:vocab_len]]
    return vocabulary

# %%
vocab_freq = create_vocabulary_frequency(documents, 1000)

# %%
vocab_freq
# Out:
# ['epfl',
#  'epflen',
#  'via',
#  'new',
#  'lausanne',
#  'switzerland',
#  'vdtech',
#  'research',
#  'swiss',
#  'science',
#  'students',
#  'innovation',
#  'first',
#  'martinvetterli',
#  'day',
#  'solar',
#  'great',
#  'open',
#  'unil',
#  'data',
#  'technology',
#  'learning',
#  'thanks',
#  'ethen',
#  'work',
#  'prof',
#  'today',
#  'startup',
#  'talk',
#  'see',
#  'days',
#  'next',
#  'congrats',
#  'one',
#  'good',
#  'suisse',
#  'researchers',
#  'campus',
#  'center',
#  'time',
#  'eth',
#  'energy',
#  'robots',
#  'join',
#  'us',
#  'epflcampus',
#  'cc',
#  'made',
#  'lab',
#  'dgtswitzerland',
#  'world',
#  'brain',
#  'robot',
#  'looking',
#  'meeting',
#  'people',
#  'drone',
#  'get',
#  'future',
#  'human',
#  'mooc',
#  'perovskite',
#  'could',
#  'epflenac',
#  'free',
#  'robotics',
#  'event',
#  'marcelsalathe',
#  'conference',
#  'proud',
#  'light',
#  'workshop',
#  'forward',
#  'week',
#  'school',
#  'der',
#  'president',
#  'universities',
#  'design',
#  'read',
#  'im',
#  'university',
#  'scientists',
#  'watch',
#  'cours',
#  'team',
#  'article',
#  'last',
#  'top',
#  'take',
#  'exciting',
#  'machine',
#  'best',
#  'start',
#  'excited',
#  'tomorrow',
#  'even',
#  'international',
#  'find',
#  'machinelearning',
#  'tech',
#  'epflevents',
#  'place',
#  'merci',
#  'working',
#  'oscience',
#  'für',
#  'cells',
#  'w',
#  'come',
#  'digital',
#  'award',
#  'datascience',
#  'part',
#  'architecture',
#  'paper',
#  'available',
#  'étudiants',
#  'video',
#  'years',
#  'und',
#  'congratulations',
#  'latest',
#  'cancer',
#  'projet',
#  'possible',
#  'two',
#  'mars',
#  'also',
#  'appliedmldays',
#  'smart',
#  'unigenews',
#  'quantum',
#  'drones',
#  'von',
#  'participants',
#  'really',
#  'help',
#  'professor',
#  'walk',
#  'happy',
#  'water',
#  'meet',
#  'swisscytometry',
#  'way',
#  'system',
#  'many',
#  'says',
#  'education',
#  'jacques',
#  'using',
#  'understand',
#  'zu',
#  'go',
#  'opportunity',
#  'activity',
#  'conférence',
#  'youtube',
#  'bien',
#  'global',
#  'study',
#  'show',
#  'formation',
#  'trust',
#  'nice',
#  'group',
#  'lecture',
#  'applied',
#  'ml',
#  'cseminfo',
#  'faire',
#  'façade',
#  'programme',
#  'program',
#  'think',
#  'need',
#  'artificial',
#  'engineering',
#  'like',
#  'unifr',
#  'cool',
#  'tool',
#  'vr',
#  'director',
#  'zurich',
#  'public',
#  'developed',
#  'topic',
#  'space',
#  'eucommission',
#  'impact',
#  'french',
#  'largest',
#  'clean',
#  'presenting',
#  'étudiant',
#  'cest',
#  'night',
#  'apply',
#  'startups',
#  'look',
#  'sdscdatascience',
#  'internet',
#  'year',
#  'cell',
#  'virtual',
#  'mieux',
#  'improve',
#  'rolex',
#  'comment',
#  'epflpark',
#  'deadline',
#  'recherche',
#  'fantastic',
#  'guide',
#  'aihealth',
#  'march',
#  'sv',
#  'disease',
#  'epflsv',
#  'phd',
#  'biology',
#  'development',
#  'house',
#  'dubochet',
#  'france',
#  'launch',
#  'less',
#  'discussion',
#  'potential',
#  'interview',
#  'plus',
#  'make',
#  'openscience',
#  'online',
#  'edtech',
#  'rolexlearningcenter',
#  'access',
#  'dark',
#  'venturelabch',
#  'library',
#  'dont',
#  'register',
#  'lead',
#  'neige',
#  'copenhagen',
#  'green',
#  'novel',
#  'das',
#  'weekend',
#  'single',
#  'noir',
#  'ever',
#  'master',
#  'numérique',
#  'learn',
#  'real',
#  'genève',
#  'robotic',
#  'young',
#  'model',
#  'dun',
#  'chuvlausanne',
#  'après',
#  'want',
#  'based',
#  'present',
#  'airbnb',
#  'ça',
#  'experience',
#  'competition',
#  'efficiency',
#  'thesis',
#  'high',
#  'blue',
#  'business',
#  'funding',
#  'hesso',
#  'jai',
#  'brjsa',
#  'centre',
#  'nouveau',
#  'thymioii',
#  'would',
#  'agepoly',
#  'million',
#  'inside',
#  'sciences',
#  'final',
#  'materials',
#  'deeplearning',
#  'nobelprize',
#  'winner',
#  'valais',
#  'film',
#  'nature',
#  'uzhnews',
#  'sxswiss',
#  'federal',
#  'institutes',
#  'welcome',
#  'forumepfl',
#  'support',
#  'zotero',
#  'intelligence',
#  'livre',
#  'towards',
#  'society',
#  'rt',
#  'offers',
#  'understanding',
#  'poster',
#  'workshops',
#  'luck',
#  'neuroscience',
#  'quality',
#  'successful',
#  'cytometry',
#  'polytechnique',
#  'systems',
#  'strong',
#  'among',
#  'still',
#  'security',
#  'information',
#  'matter',
#  'generation',
#  'apprendre',
#  'champsnight',
#  'police',
#  'love',
#  'technologies',
#  'hessovalais',
#  'stop',
#  'alzheimers',
#  'ceremony',
#  'mission',
#  'become',
#  'innovaud',
#  'santé',
#  'avalanche',
#  'full',
#  'snow',
#  'danish',
#  'installs',
#  'food',
#  'course',
#  'bigdata',
#  'level',
#  'chemistry',
#  'collaboration',
#  'frederickaplan',
#  'die',
#  'ready',
#  'colleagues',
#  'art',
#  'swissnexsf',
#  'session',
#  'tour',
#  'code',
#  'analysis',
#  'leurs',
#  'thank',
#  'mobility',
#  'cybersecurityday',
#  'impressive',
#  'well',
#  'immune',
#  'excellent',
#  'back',
#  'visit',
#  'études',
#  'making',
#  'projets',
#  'sure',
#  'applications',
#  'villes',
#  'epfllibrary',
#  'save',
#  'date',
#  'site',
#  'monde',
#  'reality',
#  'venture',
#  'former',
#  'power',
#  'market',
#  'nrel',
#  'record',
#  'hackathon',
#  'sign',
#  'projects',
#  'talking',
#  'old',
#  'done',
#  'al',
#  'develop',
#  'control',
#  'openfood',
#  'uzhnewsen',
#  'discover',
#  'edacyhq',
#  'invest',
#  'important',
#  'travail',
#  'si',
#  'quand',
#  'wef',
#  'attend',
#  'laboratory',
#  'fmondada',
#  'swsx',
#  'moocs',
#  'traces',
#  'martian',
#  'biological',
#  'meteorite',
#  'bravo',
#  'long',
#  'geneva',
#  'takes',
#  'health',
#  'life',
#  'early',
#  'april',
#  'main',
#  'city',
#  'aujourdhui',
#  'demain',
#  'epfls',
#  'areas',
#  'vaud',
#  'mechanics',
#  'wave',
#  'particle',
#  'lepfl',
#  'sich',
#  'chf',
#  'interaction',
#  'highlights',
#  'student',
#  'rlerignier',
#  'norme',
#  'tous',
#  'indeed',
#  'tumuenchen',
#  'hand',
#  'tuned',
#  'speakers',
#  'deep',
#  'psf',
#  'algorithms',
#  'digitalhealth',
#  'exposition',
#  'play',
#  'spinoff',
#  'know',
#  'rrl',
#  'dr',
#  'michael',
#  'panel',
#  'point',
#  'solutions',
#  'without',
#  'nanostructures',
#  'use',
#  'timeshighered',
#  'opportunities',
#  'inspired',
#  'wikipedia',
#  'studies',
#  'danger',
#  'slf',
#  'innovative',
#  'challenge',
#  'ia',
#  'eawagresearch',
#  'bibliotheque',
#  'très',
#  'aging',
#  'mit',
#  'alumni',
#  'unigeen',
#  'stem',
#  'much',
#  'sneedition',
#  'iso',
#  'february',
#  'cern',
#  'eurekalert',
#  'music',
#  'call',
#  'starts',
#  'intel',
#  'lets',
#  'privacy',
#  'lieu',
#  'info',
#  'page',
#  'fish',
#  'optical',
#  'may',
#  'amazing',
#  'europe',
#  'prize',
#  'bacterial',
#  'around',
#  'social',
#  'nberpubs',
#  'letemps',
#  'check',
#  'lesoepfl',
#  'club',
#  'scicomm',
#  'entre',
#  'happening',
#  'give',
#  'software',
#  'big',
#  'building',
#  'going',
#  'modeling',
#  'method',
#  'cet',
#  'january',
#  'soft',
#  'lake',
#  'dna',
#  'nccrrobotics',
#  'premier',
#  'network',
#  'achieve',
#  'sustainability',
#  'exosquelette',
#  'created',
#  'published',
#  'swisstechepfl',
#  'tonight',
#  'host',
#  'book',
#  'question',
#  'nexus',
#  'opensource',
#  'datadriven',
#  'girls',
#  'wslresearch',
#  'entrepreneurship',
#  'jobs',
#  'ask',
#  'speaking',
#  'silicon',
#  'prix',
#  'heart',
#  'epflartlab',
#  'man',
#  'opendata',
#  'computer',
#  'edacy',
#  'digitaltrust',
#  'ethrat',
#  'atelier',
#  'etc',
#  'ligne',
#  'keep',
#  'hosted',
#  'live',
#  'engineers',
#  'interesting',
#  'blockchain',
#  'fintech',
#  'robotique',
#  'humans',
#  'media',
#  'experts',
#  'mind',
#  'institute',
#  'symposium',
#  'summer',
#  'complexes',
#  'computational',
#  'presents',
#  'plenty',
#  'presented',
#  'missing',
#  'mobile',
#  'window',
#  'monitoring',
#  'process',
#  'début',
#  'septembre',
#  'ein',
#  'effyvayena',
#  'sxsw',
#  'aussi',
#  'solaire',
#  'thing',
#  'another',
#  'else',
#  'offer',
#  'pratique',
#  'csl',
#  'enjeux',
#  'artificielle',
#  'iot',
#  'découvrez',
#  'industrial',
#  'davos',
#  'interactions',
#  'transportation',
#  'alahi',
#  'travers',
#  'sans',
#  'policy',
#  'according',
#  'tueindhoven',
#  'used',
#  'naturecomms',
#  'super',
#  'stay',
#  'violainesee',
#  'cciliv',
#  'images',
#  'test',
#  'sécurité',
#  'able',
#  'medtech',
#  'p',
#  'measuring',
#  'swissedtechcollider',
#  'line',
#  'lives',
#  'mal',
#  'ecole',
#  'fédérale',
#  'feb',
#  'operations',
#  'size',
#  'virtualreality',
#  'environments',
#  'natural',
#  'bad',
#  'ist',
#  'partners',
#  'yunus',
#  'makes',
#  'darker',
#  'thought',
#  'darkmatter',
#  'hubble',
#  'astronomy',
#  'presentation',
#  'hopitauxunige',
#  'training',
#  'storage',
#  'professeur',
#  'besoin',
#  'population',
#  'uefa',
#  'healthy',
#  'mitochondria',
#  'someone',
#  'concept',
#  'travel',
#  'thomas',
#  'claude',
#  'nicollier',
#  'european',
#  'dsmeu',
#  'factory',
#  'masschallengech',
#  'japan',
#  'rts',
#  'envirobot',
#  'ainsi',
#  'snowscience',
#  'sensors',
#  'medicine',
#  'proteins',
#  'series',
#  'waste',
#  'encore',
#  'alpine',
#  'extreme',
#  'portable',
#  'artlab',
#  'pierresoulages',
#  'points',
#  'different',
#  'bci',
#  'awards',
#  'champions',
#  'directeur',
#  'dune',
#  'humaines',
#  'measurements',
#  'tip',
#  'imaging',
#  'espace',
#  'avant',
#  'édition',
#  'avril',
#  'comes',
#  'travaux',
#  'stanford',
#  'spy',
#  'bbc',
#  'technologisteu',
#  'dhums',
#  'carlo',
#  'sept',
#  'review',
#  'sustainable',
#  'fast',
#  'espdakar',
#  'verge',
#  'datajamdays',
#  'ar',
#  'venez',
#  'patrimoine',
#  'reportage',
#  'français',
#  'months',
#  'techcrunch',
#  'lereseau',
#  'try',
#  'proposé',
#  'field',
#  'oui',
#  'chimie',
#  'isbsib',
#  'thursday',
#  'inscription',
#  'temps',
#  'resistance',
#  'microscopy',
#  'startuptickerch',
#  'discuss',
#  'artificialintelligence',
#  'itfaconference',
#  'v',
#  'behind',
#  'approach',
#  'matin',
#  'currently',
#  'wish',
#  'über',
#  'sharing',
#  'scala',
#  'grätzel',
#  'practical',
#  'specialist',
#  'academia',
#  'three',
#  'times',
#  'behavior',
#  'concours',
#  'epflmaurice',
#  'mauricelibrarysecurity',
#  'additive',
#  'photograph',
#  'birthday',
#  'vusurlecampus',
#  'active',
#  'shared',
#  'abstract',
#  'submission',
#  'touch',
#  'jmlattes',
#  'regisgodec',
#  'autatetoulouse',
#  'type',
#  'probably',
#  'harvardmed',
#  'museomix',
#  'candidatures',
#  'winter',
#  'improves',
#  'chromatin',
#  'digitalday',
#  'programmation',
#  'classe',
#  'drivers',
#  'kickoff',
#  'pm',
#  'graphene',
#  'create',
#  'truly',
#  'anton',
#  'schleiss',
#  'jours',
#  'deux',
#  'promising',
#  'modular',
#  'origami',
#  'ieee',
#  'received',
#  'suivre',
#  'looks',
#  'awesome',
#  'places',
#  'reconstruction',
#  'juridiques',
#  'rehabilitation',
#  'registration',
#  'built',
#  'species',
#  'ones',
#  'paris',
#  'set',
#  'aceexpedition',
#  'ethz',
#  'weeks',
#  'seed',
#  'industry',
#  'opening',
#  'job',
#  'stratocore',
#  'geomechaepfl',
#  'geteschool',
#  'management',
#  'cloud',
#  'lors',
#  'opticalfiber',
#  'succès',
#  'martin',
#  'vetterli',
#  'app',
#  'aus',
#  'opendatach',
#  'christmas',
#  'together',
#  'featuring',
#  'value',
#  'camp',
#  'bring',
#  'case',
#  'skills',
#  'e',
#  'swissedtech',
#  'feedback',
#  'enhances',
#  'brainwave',
#  'handexoskeleton',
#  'september',
#  'assist',
#  'patrick',
#  'aebischer',
#  'soir',
#  'repair',
#  'tissue',
#  'pain',
#  'gamayanews',
#  'break',
#  'pump',
#  'références',
#  'filles',
#  'highway',
#  'dindin',
#  'starting',
#  'unique',
#  'humanitarian',
#  'progress',
#  'getting',
#  'soon',
#  'jchenal',
#  'tdgch',
#  'focusonline',
#  'bild',
#  'regierungbw',
#  'cdu',
#  'gruenebundestag',
#  'thomasoppermann',
#  'gruenebw',
#  'europarlen',
#  'thats',
#  'pitch',
#  'news',
#  'patterns',
#  'transform',
#  'furniture',
#  'kamiahok',
#  'microsoft',
#  'bradsmi',
#  'ebugnion',
#  'geneve',
#  'donc',
#  'cette',
#  'archives',
#  'members',
#  'including',
#  'scientific',
#  'reveals',
#  'aviation',
#  'zhaw',
#  'facebook',
#  'versatile',
#  'countries',
#  'cltucci',
#  'présentation',
#  'registered',
#  'matière',
#  'stress',
#  'cyclometalated',
#  'ruthenium',
#  'directly',
#  'leader',
#  'giving',
#  'kicking',
#  'tutorial',
#  'timeseries',
#  'identified',
#  'gene',
#  'heclausanne',
#  'trois',
#  'étudier',
#  'observed',
#  'weather',
#  'antarctica',
#  'ict',
#  'conf',
#  'platforms',
#  'capitale',
#  'kuka',
#  'setzt',
#  'trusting',
#  'asks',
#  'sait',
#  'etatdevaud',
#  'national',
#  'dynamics',
#  'mechanisms',
#  'transformtech',
#  'imd',
#  'mrhiura',
#  'avoid',
#  'everyone',
#  'board',
#  'gender',
#  'strategy',
#  'childcare',
#  'trekkinglemon',
#  'lextensoetudian',
#  'fait',
#  'swisscom',
#  'défis',
#  'tout',
#  'citation',
#  'produce',
#  'dtsbourg',
#  'informed',
#  'nucleosomes',
#  'micro',
#  'histone',
#  'dynamic',
#  'jan',
#  'talks',
#  'small',
#  'existing',
#  'revolutionize',
#  'lire',
#  'louvrir',
#  'secret',
#  'archimagredac',
#  'challenges',
#  'r',
#  'dtutweet',
#  'leukemia',
#  'clearer',
#  'woop',
#  'covestrogroup',
#  'imdeanano',
#  'ujinoticias',
#  'imperialcollege',
#  'irem',
#  'winning',
#  'hot',
#  'geothermal',
#  'scireports',
#  'chance',
#  'deconvolution',
#  'deconvolutionlab',
#  'results',
#  'act',
#  'selfsufficient',
#  'home',
#  'panels',
#  'solardecathlon',
#  'advanced',
#  'ht',
#  'surface',
#  'nano',
#  'ex',
#  'member',
#  'discovery',
#  'century',
#  'jet',
#  'lag',
#  'chiccommunity',
#  'eye',
#  'architect']

# %% [markdown]
# ### 1.3. Construct the term document matrix
# In this question, you need to construct the term document matrix given the vocabulary and the set of documents.
# The value of a cell (i, j) is the term frequency of the term i in document j.

# %%
def construct_term_document_matrix(vocabulary, documents):
    # Construct term-doc matrix
    matrix = np.zeros((len(vocabulary), len(documents)))
    for j, document in enumerate(documents):
        counter = Counter(document.split())
        for i, word in enumerate(vocabulary):
            if word in counter:
                matrix[i,j] = counter[word]
    return matrix

# %%
term_doc_matrix_freq = construct_term_document_matrix(vocab_freq, documents)

# %% [markdown]
# ### 1.4. Perform LSI by selecting the first 100 largest singular values of the term document matrix
# Hint 1: np.linalg.svd(M, full_matrices=False) performs SVD on the matrix $\mathbf{M}$ and returns $\mathbf{K}, \mathbf{S}, \mathbf{D}^T$
#
#  -  $\mathbf{K}, \mathbf{D}^T$ are matrices with orthonormal columns
#  -  $\mathbf{S}$ is a **vector** of singular values in a **descending** order
#
# Hint 2: np.diag(V) converts a vector to a diagonal matrix
#
# Hint 3: To select
#  - The first k rows of a matrix A, use A[0:k, :]
#  - The first k columns of a matrix A, use A[:, 0:k]
#  - The submatrix from first k rows and k columns of a matrix A, use A[0:k, 0:k]

# %%
def truncated_svd(term_doc_matrix, num_val):
    K, S, Dt = np.linalg.svd(term_doc_matrix, full_matrices=False)
    K_sel = K[:,0:num_val]
    S_sel = np.diag(S)[0:num_val,0:num_val]
    Dt_sel = Dt[0:num_val,:]
    return K_sel, S_sel, Dt_sel

# %%
K_freq, S_freq, Dt_freq = truncated_svd(term_doc_matrix_freq,100)

# %% [markdown]
# ### 1.5. Transform the given query
# In this question, you need to construct a vector representation for the following query:

# %%
query = ['epfl']

# %%
def query_to_document_vector(query, vocabulary):
    vector = np.zeros(len(vocabulary))
    for word in query:
        try:
            vector[vocabulary.index(word)] += 1
        except: # if query word is not in vocabulary
            # ignore it
            pass
    return vector

# %% [markdown]
# Hint:
#  -  To compute inverse of a matrix M, use np.linalg.inv(M)
#  -  To compute the dot product of A, B, use np.dot(A,B)

# %%
def construct_query_vector(query, vocabulary, K_sel, S_sel):
    q = query_to_document_vector(query, vocabulary)
    mapper = np.dot(K_sel, np.linalg.inv(S_sel))
    q_trans =  np.dot( q, mapper)
    return q_trans

# %%
query_vector_freq = construct_query_vector(query, vocab_freq, K_freq, S_freq)

# %% [markdown]
# ### 1.6. Retrieve top-10 relevant documents
# In this question, you need to retrieve the top-10 documents that are relevant to the query using cosine similarity. You are given a function to compute the cosine simimlarity and a function that return the top-k documents given the query and document vectors.

# %%
def cosine_similarity(v1, v2):
    sumxx, sumxy, sumyy = 0, 0, 0
    for i in range(len(v1)):
        x = v1[i]; y = v2[i]
        sumxx += x*x
        sumyy += y*y
        sumxy += x*y
    return sumxy*1.0/math.sqrt(sumxx*sumyy)

# %%
def retrieve_documents(query_vector, top_k, Dt_sel):
    scores = [[cosine_similarity(query_vector, Dt_sel[:,d]), d] for d in range(len(documents))]
    scores.sort(key=lambda x: -x[0])
    doc_ids = []
    retrieved = []
    for i in range(top_k):
        doc_ids.append(scores[i][1])
        retrieved.append(orig_docs[scores[i][1]])
    return doc_ids, retrieved

# %%
retrieved_ids_freq, retrieved_docs_freq = retrieve_documents(query_vector_freq, 10, Dt_freq)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars

# %%
pprint(retrieved_docs_freq)
# Out:
# ['Environnement, un marché en pleine croissance https://t.co/ThTcYLrMtn Avec '
#  'Philippe Thalmann @EPFL\n',
#  'signé @EPFL https://t.co/sRldB2O7PM\n',
#  'Chocolate &amp; berries #vegan cheesecake for my @EPFL coworkers! ✌🏽🌱 '
#  '#veganfood #EPFLfood https://t.co/wPlLsIt0KD\n',
#  "L'app pour «liker» en direct les transports publics https://t.co/3HbkTnIE3Q "
#  '#epfl\n',
#  "L'électrochimie débusque les protéines résistantes aux antibiotiques "
#  'https://t.co/BHlj5WHMbC Avec Hubert Girault @EPFL\n',
#  '#ff @Kikohs and his beautiful artworks. Some of them are displayed at @EPFL '
#  'and featured on ZettaBytes! https://t.co/8F4BNL7aAs\n',
#  'Ca court, ca court à #carandache #epfl #wwim15 #wwim15_igerslausanne '
#  'https://t.co/0bNMBPx50k\n',
#  'Femmes en politique, pour en finir avec les seconds rôles '
#  'https://t.co/IgIkg8yrxy #epfl\n',
#  'Le camion Cargo Congo du @theatredevidy est sur la #PlaceCosandey- ne '
#  'manquez pas de venir découvrir ce spectacle de 10 mins jusqu’à 14h puis à '
#  '16h @EPFL https://t.co/D2JZztA3Ca\n',
#  "Bras de fer autour de la taxe d’études de l'#EPFL https://t.co/pr7GBU3f04\n"]

# %% [markdown]
# ## Part2: Evaluation
# In this question, we consider the scikit reference code as an “oracle” that supposedly gives the correct result. You need to compare your retrieval results with this oracle using the F1-score.

# %%
# Retrieval oracle 
tf = TfidfVectorizer(analyzer='word', ngram_range=(1,1), vocabulary=vocab_freq, min_df = 1, stop_words = 'english')
features = tf.fit_transform(documents)
npm_tfidf = features.todense()

# Return all document ids that that have cosine similarity with the query larger than a threshold
def search_vec_sklearn(query, features, threshold=0.3):
    new_features = tf.transform([query])
    cosine_similarities = linear_kernel(new_features, features).flatten()
    related_docs_indices, cos_sim_sorted = zip(*sorted(enumerate(cosine_similarities), key=itemgetter(1), 
                                                       reverse=True))
    doc_ids = []
    for i, cos_sim in enumerate(cos_sim_sorted):
        if cos_sim < threshold:
            break
        doc_ids.append(related_docs_indices[i])
    return doc_ids

# %%
gt_ids = search_vec_sklearn(" ".join(query), features)

# %%
for i in gt_ids:
    print(orig_docs[i].strip())
# Out:
# @EPFL Retrouvez votre 1er tweet sélectionné par L'important https://t.co/B2tCt924Cp
# Environnement, un marché en pleine croissance https://t.co/ThTcYLrMtn Avec Philippe Thalmann @EPFL
# Belle leçon de technologie dans @RTScqfd avec l'exosquelette @twiice_official testé par Silke Pan. https://t.co/4uIdXckvaq #RTScqfd #EPFL
# Chocolate &amp; berries #vegan cheesecake for my @EPFL coworkers! ✌🏽🌱 #veganfood #EPFLfood https://t.co/wPlLsIt0KD
# L'app pour «liker» en direct les transports publics https://t.co/3HbkTnIE3Q #epfl
# I see you @EPFL ! https://t.co/BxrHPaMqlX
# #Walking on two #legs isn’t as easy as it seems... @EPFL  https://t.co/Af6Shy2CvV https://t.co/ecz2M8Znl4
# signé @EPFL https://t.co/sRldB2O7PM
# L'électrochimie débusque les protéines résistantes aux antibiotiques https://t.co/BHlj5WHMbC Avec Hubert Girault @EPFL
# #ff @Kikohs and his beautiful artworks. Some of them are displayed at @EPFL and featured on ZettaBytes! https://t.co/8F4BNL7aAs
# Ca court, ca court à #carandache #epfl #wwim15 #wwim15_igerslausanne https://t.co/0bNMBPx50k
# Femmes en politique, pour en finir avec les seconds rôles https://t.co/IgIkg8yrxy #epfl
# Le camion Cargo Congo du @theatredevidy est sur la #PlaceCosandey- ne manquez pas de venir découvrir ce spectacle de 10 mins jusqu’à 14h puis à 16h @EPFL https://t.co/D2JZztA3Ca
# Un Plan de mobilité « Made in EPFL » https://t.co/efcVQ215Nh #epfl
# Des #microchips optimisent les «codes polaires» essentiels à la #5G https://t.co/FS7tDPBFsP @epfl
# Attention aux emails frauduleux https://t.co/Mjlq4D3RWM #epfl
# Des nichoirs digitaux pour observer les chouettes https://t.co/iPc3bFDrsL Avec Marion Curdy @EPFL
# #Melenchon passe 2eme dans l'outils d'analyse des #reseauxsociaux de @SwissquoteNews @EPFL  https://t.co/gQk1H9bPlR #Presidentielle2017 https://t.co/qFNRPQE4t2
# Les #GAFA sont-ils devenus trop puissants? https://t.co/9F9q98oXPE Avec Charles Wyplosz @IHEID et Denis Gillet @EPFL
# But what a woman! @samsam_86 #EPFL   https://t.co/hM1ccY2plN
# L'histoire de l'Académie racontée par #Jean-ClaudeBadoux, seul président romand de la SATW jusqu'à présent: https://t.co/yRkOycBSle @EPFL https://t.co/ZZXZHasdjN
# Que reste-t-il de lʹesprit des squats des années 1980?  https://t.co/m80VlQSkfQ Avec Luca Pattaroni @EPFL
# EPFL morning #epfl #lausanne #photography https://t.co/6IXddicblu
# PostCarWorld | EPFL https://t.co/KfFQRJrQVb #epfl #epflcampus
# Bluebrain | EPFL https://t.co/Y2S3hz1817 #epfl #epflcampus
# Six EPFL startups are among the Swiss top 10 https://t.co/Re0xB2VBZ0 #epfl
# EPFL students get hands-on experience with “Made in China” https://t.co/DKgMXia7tQ #epfl
# Spaceship #epfl #lausanne https://t.co/Lb223yT804
# L'électrochimie débusque les protéines résistantes aux antibiotiques via @EPFL #VDtech https://t.co/r9bSbXeLCB
# Waiting for the ceremony to start! #epflalumnigala #epfl  @epfl https://t.co/ucZjZmNfYF
# Deprivation: a decisive factor in genetic predisposition to #obesity a study @EPFL @CHUVLausanne https://t.co/epvU8vlA0c #epfl #publichealth https://t.co/jW8sWVTLTQ
# Nicolas Mounet from EPFL @EPFL talking about two-dimensional materials and high-throughput calculations at #MaXConf2018 in Trieste @aiidateam @nccr_marvel https://t.co/qGyOt0yVZn
# Drone Days | EPFL https://t.co/ZdNwhb0EzL #epfl #epflcampus
# Le mystère Soulages éblouit la science @EPFL  https://t.co/u3uNICyAdi
# Functional programming in @scala_lang @epfl first day https://t.co/HTryOqhYq7

# %% [markdown]
# ### 2.1. Compute F1-score at 10 between the oracle and your result

# %%
def compute_recall_at_k(predict, gt, k):
    correct_recall = set(predict[:k]).intersection(set(gt))
    return len(correct_recall)/len(gt)

# %%
def compute_precision_at_k(predict, gt, k):
    correct_predict = set(predict[:k]).intersection(set(gt))
    return len(correct_predict)/k

# %%
def f1score(predict, gt, k):
    prec = compute_precision_at_k(predict, gt, k)
    rec = compute_recall_at_k(predict, gt, k)
    print(prec, rec)
    return 2*prec*rec/(prec+rec)

# %%
f1score(retrieved_ids_freq, gt_ids, 10)
# Out:
# 0.9 0.2571428571428571
# 0.39999999999999997

# %% [markdown]
# ## Part3. Visualization
# Plot the terms using two principal concepts

# %% [markdown]
# ### 3.1. Compute the term vectors using two principal concepts
# Hint: you can reuse a method from the above

# %%
term_vecs_freq, _, _ = truncated_svd(term_doc_matrix_freq,2)

# %%
term_vecs_freq.shape
# Out:
# (1000, 2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import *

# %% [markdown]
# Hint: You can use plt.scatter(x, y) for a scatter plot. x is a vector of x-axis value and y is a vector of y-axis value

# %%
plt.scatter(term_vecs_freq[:, 0], term_vecs_freq[:, 1])
for i, t in enumerate(vocab_freq):
    plt.annotate(t, (term_vecs_freq[i, 0], term_vecs_freq[i, 1]))
plt.show()

# %% [markdown]
# ### 3.2. Explain the scatter plot of the term vectors

# %% [markdown]
# epfl and epflen are two Twitter handles of EPFL which explains why the two principal concepts are mainly made up of these terms.
