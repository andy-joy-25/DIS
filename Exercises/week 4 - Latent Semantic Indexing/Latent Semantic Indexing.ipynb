# %% [markdown]
# ## 📚 Exercise: Latent Semantic Indexing
# In this exercise we would learn about Latent Semantic Indexing (LSI) based retrieval models.
#
# ### Goal:
# - Implement a search engine using LSI
# - Visualize the LSI concepts
# - Compare the retrieval results with scikit vector space retrieval method (as an oracle)
#
# ### What you are learning in this exercise:
# 1. Learn more about LSI approach
# 2. How retrieval results can be different in LSI and vector space retrieval models

# %% [markdown]
# ## Part1: Implement Latent Semantic Indexing (LSI)
# ### 1.1 Read the corpus data

# %%
#Required libraries

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import math
from nltk.stem import PorterStemmer, WordNetLemmatizer
import os
import string
import numpy as np
from collections import Counter
from nltk.tokenize import word_tokenize, TweetTokenizer
from nltk.corpus import stopwords
from collections import Counter
from operator import itemgetter
from pprint import pprint
import nltk
import matplotlib.pyplot as plt
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english')).union(set(stopwords.words('french')))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/anandchoudhary/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anandchoudhary/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def read_corpus():
    '''Reads corpus from files.'''
    
    documents = []
    orig_docs = []
    DIR = './'
    tknzr = TweetTokenizer()
    with open("epfldocs.txt", encoding = "utf-8") as f:
        content = f.readlines()
    for text in content:
        orig_docs.append(text)
        # split into words
        tokens = tknzr.tokenize(text)
        # convert to lower case
        tokens = [w.lower() for w in tokens]
        # remove punctuation from each word
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove remaining tokens that are not alphabetic
        words = [word for word in stripped if word.isalpha()]
        # filter out stop words
        words = [w for w in words if not w in stop_words]

        documents.append(' '.join(words))
    return documents, orig_docs

# %%
documents, orig_docs = read_corpus()

# %%
assert(len(documents) == 1075)

# %%
documents
# Out:
# ['congrats ethen place epflen place',
#  'thats standing ovation epflen',
#  'time open farms pitch openfood opendata epfl',
#  'good opportunity ethen epflen epflpark uzhnewsen',
#  'exciting news world university rankings subject computer science eth epfl congrats httpstcoarslxzoshq',
#  'epfl cryptotokenize free energy httpstcozyenraseir get rich',
#  'scientists discover hidden patterns brain activity httpstcohblrytdmtt epfl',
#  'edacyhq edacy invest',
#  'deadline breast cancer research funding epfl againstbc',
#  'robots transform furniture epfl november kamiahok',
#  'microsoft president bradsmi epfl ebugnion digitalgenevaconvention digitaltrust important topics ethrat epflen',
#  'atelier travail future traversée rade geneve cantongeneve epfl hslu etc hesso hei hepia heiafr',
#  'formidable fan projet time machine donc possible revoir conférence chaîne youtube si jai bien lu précédents commentaires merci signaler quand cette dernière ligne archives numerique',
#  'members wef global university leaders forum including switzerlands ethen epflen responsible large proportion world scientific publications new study reveals',
#  'switzerland working hard keep best brjsa robotics srindustryday',
#  'free yoga event hosted indian students epfl lausanne ambassador gill cdmissionindia attend unil myswitzerlandf epflen httpstcoxnciwuqcxw',
#  'aviation suisse désormais centre recherche aéronautique zhaw hsgstgallen epfl via swissinfofr',
#  'scirobotics live facebook watch epflen engineers show versatile vacuumpowered robots',
#  'countries switzerland interesting laboratory epfl',
#  'fantastic explanation blockchain blockchain fintech startup epflen swissborg cltucci',
#  'présentation nouveau guide robotique éducation cours formation thymioii hep fmondada epfl',
#  'would trust doctor human one marcelsalathe epflen listens humans compete aihealth swsx',
#  'nice animation fourthrevolution luciano floridi uniofoxford agepoly epflen epfl',
#  'epfl moocs two million registered users switzerland',
#  'traces possible martian biological activity inside meteorite oscience epflen mars',
#  'ehre für schweizer vmwaremitgründer ebugnion herzliche gratulation epfl',
#  'etre bien positionné départ clef merci bravo epfl ménage efforts matière contribuant prospérité compétitivité modernité pays long terme',
#  'join mediaroad team talk media innovation experts march geneva upcoming event organized epfl takes fakenews socialmedia data',
#  'epfl sv bms brain mind institute symposium summer stress health disease switzerland',
#  'cyclometalated ruthenium complexes dyesensitized solar cells epfl',
#  'new epflen life sciences epflsv phd directly independent group leader elfirepfl early independence research scholars see also computational biology compbio deadline april httpstcomjqcrfiqkb',
#  'ecorobotix presents development weeding robot epfl start conference epfl',
#  'douglas hanahan isrec epfl giving final closing lecture microenvironmental determinants invasion metastasts lornecancer cancer metastasis nottheashleydunnoration',
#  'applied machine learning days main event kicking epfl practitioners house cisco proud sponsor',
#  'ml tutorial timeseries sequence data apachemxnet gluon plenty introductory materials deeplearning timeseries presented appliedmldays epfl',
#  'sestrin identified epflen researchers gene frequently missing mutated follicular lymphoma',
#  'colorselective versatile light steering w upscalable subwavelength planar optics cseminfo epflen',
#  'mobile crowdsourcing epflen campus',
#  'paulg come epflen hardworking students',
#  'march geneve smart city aujourdhui demain unigenews siggeneve epflen secheronsa plrge',
#  'jimharris epfls campus worlds first solar window epfl',
#  'enroll free epflen iucn mooc ecological monitoring essential protected areas ecology',
#  'celebrating nobelprize winner jaques dubochet unil lausanne vaud proud heclausanne epfl',
#  'epfl valais bourse trois millions étudier avc switzerland',
#  'possible film quantum mechanics paradoxical nature directly light photographed wave particle first time via epflen epfl',
#  'researchers observed weather process previously known occur antarctica via epflen',
#  'ict conf lausanne join us ict rural circular digital platforms epfl epflcampus',
#  'lepfl capitale drones début septembre epfl',
#  'hannover messe mechatronik greifbar messestand von kukaroboticsde manchu epflen kuka innovation award',
#  'martinvetterli epfl setzt sich für open science ein wissen teilen für mehr wirkung',
#  'marcelsalathe epflen personify deceiving trusting effyvayena uzhnews asks aihealth sxsw sxswiss',
#  'aussi sait faire france façade solaire',
#  'switzerland brjsa unil epfl swisssporttv remnantnews httpstcofhtmlunack etatdevaud communelausanne',
#  'congrats sensima inspection granted chf million loan sgs vdtech cc epflen httpstcogbdmfiztsk',
#  'swiss federal institutes technology ethen epflen open national center datascience',
#  'aziz heddi dynamics mechanisms weevilsodalis interaction lifespan highlights continuum symbionthost interaction',
#  'bienvenue arielle mahamadou eddy mactar cohorte programme edacyhq débutent stage aujourdhui',
#  'launch imdepfl transformtech program welcome participants martinvetterli epfl imd',
#  'mrhiura marcelsalathe epflen forumepfl one thing censor another avoid promoting agenda tbh student really confusing',
#  'effyvayena eth everyone else epfl',
#  'eth board releases new gender strategy applied machine learning days excited offer childcare help support epfl trekkinglemon martinvetterli',
#  'rlerignier epfl norme théorique pratique si lextensoetudian fait csl zotero norme proprio prendrai',
#  'connected event sconnecte epfl urs lehner swisscom défis enjeux intelligence artificielle considérables vdtech',
#  'bravo tous membres think tank iot tout travail fourni découvrez livre restitution citation didier mesnier secrétaire exécutif micronarc cseminfo hesso epfl',
#  'less universities produce research entire industrial nations proud epflen ethen part gulf group ethrat epfl davos',
#  'dtsbourg mrhiura marcelsalathe epflen forumepfl confusion epflen indeed clear responsibility towards swiss society need informed hear various voices need provide input debates',
#  'nucleosomes engage shortlived micro milliseconds stacking interactions one neighbors tetranucleosome units engages methylated histone tails thereby transiently stabilizes stacked nucleosomes compacted state nevertheless remains dynamic',
#  'traces possible martian biological activity inside meteorite oscience epflen mars',
#  'workshop decentralization messaging epfl lausanne tomorrow jan carmelatroncoso gdanezis trevp come time talks small group discussion existing new protocols',
#  'artificial intelligence potential revolutionize transportation interview alexandre alahi new professor transportation engineering epfl rt traceepfl',
#  'physiciens epfl peuvent lire travers livre sans louvrir testament scellé catharuçia savonario rivoalti na plus secret httpstcosoiiictqnr via archimagredac',
#  'improving cooperation universities businesses one main challenges r policy according eusciencehub innovation tueindhoven tumuenchen epflen dtutweet',
#  'kicks tomorrow epflen',
#  'new study leukemia offers clearer understanding biology via epflen',
#  'webots simulations used epfl researchers simulate insect walk naturecomms article',
#  'make gigantic soap bubbles tutorial made epfl experts httpstcoskukeuexpm',
#  'woop woop super happy looking forward working hand hand covestrogroup imdeanano epflen ujinoticias imperialcollege etc',
#  'congrats ibm scientist irem boybat winning best poster award synaptic architecture last week ieeeorg nvmts njit epfl',
#  'stay tuned announcing epflen openscience summer school next week fantastic speakers great workshops',
#  'deep hot geothermal energy new experimental paper scireports epflen highenthalpy geothermal',
#  'dnmason violainesee cciliv chance images psf acquisition meta data made publicly available id like test imagejops deconvolution algorithms deconvolutionlab producing equivalent results btw measure compute psf',
#  'vélos étudiants vacances bien sécurité vélostation epfl httpstcoeituenfoax',
#  'act global think campus epflen epfldurable martinvetterli',
#  'students epfl unifr design selfsufficient home integrated solar panels good luck solardecathlon httpstcocuixeajydh',
#  'scientists epflen able watch human brain rewire adjust advanced prostheses neuroscience medtech digitalhealth',
#  'epfl badcompany days p',
#  'measuring water quality snake robot biosensors cool work dmfunil jr vd meer epfl ht fpbock httpstcovpzbekanay',
#  'water surprisingly ordered surface nano droplets epfl httpstcoyjkjnlqnyw',
#  'ran ex utcaee student gordon research conf worked w undergrad satoshi takahama successful faculty member epfl',
#  'video nicola marzari epflen computational discovery century online httpstcotfckevyktq',
#  'jet lag forgetting hk chic episode chiccommunity epfl voyage hongkong',
#  'tomorrow swissedtechcollider keep eye edtech',
#  'spaceship epfl lausanne',
#  'top architect travail fin dannée exhibition exposition epfl architectureschool seoul métro line proje httpstcozdvowdckrx',
#  'superpouvoirs bibliothécaires bcu alors httpstcojoyiuorohe',
#  'meet ijspeert lab epflen lab pleurobot lives see whole video',
#  'mal soiréesbibliothèque rolexlearningcenter epfl',
#  'constructive ml posters creativeai musictech httpstcoixjnhrirwy',
#  'looking forward swiss cytometry meeting ecole polytechnique fédérale lausanne feb drop top tips streamlining operations research facility corefacility roi epfl epflsv swisscytometry swisscytometry',
#  'watch video knight supports flatearth view brjsa augustepiccard ericdubay holyghostalice',
#  'nice day spheroids violainesee lab imaged size cciliv good opportunity play deconvolution algorithms deconvolutionlab httpstcobkliewfcro',
#  'parametric tool evaluate environmental economic feasibility decentralized energy systems',
#  'spinoff fhaptics attending th march finland know foldaway haptics robotics virtualreality robots joystick vr rrl epfl swissstartups roboticists haptics',
#  'strong robust negative relation length title article scientific quality worried moment economics articles',
#  'years reiterating safe navigation populated indoor environments mobile robotics largely solved epfl alex alahi demonstrated safe natural normal bad alexalahi',
#  'dieser dr michael gonin ist wirklich gut er bringt geschichte unternehmertum und soziale verantwortung zusammen epfl hybridesdenken httpstcoboreqiexit',
#  'excited see epfl among inaugural partners gixedu global innovation exchange w uw tsinghuauni',
#  'fifel panel prof yunus discussion prof f vuille epfl cen director hrff zurich access energy human right billion people still access electricity following day prof yunus public lecture epfl httpstcohxsovlrngb via youtube',
#  'thankfully next plane also delayed jenmccutcheon also got security plane also met henrik epfl shortly way next leg cape town halfway point antarctica antarcticbase polarfoundation',
#  'rx solutions ct system ultratom helps read books without open read unreadable sciences ct tomography lemondefr epfl epflen information',
#  'new evidence dark matter makes even exotic via epflen vdtech research',
#  'dark matter even darker thought oscience epflen darkmatter hubble astronomy',
#  'according epfl study butterflies living urban areas face threat consanguinity potential extinction',
#  'ultrafast processors thanks plasmons epflen quantum nanostructures',
#  'fantastic multimedia presentation solving paralysis epflen gregoire courtine great see human steps wysssupport',
#  'installation metal iterlike first wall fusion reactor jet made difficult operate epfl',
#  'chrlovis hopitauxunige unigenews planetesante epfl careers need strong health informatics training use standards',
#  'new perovskite next generation data storage epfl epflen energystorage',
#  'franceia aude billard professeur epfl lintelligence comprendre sadapter besoin connaissance apprendre extrapoler',
#  'prof tom battin epflen presents ocean streams ntusg natureconf naturenpj assoc ed',
#  'great talk discussion mindmazesa ceo tejtadi venturelabch jordimontserrat champsnight epflen vdtech',
#  'timeshighered ranks eth epflen international universities swissuniversities highered httpstcowvjrzxajgi',
#  'wonder many innocent people swiss police raped tortured prison population foreign many tortured confess',
#  'laboratoire sauver architecture xxe siècle epfl lecorbusier',
#  'drone week epfl lausanne origamiinspired vtol cargo drone folding protective cage fly deliver safely',
#  'first time epfl library takes part love data week find program details stay tuned week dedicated researchdata openscience httpstcochibnceiwj',
#  'presentation held prof dominiqueforay evidencebased future post r policy landscape says one goals finding new combinations regionalspecific capacities regionalspecific opportunities epfl epflen httpstcosktacgrukw',
#  'financial predictions appliedmldays stefanotempesta epflen machinelearning future fintech datascience httpstcofclzitsweo',
#  'uefa uefaeuro anyway epflen students enter',
#  'opportunités saisir technologies développées laboratoire profitent sportifs httpstcoqfzdfohgpp via epfl',
#  'sion construit campus denfer hessovalais thearkvalais epfl valais vu depuis esrofficiel',
#  'sleep neuroscience neurosciences science healthy mitochondria could stop alzheimers epfl',
#  'epfl scientists developed selfhealing materials inspired plants via epflen vdtech',
#  'database clarifies bottomup design cement httpstcoebjlvalhzz epfl',
#  'someone explores wikipedia often first stop start searching information topic even dont admit httpstcoxwvnxyfunq',
#  'shape future neuromodulation research worldleading scientists register epfl',
#  'swiss library revolutionized concept library travel epfl traveltuesday switzerland',
#  'thomas knecht ventureoffice announces award ceremony take place epfl',
#  'space enthusiasts epfl offers mooc space mission design operations w astronaut claude nicollier',
#  'international universities world ethen epflen lead timeshighered report',
#  'immersiatv part future european media according techeu dsmeu eucommission research innovation',
#  'mozz dropping githubeducation epfl mooc factory httpstcozmvfhhyhli',
#  'amin studies epflen thoughts family madness stop',
#  'become growth hacker great meeting today besmart education beobsessive passion technology swissedtechcollider innovaud epfl masschallengech swissnexindia unicef',
#  'aimerai juste donnez information japan impact lieux fev japanimpact epfl lausanne nobillag neinzunobillag rts srg rtsi',
#  'envirobot eel epfl locates sources water pollution switzerland',
#  'invest invest invest research',
#  'great week',
#  'first workshop vleadersfintech curtis giesen pitch new york dgtswitzerland postfinance innovaud sfsch epflen',
#  'alzheimer vitamine antibiotique améliorent santé mitochondries réduisent ainsi dommages maladie modèle animal via epfl',
#  'critical avalanche danger swiss also french alps due heavy snowfalls strong winds read full bulletin snow neige snowscience slf avalanche danger swiss france alps epfl',
#  'highly appreciated work sensors',
#  'danish school installs world largest solar façade epflen copenhagen switzerland clean energy green',
#  'traces possible martian biological activity inside meteorite oscience epflen mars',
#  'presenting last vleaderslifescience today mattias larsson founder epfl startup suincol httpstconhpahrisgp',
#  'selfsufficient home solarpanels installed facade httpstcodrtxjxjdzd epflen',
#  'seednight tomorrow epflen come see pb b innovative aesthetics antiaging medicine vdtech',
#  'polycopiés epfl support cours conçus profs disponibles bibliothèque empruntables httpstcobanevqtrxf httpstcocfigqtyncp',
#  'food one largest industries world enormous potential new models great challenge openfood hackdays epfl marcelsalathe',
#  'epflen scientists developed novel dnasequencing technique suitable dnabinding proteins characterization httpstcoqygdqtlvgt',
#  'epfl retrouvez tweet sélectionné limportant',
#  'cours finissent aujourdhui souhaite bonnes révisions étudiant inscrit examens agepoly epfl epflen',
#  'environnement marché pleine croissance httpstcothtcylrmtn philippe thalmann epfl',
#  'made series slides tell story torture sexualharassment sexualabuse swiss police inspector fabienfontannaz public prosecitor fredericgisler dr law unifr epfl httpstcodftdrcetrl',
#  'new version epfl mooc plasmas available time edxonline follow lectures plasma medicine superconductivity fusion laserplasma interaction taught experts sorbonneuniv polytechnique httpstcojgfkumdvyi',
#  'deeplearning course epfl machinelearning deeplearning ann ia machinelearning bigdata datascience httpstcontplsnrafn',
#  'mooc household level water treatment methods successful implementation strategies assessing impact thereof part sanitation water solid waste development mooc series free running continuously eawagresearch epfl',
#  'das neue programm für praxisorientierte eawag kurse peak ist jetzt online der nächste kurs relevé écomorphologique évaluation rives lacustres findet februar der epfl statt',
#  'rappel bibliotheque epfl recherche encore étudiantes motivées aider organiser silentparty faire danser rolexlearningcenter silentdisco epfl merci ceux déjà manifestés bon weekend tous',
#  'developing robots walk naturally robotics epflen biorobotics',
#  'smileseq identifies binding motifs single dimeric transcription factors ngs slims epflen',
#  'epfls expansion towards green chemistry alpine extreme environments epfl',
#  'belle leçon technologie rtscqfd lexosquelette twiiceofficial testé silke pan rtscqfd epfl',
#  'portable probes hunt cancer cells surgery via epflen',
#  'noir cest noir dites artlab pierresoulages epfl epflculture epfl neige expo httpstcorolwlcnfew',
#  'points last night blues epfl wins whipton st nicholas',
#  'learning adapting different materialities temporalities biomedia colab workshop epfl hackuarium ossparis',
#  'epfl embarks new horizons continuing education vdtech cc epflen logitech',
#  'epfl cnbi highlights team first ever cybathlon bci race httpstcotavirrwpkc happy everybody',
#  'im organizing conference neuromodulation travel awards available bluebrainpjt epflen httpstcokggcynsmwa',
#  'last days register next startup champions event multiple lives entrepreneurs epfl suchamps httpstcoihihujkfek',
#  'ia interview marcelsalathe epfl digitalhealth epidemiology campusbiotech limportance alertes précoses resumé',
#  'epfl crée centre cybersécurité directeur académique centre jeanpierre hubaux digitaltrust httpstcoqkysnjcskw security',
#  'très bel exemple dune collaboration interdisciplinaire quand sciences humaines recours physique epfl frederickaplan archivch archimag',
#  'new perovskite aging measurements offered standardization epfl pv tech switzerland',
#  'caution extreme avalanche danger wallis french massifs savoie due heavy snowfalls full belletin avalanche snow snowscience slf extreme danger hazard caution prudence neige risque switzerland france epfl',
#  'standardizing perovskite aging measurements epflen',
#  'kevinschawinski influencing prof ethdomain congrats epflen strong top ten',
#  'die onlineschule der epfl hat mit dem certificate open studies einen neuen akademischen diplomtypus ins leben gerufen epfl httpstcowzvufmyxid weiterbildung diplom cos',
#  'ready coltrane enoch pratt loch raven branch free show kudos weaafm tip epfl',
#  'many congrats stew great alumni epfl good luck lavieparisienne',
#  'today witnessing graduation new epfl ambassadors congratulations students epfl epflevents',
#  'wonderful teashop nyon lecercleduthe also fb unil epfl unigeen lifeinnyon mynyonregion lemantourisme',
#  'significantly speeding stem imaging nanostructures emad oveisi colleagues epfl httpstcofqknaemwgu',
#  'cyclobiblio epfl espace dexpo learning center',
#  'muslimban amin karbasi professor yale university wife daughter stuck outside u',
#  'bsc master students apply nanotechnologies summerschool grenobleinp w partners epflen politonews',
#  'bibliothèque epfl recherche étudiants epfl motivés aider organiser silentparty faire danser rolexlearningcenter intéressés collaboration écriveznous avant adresse auroregranvalepflch',
#  'unethical build humans trust much asks aihealth swsx sxswiss',
#  'rlerignier sneedition désolé juriste connais norme iso',
#  'register training writing successful proposals february zurich heigvd hesso hessovalais bfhhesb zhaw uzhnewsen ethen dgtswitzerland venturelabch fsrmch unifr swisseuresearch snfch sbfich epflpark epflen',
#  'new report risk misuse life science research epfl scnatch',
#  'photographie darchive lâge numérique bientôt édition tessin supsi campus trevano avril mai epfl epflenac',
#  'way first swisscytometry meeting epfl lausanne lhwstratocore corefacility cytometry flowcytometry winterwonderland',
#  '',
#  'future ingénieure explique projet epfl hessovalais',
#  'twos company comes mapping mapkite via epflen vdtech',
#  'pause déjeuner moment convivialité plein coeur portivechju avant reprendre travaux lag association epfl httpstconzhkfztpxe',
#  'quand deep learning confond cafetière cobra epfl robot',
#  'rueeggthurgau ewzenergie mwayonline fairpowerch ein stimmungsbild für marco rüegg tesla parking epfl',
#  'art science collisions presentation art residence cern yunchul kim helga timko epfl',
#  'anticancer drug gets boost combined antirheumatic epflen ntusg naturecomms via eurekalert',
#  'ypsomed first industrial partner switzerland swisscomm ericsson epfl',
#  'philipp jovanovic daeinar cryptosecurity researcher epfl giving talk dotsecurityio',
#  'epflen available platforms edx',
#  'dont know epfl stanford switzerland says uknis texas sxsw swissnexsf epflen',
#  'roboreptiles spy fleshandblood counterparts httpstcocbwparmemb bbc epfl',
#  'effective lowcost solution storing solarenergy epfl via technologisteu httpstcoqklwlqjifd',
#  'latest dhums carlo thanks epfl hackdisrupt',
#  'discovering adrian holzer epflen dh pedagogical day unil ladhul dariahteach',
#  'international ranking eth epfl top institutes',
#  'music spheres httpstcoxwoypkslri aristotle says born hearing noise without silence compare meditate music returns',
#  'call edtech startups get funding mentoring epflen apply july ksaccelerator edtechaccelch',
#  'happy prof thomas nevian unibern deliver final lecture afternoon session sept',
#  'actuallyworking dont call funprog nothing p',
#  'femtoprint cmi annual review meeting lausanne epfl epflen presenting femtoprint technology glass',
#  'advances digital singlephoton detectors pet dr claudio bruschini epfl digitalimaging',
#  'jordi montserrat venturelabch talks epflen champsnight',
#  'proteins domesticated genomes httpstconpgbukjhbl via epflen vdtech',
#  'learn use technology innovation tool fight poverty enable sustainable development epfl',
#  'marcabrahams starts ignobel award tour show improbresearch epfl',
#  'julio salgado born learn teach httpstcoggjxqokinp stories via epfl ibmresearch superglaze theworldin function',
#  'latest architecture free press httpstcotlieahzlsd thanks divisare jorgensundberg epfl interiordesign',
#  'encouragements carinadjey edacyhq lancement programme fast formation codeurs dakar espdakar ucadsenegal epfl code africangeek mooc',
#  'retina projection nice intel made smart glasses look normal httpstcojtnnxayhrl via verge',
#  'savmap namibian semiarid savanna images available analysis heluc sdscdatascience datajamdays opendata',
#  'lets real one reads internet privacy policies interpret inscrutable legalese helping become informed user',
#  'iciq leads aleaf collaborative project awarded eucommission towards artificial leaf',
#  'official ceremony nobelprize winner jacques dubochet unil presence br guy parmelin openscience society rabelais epfl epflen epflevents',
#  'bikes night epflcampus epfl',
#  'ericdubay valentina madonna fakepussy realbaphomet kingconrad baychimokin tortures cheat',
#  'dedux verge der miniprojektor stammt übrigens von lemoptix einem epfl spinoff dass intel übernommen hat innovation ar venturelabch swissnexsf swissnexboston',
#  'step forward targeting cancer cells measuring electric currents via epflen vdtech',
#  'conférence musée art histoire genève lieu demain mardi mahgeneve epfl unosat venez nombreux patrimoine numérique drones innovation plus info découvrez article bilanmagazine',
#  'reportage étudiants français tournent davantage vers suisse leurs formations professionnelles lausanne ehlnews epfl',
#  'warm thank visitors joined us inside epfl ecal lab open days epflecallab ecal epfl designresearch digitalinnovation',
#  'epfl offers mscrobotics join long list brillant minds robotics epflphd httpstcomsnlgmpaol',
#  'epfl spinoff sundancefest sensation months made techcrunch front page thanks joshconstine dartseventeen swissnexsf venturekick masschallengech prohelvetia worldvrforum lnco cnp markboulos elastictime',
#  'camille first paper epfl officially online envscitech kinetics inactivation waterborne enteric viruses ozone httpstcokjfcbbihjp',
#  'epfls imposter robotic fish infiltrates school zebrafish switzerland',
#  'data science mobility conference coorganized epfl sbb cff ffs janv epfl',
#  'dgtswitzerland lereseau epflen cybersecurityday objetsconnectés intelligenceartificielle réalitéaugmentée points sensibles cybersécurité',
#  'nouveau programme cours eawag axés pratique peak ligne prochain cours relevé écomorphologique évaluation rives lacustres lieu février epfl',
#  'chocolate berries vegan cheesecake epfl coworkers veganfood epflfood',
#  'robotic spy among fish epflen',
#  'waiting ceremony start epflalumnigala epfl epfl httpstcouczjzmnfyf',
#  'impressive carving diamonds optical components httpstcoivlpjaimhi via epflen vdtech',
#  'great day graduate magistrale starts live congratulations new alumni epflen',
#  'today lab day great honor welcome nobelprize winner jacques dubochet talk serendipity unil epfl epflen epflevents',
#  'special thanks espdakar epfl enabling young students quality content guide become gamechangers',
#  'design thinking unlike approaches design try apply well defined existing formula well defined problem really start questioning problem open mind allows free constraints jeffrey huang epfl',
#  'nouveau mas dédié professionnels urbanisme aménagement territorial proposé unigenews epfl',
#  'actually ive read great many privacy policies real gems im relevant knowledge comscore great work epfl epflen',
#  'merry xmas happy new year martinvetterli may year peace love success us martelinnovate dsmeu dgtswitzerland',
#  'proud years collaborations ac immune first field alzheimers disease als prof andrea pfeifer source pride inspiration us excellent role model supporter epfl students young scientists',
#  'demain personnes bah oui seulement cest cosy léprouvette prépare atelier permanent feront ah ah jacques dubochet nobelprize chimie rencontre suivie dun atelier pratique microscopie électronique unil epfl epflevents',
#  'etudesantedusoir découverte repères génétiques associés durée vie diminuée chuvlausanne epfl isbsib',
#  'congrats ethen winning years challenge well back next year epfl agepoly',
#  'cellules solaires perovskite stables pendant plus dun epfl',
#  'amazing glad part edacyhq bootcamp met stellar students theyll shine groupecofina',
#  'follow foes shadaislam today chairs roundtable discussion epflen lausanne asia meets europe day asemday',
#  'bhutans happiness stems hydropower httpstcotmtdstsjzh via epflen',
#  'another points blues epfl wins st nicholas ladysmith',
#  'thursday swiss edtech collider inauguration epfl httpstconsylbiszna edtech swissedtechcollider innovation coorpacademy',
#  'pc meeting start epfl',
#  'grid mobility concept explained epfl chemistry students prof giraulthubert good introduction electromobilis visit',
#  'petewarden google tensorflow team appliedmldays epfl',
#  'détendre après fêtes ondes cérébrales intention inscription obligatoire best wishes',
#  'shametorturers australia saying police rapists bloody god read believe people even',
#  'mouvement sens ferait gagner temps précieux nombreuses personnes',
#  'size matters titlelength impact scientificquality epflen epfl via jameslarus',
#  'scarletyohansson disgrace looking like boy womensmarch dont want nwo transgender antichrist baphomet',
#  'ouvrons epfl ceux fait études via eborloz cdfdanslapresse cdf',
#  'biociment peut être produit place moindre coût température ambiante besoin énergie limité innovation epfl',
#  'leprosys drug resistance origin revealed genome analysis epfl',
#  'switzerlandhastalent congratulations jacques dubochet',
#  'fit supports alogo analysis viventis microscopy post french welcome ventures via startuptickerch startupfit vdtech alogoanalysis epflen',
#  'chuis talk google fac ic epfl jai limpression quil aucun étudiant bachelor',
#  'latsis prize ceremony start prof xile hu epflen snsfch scientistswhoselfie',
#  'bacterial powder quickly stabilizing soils httpstcopqslfajace epfl',
#  'shameless plug audiotactile peripersonal space processing around trunk human parietal temporal cortex intracranial eeg study bernasconifosco nfaivre royesal biorxivneursci epfl',
#  'uefa professional football strategy council discuss financial fair play new rules via sportscrunchind eca epfl fifa fifpro pfsc',
#  'excellent point epfl alex alahi artificialintelligence based perception mobile robotics autonomous cars human populated environments must incorporate social intelligence understanding etiquette social norms critical alexalahi',
#  'deputy director doug stone presenting first yqi distinguished lecturer award tobias kippenberg epflen',
#  'itfa itfaconference session assameeting benefits labor mobility currency union linda tesar cesmichigan university michigan nberpubs house nberpubs proesbting epflen',
#  'congrats osaekomi making list digitalshapers datascience epflen ethen bilanz letemps sdscdatascience',
#  'prof gratzel epfl speaks past present future opportunities solar cell research check early work notredamescience',
#  'incubateur dédié technologies léducation suisse v brigittepierrat epfl',
#  'unveiling biology behind nonalcoholic fatty liver disease via epflen eurekalertaaas nafld',
#  'reconciling solar energy heritage preservation via lesoepfl epfl epflenac httpstcoxvevamgjgi',
#  'mystère soulages éblouit science epfl',
#  'tomorrow day talented participants hrs produce short films communicating science come watch works public screening wed dec cinema city club pully scicomm unil epfl lettresunil cusophd epflen',
#  'reportage epfl ehlnews',
#  'pentacene excitons investigated using molecularscale approach focusing generation electroluminescence local charge injection stm tip individual pentacene nanocrystallites maxplanckpress ucl epfl httpstcoscnzxhptgu',
#  'matin comité directeur collegium francosuisse smyle menu projets collaboratifs cours partagés innovation croisée entre epfl univbfc concret entre france suisse insiscnrs cnrscentreest ensmmofficiel ufcuniv',
#  'lets meet',
#  'meeting program committee happening epfl conference porto',
#  'infoscience currently maintenance thank understanding wish good weekend epfl',
#  'childcare conferences excellent hopefully qualified vetted persons httpstcobdowqoqxer',
#  'studenten und alumni berichten über ihre erfahrung der epfl beim jobinfoforum staatfreiburg ethingenieur elektrotechnik informatik mikrotechnik maschinenbau materialwissenschaft bauingenieurwissenschaften lebenswissenschaftenundtechnologie epflevents',
#  'trekkinglemon sharing view future education epfl epflalumnigala education epfl',
#  'apprendre éléments chimiques tableau mendeleïev haïkus gniarfffff poesie chimie cc acadsciences upmc epfl',
#  'marcelsalathe point maybe epflen reject companies forumepfl sure epfl give students means understand fundamental questions society cc dtsbourg',
#  'swiss vr sundance film festival artanimmocap imversech see vr virtualreality swissgames cc prohelvetia swissnexsf swissfilms swissembassyusa epfl',
#  'governmentmandated backdoors software chainiac tool could response says epfl toholdaquill httpstcohbayeuqajd',
#  'completed big data analysis scala spark thank heathercmiller epfl coursera',
#  'benoit seguin seguinbe prize epfl ic research day replica demo visual search digital art collections isadilenardo dhlab httpstcojnmlxmguos',
#  'spieopticsphotonics plenary michael grätzel pioneering new form solar cells httpstcontjzmgmydp opticsorg epfl',
#  'prof dario epflen solutions avoid inflight drone collision practical applications sensefly acquired parrot',
#  'chbotschaftde eth timeshighered epflen kathyriklin seht ihr geht auch ohne horizon ist uns zu eng zu klein wir sind global',
#  'join bioinformatics specialist drpetty today epfl sv building panel discussion transitioning academia hbagp',
#  'dgtswitzerland lereseau epflen cybersecurityday guyparmeiin sme naive easy accesspoint cyberattacks',
#  'villes face perception thermique silvia coccolo epfl',
#  'three times less waste particularly important food company people complain recruiting going meetings blown away alison michan bühler apps pitching also epfl msc students shouts students demoed work',
#  'modeling human behavior airbnb epflen',
#  'reste plus quune semaine participer concours insta epflmaurice dont voici quelques clichés photographier mauricelibrarysecurity rdv lentrée bibliotheque epfl original bons dachats dune valeur chf gagner',
#  'upon time lausanne switzerland library epfl epfllibrary vsco vscocam campus',
#  'pdf etat lart fabrication additive métal eric boillat epfl',
#  'first ever photograph light particle wave oscience epflen quantum',
#  'pvalue reliability epfl openscience',
#  'happy birthday mister president martinvetterli epfl thanksforthefollow',
#  'études epfl commencent comme ça vusurlecampus httpstcoicjzbgikkg',
#  'new microscopy method offers oneshot imaging nanostructures via epflen vdtech',
#  'codeweekeu turning yay look much forward computational thinking unplugged activities codeweekch',
#  'brief review synthesis catalytic applications graphenecoated oxides epfl unistra',
#  'morning views cecam epfl bad back active nematics ctmcecam natxopago',
#  'route lausanne seminar phd committee harmanton kloks group epflen',
#  'workshops days sold cumulative people weekend handson applied machine learning epflen thank workshop organizers',
#  'hybrid denken das wurde thuner politlunch gefordert evp edu michaelgonin',
#  'days public screening films opportunity meet participants mentors wednesday december cinema cityclub pully save date scicomm epfl unil epflen cusophd',
#  'computationalsciences neuroscience research folks circle might want consider conference lausanne httpstcoilctlfatmt',
#  'looking newyearresolutions drafting innovative proposal thanks tips hints shared info days taking advantage new funding opportunities',
#  'japanimpact cest weekend campus epfl trouverez programme billetterie ainsi dautres informations pratiques site japan impact httpstconpcumuigef',
#  'excited prepare laboratory exercises using new epuck version epfl fmondada',
#  'congrats beat',
#  'mauricelibrarysecurity volera bibliotheque epfl cet aprèsmidi entre loccasion prendre photo plein vol participer concours instagram epflmaurice',
#  'looking forward share experience gained writing many successful proposals ictproposereu martinvetterli supsich usiuniversity simonl fcokienzle pfurrer swissskills swissmissioneu swisscore friup creapole unibasel',
#  'machine learning go workshop applied machine learning days workshop epfl machinglearning programming coding coder programmer golang ml switzerland lausanne suisse',
#  'best open access get free copy httpstcoybkxlwpuow',
#  'matrixbinding checkpoint immunotherapies enhance antitumor efficacy epflen tokyotechjp uchicago httpstcocmhoigyevq',
#  'gehendragurung great topic consider abstract submission deadline january epfl epflcampus unisdr',
#  'lire travers livre sans louvrir archives tomographie rayonsx epfl via archimagredac',
#  'human genomics infection immunity working closely engineering clinical colleagues epfl chuvlausanne please get touch',
#  'thanks epfl know soft robots really suck watch httpstcoulurhrsqwi',
#  'new findings could lead improved vitro testing via epflen vdtech',
#  'dark matter even darker thought oscience epflen darkmatter hubble astronomy',
#  'jmlattes regisgodec autatetoulouse coup quid dune expertise independante type epfl cela mettrait tout monde daccord',
#  'probably antoine geissbuhler parle nouveaux métiers santé hopitauxunige unigenews planetesante epfl',
#  'hey trainees looking postdoc genomics come switzerland lake mountains exciting science',
#  'iranian epfl denied us boarding cant start postdoc harvard med gqdaley harvardmed help',
#  'happy birthday maurice first president epfl maurice cosandey turns epflen',
#  'measuring time without clock epflen',
#  'chimie cerveau dévoilée httpstcooswxdojogr epfl',
#  'marathon créatif museomix appel candidatures clos samedi museomix artlab creation epfl',
#  'swiss team solar decathlon competition via epflen congrats swissliving vdtech',
#  'dr julien faget epflsv epflen talk flow cytometry unsupervised analyses immune signature functional biology',
#  'lapp liker direct transports publics epfl',
#  'see epfl httpstcobxrhpamqlx',
#  'winter coming epfl',
#  'hey martinvetterli merci tour hélico séoul voyagebachelor epfl',
#  'functional programming scalalang epfl first day',
#  'heading lecture circuitqed epfl school interactions httpstconfcteddnmh epfl epflcampus',
#  'traveling epflen nice trip car',
#  'walking two legs easy seems epfl',
#  'looking forward sure tune',
#  'results made cover flyer lft pic grt initiative swiss manufacturing sctr cont thrive epfl csem',
#  'inspiring talk virtual reality daylight research architecture velux daylightsymposium epflen sbiaau',
#  'new method improves stability perovskite quantum dots epflen',
#  'dna sequencedirected assembly bacterial chromatin epfl microbiology chromatin biophysics',
#  'sixlegged robots faster natureinspired gait epflen robotics biologists insects',
#  'full house ignobel award tour show marcabrahams improbresearch epfl',
#  'drpetty bioinformatics specialist present epfl sv building yesterday discuss transitioning academia hbagp',
#  'digitalday thymio présenté fmondada illustrer léducation numérique initiée epfl nccrrobotics toute suisse programmation robotique dgtswitzerland',
#  'système mieux nettoyer rues chercheurs epfl hauteecolearc ainsi startup cortexia mis pied dispositif détecte déchets ville classe catégories via',
#  'eth lausanne epfl gründet plattform für digitales vertrauen digitaltrust',
#  'credit suisse ouverture dun espace collaboratif epfl switzerland',
#  'superbe projet edtech winner kickstartaccelerator epfl ubisim révolutionne formation soins infirmiers réalité virtuelle',
#  'lab epfl collaborating nissan studying neural patterns drivers really excited see nissan unveiling braintovehicle communication improve drivers experience via verge',
#  'montagne cabanes futur epfl séduisent club alpin suisse httpstcoqtvitueusn switzerland',
#  'impressive carving diamonds optical components httpstcoivlpjaimhi via epflen vdtech httpstcootfyqinqgv',
#  'premier swiss startup competition venture kickoff edition feb pm epfl rolex learning center get inspired former participants epfl president martinvetterli learn competition network',
#  'join us february zurich training write successful proposal httpstcoglfsbvjxso funding eucommission martelinnovate ethen epfl uzhnewsen unifr uzhnews',
#  'lavoir parcouru cela lair dêtre sérieux ouvrage matière',
#  'call papers extended abstracts open deadline submission january invite submit abstract session open science opportunity global south epfl epflcampus gosh ocsdnet opencon sciencebiencomm',
#  'music playing head real conundrum scientists epflen',
#  'using graphene create quantum bits epflen',
#  'amazing seethrough solar film could turn every window power generator auspol energy',
#  'market researchers achieve truly understand audience real time facialrecognition httpstcoqjzmsogwyo',
#  'nrel research swiss cseminfo epflen sets new efficiency record siliconbased multijunction solar cells',
#  'incredible week vleaderstech thanks dgtswitzerland wpcapital innovaud epflen ethen',
#  'power hydro cnbc w epflenac lch team anton schleiss epflenac',
#  'raulpacheco pages thesis address world sustainability economic inequality',
#  'encore quelques jours inscrire hearcingenierie hauteecolearc unineuchatel cseminfo epfl microcityne',
#  'award blockchainsummit prime projet deux étudiants epfl',
#  'contrôler exosquelette main pensée epfl httpstcodenokqywrc',
#  'lélectrochimie débusque protéines résistantes antibiotiques via epfl vdtech',
#  'promising light improve perovskite solar cell performance epflsb epflen',
#  'paper introducing first ever modular origami robot popular article ieee asme transactions mechatronics two months row httpstcopfocmykcvb rrl epfl robots origami modular tmech tech robotics ieee',
#  'nouveaux moocs augmentés plasmas epfl',
#  'received letter epfl scalalang scalacenter stickers didnt remember asked great day',
#  'galaxies growing edge void epflen httpstcomftlolyolu',
#  'swiss machine learning days epfl today hit want hang',
#  'today day',
#  'one students dataviz like teaching style deserves medal comparing epfl lectures attend hats thankyou',
#  'fascinating work epflen creating imposter robot fish created kind secret agent infiltrate schools small fish robots robot robotics technews technology tech nature artificialintelligence httpstcoxthmthjpto',
#  'new paper describing database ngs data published naropen httpstcovnvszikvoc isbsib epflen',
#  'tree beer made gianpaolorando beerdecoded beer dna epfl diy',
#  'très curieuse suivre leurs réflexions',
#  'tetsurokitahara looks awesome paper online would love give try memotv goldcomputing epflen elluba',
#  'futuris shoot epfl lausanne solliancesolar lab eindhoven exciting perovskite solar developments terrywinn filming lab kitted clean room thierry greatcellsolar olivier bellon prof adelio mendes euronewsknwldge euronews',
#  'exposure science film hackathon applications open come join scicommfilmhacking event science scicomm',
#  'enac launches innoseed program startuptickerch httpstcoqziorlabwr via epflenac epflen innovaud vdtech',
#  'take ownership scholarly system inherit apply attend opencon berlin deadline aug httpstcocmujlvakjl',
#  'signé epfl',
#  'lélectrochimie débusque protéines résistantes antibiotiques hubert girault epfl',
#  'remo lütolf von abbschweizag swisstechepfl zusammenarbeit von mensch und robots steigert produktivität sichert arbeitsplätze epflen',
#  'swiss data science twitter sign epflen datajamdays learn httpstcoknvilhwpgb see',
#  'excited jvican epfl mbryzek flowecommerce visit hbcdigital gilttech tonight dublin scala meetup',
#  'glad see high quality work cinegy vrtmedialab epfl videostitch imecint psncnews lightbox',
#  'classe pilote flipclass algèbre linéaire epfl places volontaires',
#  'three ecargobikes available campus free use go h carry via epflen',
#  'sketchnote epfl jeanphilippe brantuts talk atomtronics vallebenasque jilascience jqinews',
#  'epfl spinoffs flourish finely tuned ecosystem via epflen vdtech epflpark',
#  'great talk mindmazesa',
#  'congratulations laureates global issues poster awards epflen',
#  'touchable tablet guide visuallyimpaired epfl blindpad sigchi',
#  'sign mooc simulation neuroscience reconstruction single neuron epfl',
#  'rejouit déchanger smattheydoret mariage geographe medecin hopitauxunige epfl chuvlausanne',
#  'epfl cnbi highlights shared ctrl allows lockedin user operate bci months w calibration httpstcoxnxlvbbkyr',
#  'rlerignier epfl oui lai aije tort croire lexpertise csl zotero appartient documentalistes juridiques',
#  'epfl researchers developed soft flexible robots improve physical rehabilitation via epfl',
#  'save date epflen registration starts december digitallernen gisiq gised',
#  'open phd position epflen lesopb big data renewable energy built environment',
#  'eth zürich und epfl haben das swiss data science center eröffnet eth epflen sdscdatascience',
#  'immersive interaction research group epfl deforming virtual reality purpose physicaltherapy epfl',
#  'excited host epflen',
#  'investigating embolism resistance herbaceous species new high resolution xray tomograph thanks epflenac epfl',
#  'looking forward retinai venturelabch champsnight ophthalmology eye',
#  'market researchers achieve truly understand audience real time epfl epflpark nviso innovation',
#  'blue brain allen institute created virtual neurons epfl',
#  'robot help visually impaired schoolchildren find way epflen',
#  'haben gerade dieses filigrane häuschen im genfersee entdeckt das pavillon für wasser land licht wolhoff epfl',
#  'commence composer musique artificialintelligence ia via epfl',
#  'book launch exposition ubiquitaire open design studios epfl school architecture archizoom',
#  'mooc simulation neuroscience reconstruction single neuron httpstcoohzdqrzejj epfl',
#  'staircase epfl campus inspiration scala logo fujifilmxseries architecture',
#  'fascinante plongée œuvre pierresoulages expérimenter soimême epfl fragmentin',
#  'vaud based projects epflen great fully associated member',
#  'ff kikohs beautiful artworks displayed epfl featured zettabytes',
#  'watch jose millans talk bci general population asilomar meeting epfl via youtube',
#  'latest dhums carlo thanks epfl',
#  'thehiphopswami epflen unfortunately try record one next ones',
#  'dessiner larchitecture alpine epfl mettre raccards rencart httpstcoaumywxycdb',
#  'entretiens urbains rémy pagani maire genève rencontre vincent kaufmann professeur sociologie urbaine danalyse mobilité epfl pont lîle',
#  'exciting venture premier swiss startup competition kickoff edition next week date wednesday february pm epfl rolex learning center get inspired register via httpstcoxxmuldcqlg epflen switzerland innovation',
#  'venture kick epflen february ventureoffice',
#  'lets talk data quality first topic love data week epfl library openscience find useful resources httpstcoovcxbizfdj',
#  'epfl bonjour étudiant journalisme cfj paris possible poser petite question privé sil plaît bonne journée',
#  'itfa itfaconference session assameeting benefits labor mobility currency union linda tesar cesmichigan university michigan nberpubs house nberpubs proesbting epflen itfaconference httpstconxduwheyyj',
#  'set novel heuristics inducing largescale taxonomy english wikipedia categories network novel comprehensive pathbased evaluation framework taxonomies thesis amit gupta epflen fulltext forthcoming',
#  'remarkable increase startup activity epfl congrats martinvetterli cltucci entreptech',
#  'month go frances largest student sporting event begins almost participants including epfl cranfielduni students httpstcoarkwnybioy',
#  'fans cc phbismuth xaviercoadic editionslavolte cosmoorbus usbeketrica epfl damasio',
#  'danish school installs world largest solar façade epflen copenhagen switzerland clean energy green',
#  'exciting journey lies ahead moschaerer talking aceexpedition crew sciencehasnoborders climatechange epflen',
#  'ca court ca court carandache epfl',
#  'swiss tech center epfl',
#  'profile epfl president martinvetterli nzz',
#  'julnicolas epflen cool',
#  'new speaker announcement philipp jovanovic daeinar cryptosecurity researcher epfl paris next april',
#  'sdscdatascience national center datascience opens today bern created ethz epflen',
#  'last weeks bertarellineuro symposium teams harvardmed epfl explain programs',
#  'amazing hoping see guys universities like hecparis epflen polytechnique',
#  'happening mins',
#  'poster prize chethana emrs epflen',
#  'senior software engineer apple plenty plate make ios reliable stable good luck thing pest',
#  'promising powered exoskeleton prevents elderly falling via epflen',
#  'looking forward startup champions seed night epfl meet us',
#  'femmes politique finir seconds rôles epfl',
#  'swiss physiology meeting young inv award sept bern unifr unigeen uzhscience ethen unibern unil epfl',
#  'annelies garcia director epflalumni stressed epflen champsnight popularity makes run late',
#  'species cohabit epflen roadsign diversity epfl phdlife graphicdesign wish fairy',
# ...
#  'important timely issue protecting humanitarian cyberspace pmaurericrc icrc bradsmi microsoft davos wef epflen epfl httpstcozkvrbayrqw',
#  'new software model natural light occupants perspective via epflen vdtech',
#  'modeling human behavior airbnb epfl',
#  'cell senescence regulated innate dna sensing via epflen eurekalert aging',
#  'cseminfo epflen nrel present natureenergyjnl energy efficiency rates far excess httpstcoavujdhhuvu',
#  'robotics researchers discovered better way insects walk robots epfl',
#  'swiss mountains climbed staying lake level startuplife startup suisse switzerland epfl innova',
#  'noir cest noir outrenoirs pierre soulages culture art science epfl epflcampus',
#  'new computer model shows proteins controlled distance via epflen vdtech',
#  'new study leukemia offers clearer understanding biology via epflen httpstcovekuwvpahh',
#  'rzanolli sneedition partir dun iso note traitant spécifiquement types zotero docs juridiques souvent mal traités else',
#  'parcours vert ecole polytechnique fédérale lausanne epfl étéindien greenway illustrations exhibitiondesign',
#  'première fois citecmobilite remis prix citec mobility solutions étudiant master génie civil epfl mobilite',
#  'archaïque sublime leçon honneur jacques lucan epfl via youtube',
#  'larchive lhonneur exposition landesmuseum zürich jusquau mai article proposé temps parle mise valeur patrimoine httpstcoppddpyyiry lmzurich letemps exposition zurich archive patrimoine valorisation epfl mjf',
#  'raulpacheco case would handy study title length merits',
#  'proud asked tell story favorite book payot epfllibrary epflevents epflen epfl agepoly borgesjorgel',
#  'welcome epfl chemistry students lausanne visiting valaiswallis energypolis',
#  'bravo epfl constante innovation',
#  'artmyn scanning technology epfl bring highlights sotheby life',
#  'opening epfl professorship field metabolismcontext nutrition human health disease',
#  'bepooler partecipa incontro transports aménagement territoirela coordination estelle réussie al rolexlearningcenter epfl',
#  'impressive smart walk assist improves rehabilitation httpstconiyyitetug via epflen vdtech',
#  'danish school installs world largest solar façade epflen copenhagen switzerland clean energy green',
#  'portable probes hunt cancer cells surgery via epflen httpstcoclpyvpputz',
#  'adrien besson epfl presenting work ultrasound reconstruction compressed sensing',
#  'understanding technology revolutionize humanitarian work article epflen featuring civique app',
#  'conseil syndical tisseo jmlattes refuse contreexpertiser projets alternatifs autatetoulouse collectiftae',
#  'franc invested eth domain generates five times value switzerland job creates another five jobs epflen ethen',
#  'slides lecture ee deep learning epflen ready ones gan wasserstein gan dcgan image translation model persistence pytorch pytorch deeplearning epfl idiap',
#  'sait lattendez tous impatience epfl mauricelibrarysecurity epflmaurice prendra envol bibliotheque epfl matin',
#  'exosquelette aide mouvement httpstcokxtlvcsnst mohamed bouri epfl',
#  'scadays proposais serment turing httpstcoezqkccdlqn proche serments hypocrates celui ingénieurs proposé étudiants epfl idée rendre responsable développeurs merci thinkservices',
#  'children conversant digital technology sure able embrace fourth industrial revolution epfl president martin vetterli epflen stepgeneva',
#  'latest work lab shows feedback enhances brainwave control novel handexoskeleton epfl',
#  'research quantum waltz electrons hints next generation chips via epflen vdtech',
#  'sign human presence clean tidy original picture epfl switzerland',
#  'ali motamed ph lesoepfl presenting thesis control systems improve visual comfort energyefficiency epflen epflenac',
#  'final countdown httpstcojlnocxclmg',
#  'govender mentioned particular revolution astronomers contribute positively change dotastro day zero talk',
#  'solarpower technology brighten future renewableenergy market aisten stanford epfl',
#  'robotic exoskeletons new wheelchairs httpstcoxivngafghi rewalkrobotics neuroconcept eksobionics usbionics epfl',
#  'flat grounds rolexlearningcenter epfl rolex learning center',
#  'sign hackathon take place simultaneously epfl lausanne zhdk zurich',
#  'suisse former sinspirer business lors dun séminaire direction cern epfl event',
#  'ee colleagues epflen threw belgianthemed party appointment vice president best',
#  'app mesurer lenvironnement sonore canton genève epfl',
#  'cest lepfl quon fabrique lhiver si si vusurlecampus',
#  'today worldbrailleday discover blindpad touchscreen device allowing visuallyimpaired people access graphical content touch cc iitalk epfl httpstcooueqdvczdd',
#  'ac immune ceo andrea pfeifer tackling alzheimers disease via labiotecheu',
#  'longsought attack signal type diabetes identified epflen',
#  'innovative window system earns european patent epfl epflenac lesoepfl civilengineering',
#  'gymnases nouvelle dimension classe biologie grâce nanoliveltd httpstcotxqbyqdzsl via epfl vdtech',
#  'impressive unique additive ideal concrete via epflen vdtech httpstcovtwpvixgkz',
#  'unique additive ideal concrete via epflen vdtech',
#  'epfl become drone central early september epfl drone vdtech',
#  'epfl years swiss perl workshop takes place august damian conway speaking interested',
#  'tocare save date epfl drone days september',
#  'time learn drones full program details epflen lausanne innovation airsportsfai',
#  'drone days epfl présentent potentiel infini dutilisations via radiotelesuisse vaud',
#  'urswyder ich auch beim versuch von der epfl punkte uzhnews zu überführen war dann einfacher die module neu zu machen srfarena',
#  'congratulations gamayanews vdtech startupfit cc fitfund httpstcojpwhjdpxsu',
#  'sécurité aérienne caméra peut suffire détecter suivre drone montre recherche epfl',
#  'jeux vidéos connaissent nouvelle jeunesse epfl létudie travers gamelab rtstribu',
#  'mars avril assistez smile jours dimprovisation folie salle polyvalente epfl httpstcosrfcmyssvn',
#  'découverte lexposition pierresoulages merci lucmeier visite passionnante artlab epfl',
#  'livre réussir études epfl ailleurs',
#  'researchers epflen working edible robots improve healthcare via businessinsider httpstcojkeufaeydp',
#  'jimstolze aigencycom yves perriard epflen two keynote speakers hightech systems visitor registration open eindhoven httpstcosmknizeyip',
#  'attending applied machine learning days epfl address fear ml weekend workshops hundreds took hundreds waiting lists probably livetweet online extension school ml',
#  'émissions hausse après trois ans stabilité httpstcohpzanzzkzi marc laperrouza heclausanne epfl',
#  'tech epfl capitale drones début septembre hightech lematinch switzerland',
#  'manquer édition stil salon technologies linnovation lausanne lieu mars swisstechepfl vdtech epfl stilofficiel',
#  'prof haenni presenting epfl current research electronic voting lots fascinating math currently deployed particular geneva probably one todays advanced evoting systems though operational yet httpstcojovwcjqzeh',
#  'energy people blue brain nexus opensource tool datadriven science epfl',
#  'interesting article ageficom today french switzerland talent pool robotics featuring interview nccrrobotics director dfloreano nccrrobotics snsfch funded constituted groups epfl ethz uzh idsia',
#  'corse design workshop mooc camp epfl',
#  'kiss chronic pain goodbye virtual reality see epfl using vr reduce pain paraplegics',
#  'first ever photograph light particle wave epfl',
#  'suhaibfahmy epflen demonstrated fpgas virtualised limited overhead lots parts still missing',
#  'yosef akthman never planned become entrepreuner entrepreneurial community epflen encouraged start gamayanews',
#  'energy focus conversation michael grätzel open access epfl',
#  'reuters ranked epflen europes innovative university imperial cambridge university',
#  'école arbore plus grande façade solaire monde pv enr solar v epfl',
#  'archival photos offer research value exhibition acmepfl epflen',
#  'innovation needs sustainable prof chris tucci jos verbeek rajiv srivastava epfl worldbank goodpowwow onlythegood',
#  'cryogenic fab chip acsnano matthias imboden epflen wpdl david bishop buece butweets psw nano',
#  'paper collaborators epflen virtualized fpga runtime cloud published ieee access',
#  'first lowcost system splitting carbon dioxide epflen',
#  'sarah perrin epfl quitte punta arenas haute mer stormy weather expected next hours aceexpedition',
#  'bonnardv epfl cest',
#  'gafa sontils devenus trop puissants charles wyplosz iheid denis gillet epfl',
#  'gros plan infections graves chez nouveaunés jfellay epfl isbsib egiannoni chuvlausanne',
#  'propriété intellectuelle suisse championne monde brevets suisse via epfl',
#  'robots futur yeux suisses httpstcolrvirfnywc via ictjournalch vision startup switzerland innovation gafam epfl httpstcojlgbaxvtkj',
#  'aurelberra frederickaplan campus règles varient entre epfl unil aussi sein chaque faculté unil',
#  'epfls robotic eel detects water pollutants internet business switzerland httpstcoluzvtvhqzm',
#  'lili bêche bien chez oncle ferdinand nestor napoleon mange allègrement six poulet sans claquer dargent',
#  'talk sex power johnantonakis epfl',
#  'newsletter robotique epfl septembre là inscrivezvous profitez activites httpstcojokzxoverh',
#  'oblivious ride encryption system hides travel data uber epfl ht',
#  'mscactions esr imane bartek epfl presented research work research day epflenac enacresearchday',
#  'traces possible martian biological activity inside meteorite oscience epflen mars',
#  'covestrogroup imdeanano epflen ujinoticias imperialcollege lot european institutions industries indeed congrats',
#  'proud see epflen top international universities ethen httpstcoxxxszgejwt via philbaty timeshighered',
#  'read wikipedia leila zia joint work progress gesisorg epfl stanford wikipedia readership httpstcoockxeddtcn',
#  'rosicrucioprotestant cardinaldolan took piss traditionalcatholic fatherjenkins trumpinauguration',
#  'practical steps institution take make progress openaccess journey',
#  'marcelsalathe back tried recruit said thanks thanks maybe hasty analysis puzzled sure reply got led think employee didnt really understood meant work',
#  'rlerignier sneedition doit bien avoir ressources quelque part premier standard csl zotero droit français',
#  'martinvetterli epflen epfl congratulations wishing much success martindahinden',
#  'get hands dirty making fast slow workshop thursday spots left epfl',
#  'lorsque lintelligence artificielle compose mélodies authentiques epfl robot',
#  'gene behind follicularlymphoma epflen sciencetm',
#  'university cargobike sharing lausanne epfl httpstcovcqxjwcrfr',
#  'fox foundation research funding epfl michaeljfoxorg',
#  'tuesday join us free mfe practitioner seminar epfl investglass bigdata roboadvisor epfl',
#  'impressionnante présentation activités centre neuroprothèses epfl',
#  'rewards long reviewing process bürgi al epfl helped understand raredisease well done',
#  'swisslitho epflen make nanopatterns silicon thermal scanning probe lithography nanofabrication httpstcoptubxymebp',
#  'board swiss federal institutes technology announced appointment three professors epfl',
#  'arrived seedstarssummit epfl salad nespresso disruptive disconcerting coffee break look fwd plenary excitement',
#  'latest lîlot dashdawai epfl',
#  'direct periscope getting kicked jordimontserrat aitcamp epfl httpstcojogvkdfeln',
#  'andrisilbi ich würde meinen exzellenz zahlt sich aus glückwunsch eth félicitations epfl',
#  'migration vers saphana epfl projet réussi accompagné teamwork casestudy témoignage',
#  'woman epfl',
#  'last thing would want palantir private sv data mining corporation owned peter thiel anywhere near even single bit digital identity httpstcorssxorvwmg',
#  'janvier lieu enssib conférence europe doit construire première time machine frederickaplan professeur humanités numériques epfl directeur digital humanities lab programme inscription ligne numérique',
#  'check new paper internal structure dynamics chromatin fibers revealed singlemolecule fret modulated naturecomms epfl',
#  'przemek kornatowski sharing experience good practices opening startup still working academia drones epfl',
#  'lauréats prix durabilis concours travaux durabilité étudiant e unil epfl unildurable',
#  'comment vaches sadapterontelles changement climatique httpstcooxyrjroudp stéphane joost epfl',
#  'proud announce startup chosen take part innosuisse winter startup camp cohort san francisco usa see soon swissnexsf swissnex innosuisse sanfrancisco smartparking smartmobility smartcity ethspinoff swissstartups',
#  'epfl morning epfl lausanne photography',
#  'calculating emissions biofuels enough epflen biofuels psd',
#  'today osaopex researchers epflen develop opticalfiber could lead using repair damaged tissue via opticalsociety eurekalert',
#  'conférence géothermie surface développements architecturaux urbains souterrain juin epfl',
#  'danish school installs world largest solar façade epflen copenhagen switzerland clean energy green',
#  'interessanter artikel von mirkobischberg epfl aus texas virtualreality science arts evolution der maschinen',
#  'fantastic primates regain control paralyzed limb via epflen vdtech',
#  'silent accurate century mechanicclock epfl unveiled neuchatel city hall',
#  'therapeutic robots may soon assist patients stroke via riarobotics ft mit epflen httpstcofpkkytclij',
#  'great event opportunity network next week rolex center epflen see meilleurduwebch httpstcoupvwgqkpez',
#  'epfl president martinvetterli speaking tonight competition kickoff epflen rolex learning center httpstcowsosmmrtbl',
#  'sandec next mooc public health engineering humanitarian contexts starts nov epfl icrc',
#  'lausanne riponne comment valoriser mieux places villes jchenal epfl',
#  'lausanne riponne comment valoriser mieux places villes httpstcosyqnwjmzzx jchenal epfl',
#  'effets nanoparticules cellules immunitaires humaines former mieux comprendre enjeux liés sécurité nanoobjets nanoparticules formation epfl nanonmatériaux',
#  'elliottrhams winstonmeiiis send envelope swiss policevalais help take racist torturing sexual pervert like oskarfreysinger whose police rape year old boys dont get investigated even found child porn police laptop less switzerland nazis epfl unifr metoo',
#  'footersis fhll lausanne end solutionssolar lab development',
#  'epfl go read campaign election',
#  'spaces available sign sdscdatascience epflen datajamdays datascience opendata',
#  'jouer musée cest nouveau ça venez découvrir prototypes heures epflartlab museomixch epfl',
#  'want overview eight sdscdatascience exciting projects starting fall collaboration eth domain institutes ethen epflen empach psichen wslresearch eawagresearch datascience',
#  'epfl students get handson experience made china epfl',
#  'new article epfl team systematically studies impact operation conditions degradation perovskite solarcells read free httpstcovbgwifasea',
#  'strongly encourage anyone epflen apply pm want info event went last year fantastic ping epfllibrary',
#  'epfl veuillez retirer zizi vue où dénonce manif tous',
#  'président jcangelini accueille représentants epfl portivechju jours',
#  'join us april startup champions seed night epfl showcasing worldclass startups champsnight',
#  'final day looking forward insectmicrobe session',
#  'swisstech convention center lausanne looking ahead todays uefa nationsleague draw watch live cet',
#  'juristes utilisez guide citation références juridiques reflex sneedition références bibliographie',
#  'congrats epflen',
#  'still wondering best engineering universities world ethen epflen top thinkswiss',
#  'merci martinvetterli soutien création dun campus carboneutre lhorizon campus durable epfl déjà travail afin datteindre cet objectif très ambitieux',
#  'healthy mitochondria could stop alzheimers via epflen vdtech research',
#  'soon starting',
#  'conference going awesome really excited teach workshop days machinelearning datascience',
#  ...]

# %%
' '.join(documents)
# Out:
# 'congrats ethen place epflen place thats standing ovation epflen time open farms pitch openfood opendata epfl good opportunity ethen epflen epflpark uzhnewsen exciting news world university rankings subject computer science eth epfl congrats httpstcoarslxzoshq epfl cryptotokenize free energy httpstcozyenraseir get rich scientists discover hidden patterns brain activity httpstcohblrytdmtt epfl edacyhq edacy invest deadline breast cancer research funding epfl againstbc robots transform furniture epfl november kamiahok microsoft president bradsmi epfl ebugnion digitalgenevaconvention digitaltrust important topics ethrat epflen atelier travail future traversée rade geneve cantongeneve epfl hslu etc hesso hei hepia heiafr formidable fan projet time machine donc possible revoir conférence chaîne youtube si jai bien lu précédents commentaires merci signaler quand cette dernière ligne archives numerique members wef global university leaders forum including switzerlands ethen epflen responsible large proportion world scientific publications new study reveals switzerland working hard keep best brjsa robotics srindustryday free yoga event hosted indian students epfl lausanne ambassador gill cdmissionindia attend unil myswitzerlandf epflen httpstcoxnciwuqcxw aviation suisse désormais centre recherche aéronautique zhaw hsgstgallen epfl via swissinfofr scirobotics live facebook watch epflen engineers show versatile vacuumpowered robots countries switzerland interesting laboratory epfl fantastic explanation blockchain blockchain fintech startup epflen swissborg cltucci présentation nouveau guide robotique éducation cours formation thymioii hep fmondada epfl would trust doctor human one marcelsalathe epflen listens humans compete aihealth swsx nice animation fourthrevolution luciano floridi uniofoxford agepoly epflen epfl epfl moocs two million registered users switzerland traces possible martian biological activity inside meteorite oscience epflen mars ehre für schweizer vmwaremitgründer ebugnion herzliche gratulation epfl etre bien positionné départ clef merci bravo epfl ménage efforts matière contribuant prospérité compétitivité modernité pays long terme join mediaroad team talk media innovation experts march geneva upcoming event organized epfl takes fakenews socialmedia data epfl sv bms brain mind institute symposium summer stress health disease switzerland cyclometalated ruthenium complexes dyesensitized solar cells epfl new epflen life sciences epflsv phd directly independent group leader elfirepfl early independence research scholars see also computational biology compbio deadline april httpstcomjqcrfiqkb ecorobotix presents development weeding robot epfl start conference epfl douglas hanahan isrec epfl giving final closing lecture microenvironmental determinants invasion metastasts lornecancer cancer metastasis nottheashleydunnoration applied machine learning days main event kicking epfl practitioners house cisco proud sponsor ml tutorial timeseries sequence data apachemxnet gluon plenty introductory materials deeplearning timeseries presented appliedmldays epfl sestrin identified epflen researchers gene frequently missing mutated follicular lymphoma colorselective versatile light steering w upscalable subwavelength planar optics cseminfo epflen mobile crowdsourcing epflen campus paulg come epflen hardworking students march geneve smart city aujourdhui demain unigenews siggeneve epflen secheronsa plrge jimharris epfls campus worlds first solar window epfl enroll free epflen iucn mooc ecological monitoring essential protected areas ecology celebrating nobelprize winner jaques dubochet unil lausanne vaud proud heclausanne epfl epfl valais bourse trois millions étudier avc switzerland possible film quantum mechanics paradoxical nature directly light photographed wave particle first time via epflen epfl researchers observed weather process previously known occur antarctica via epflen ict conf lausanne join us ict rural circular digital p ...

# %% [markdown]
# ### 1.2. Build the vocabulary by selecting top-k frequent words

# %%
def create_vocabulary_frequency(corpus, vocab_len):
    '''Select top-k (k = vocab_len) words in term of frequencies as vocabulary'''
    
    count = {} # dictionary that contains the frequency of each word count[word] = freq
    for document in corpus:
        for word in document.split():
            
            # YOUR CODE HERE
    
    sorted_count_by_freq = sorted(count.items(), key=lambda kv: kv[1], reverse=True)
    vocabulary = [x[0] for x in sorted_count_by_freq[:vocab_len+1]]
    
    return vocabulary

# %%
vocab_freq = create_vocabulary_frequency(documents, 1000)

# %% [markdown]
# ### 1.3. Construct the term document matrix
# In this question, you need to construct the term document matrix given the vocabulary and the set of documents.
# The value of a cell (i, j) is the term frequency of the term i in document j.

# %%
def construct_term_document_matrix(vocabulary, documents):
    matrix = np.zeros((len(vocabulary), len(documents)))
    for j, document in enumerate(documents):
        counter = Counter(document.split())
        for i, word in enumerate(vocabulary):
            
            # YOUR CODE HERE
            
    return matrix

# %%
term_doc_matrix_freq = construct_term_document_matrix(vocab_freq, documents)

# %% [markdown]
# ### 1.4. Perform LSI by selecting the first 100 largest singular values of the term document matrix
# Hint 1: np.linalg.svd(M, full_matrices=False) performs SVD on the matrix $\mathbf{M}$ and returns $\mathbf{K}, \mathbf{S}, \mathbf{D}^T$
#
#  -  $\mathbf{K}, \mathbf{D}^T$ are matrices with orthonormal columns
#  -  $\mathbf{S}$ is a **vector** of singular values in a **descending** order
#
# Hint 2: np.diag(V) converts a vector to a diagonal matrix
#
# Hint 3: To select
#  - The first k rows of a matrix A, use A[0:k, :]
#  - The first k columns of a matrix A, use A[:, 0:k]
#  - The submatrix from first k rows and k columns of a matrix A, use A[0:k, 0:k]

# %%
# Input: a term document matrix and the number of singular values that will be selected
# Output: K_s, S_s, Dt_s are similar to the defintion in the lecture
def truncated_svd(term_doc_matrix, num_val):
    
    # YOUR CODE HERE
    
    return K_sel, S_sel, Dt_sel

# %%
K_freq, S_freq, Dt_freq = truncated_svd(term_doc_matrix_freq, 100)

# %% [markdown]
# ### 1.5. Transform the given query
# In this question, you need to construct a vector representation for the following query:

# %%
query = ['epfl']

# %%
def query_to_document_vector(query, vocabulary):
    vector = np.zeros(len(vocabulary))
    for word in query:
        try:
            
            # YOUR CODE HERE
            
        except:
            # if query word is not in vocabulary, ignore it
            pass
    return vector

# %% [markdown]
# Hint:
#  -  To compute inverse of a matrix M, use np.linalg.inv(M)
#  -  To compute the dot product of A, B, use np.dot(A,B)

# %%
def construct_query_vector(query, vocabulary, K_s, S_s, Dt_s):
    q = query_to_document_vector(query, vocabulary)
    
    # YOUR CODE HERE
    
    return q_trans

# %%
query_vector_freq = construct_query_vector(query, vocab_freq, K_freq, S_freq, Dt_freq)

# %% [markdown]
# ### 1.6. Retrieve top-10 relevant documents
# In this question, you need to retrieve the top-10 documents that are relevant to the query using cosine similarity. You are given a function to compute the cosine simimlarity and a function that return the top-k documents given the query and document vectors.

# %%
def cosine_similarity(v1, v2):
    sumxx, sumxy, sumyy = 0, 0, 0
    for i in range(len(v1)):
        x = v1[i]; y = v2[i]
        sumxx += x*x
        sumyy += y*y
        sumxy += x*y
    return sumxy*1.0/math.sqrt(sumxx*sumyy)

# %%
def retrieve_documents(query_vector, top_k, Dt_sel):
    scores = [[cosine_similarity(query_vector, Dt_sel[:,d]), d] for d in range(len(documents))]
    scores.sort(key=lambda x: -x[0])
    doc_ids = []
    retrieved = []
    for i in range(top_k):
        doc_ids.append(scores[i][1])
        retrieved.append(orig_docs[scores[i][1]])
    return doc_ids, retrieved

# %% [markdown]
# Fill in the correct parameters in the following function

# %%
retrieved_ids_freq, retrieved_docs_freq = retrieve_documents(# YOUR PARAMETERS HERE)
pprint(retrieved_docs_freq)

# %% [markdown]
# ## Part2: Evaluation
# In this question, we consider the scikit reference code as an “oracle” that supposedly gives the correct result. You need to compare your retrieval results with this oracle using the F1-score.

# %%
# Retrieval oracle 
tf = TfidfVectorizer(analyzer='word', ngram_range=(1,1), vocabulary=vocab_freq, min_df = 1, stop_words = 'english')
features = tf.fit_transform(documents)
npm_tfidf = features.todense()

# Return all document ids that that have cosine similarity with the query larger than a threshold
def search_vec_sklearn(query, features, threshold=0.3):
    new_features = tf.transform([query])
    cosine_similarities = linear_kernel(new_features, features).flatten()
    related_docs_indices, cos_sim_sorted = zip(*sorted(enumerate(cosine_similarities), key=itemgetter(1), 
                                                       reverse=True))
    doc_ids = []
    for i, cos_sim in enumerate(cos_sim_sorted):
        if cos_sim < threshold:
            break
        doc_ids.append(related_docs_indices[i])
    return doc_ids

# %%
# gt_ids are the document ids retrieved by the oracle
gt_ids = search_vec_sklearn(" ".join(query), features)

# %% [markdown]
# ### 2.1. Compute F1-score at 10 between the oracle and your result

# %%
def compute_recall_at_k(predicted, oracle, k):
    
    # YOUR CODE HERE
    
    return recall

# %%
def compute_precision_at_k(predicted, oracle, k):
    
    # YOUR CODE HERE
    
    return precision

# %%
def f1score(predicted, oracle, k):
    
    # YOUR CODE HERE
    
    return f1

# %%
f1score(retrieved_ids_freq, gt_ids, 10)

# %% [markdown]
# ## Part3. Visualization
# Plot the terms using two principal concepts

# %% [markdown]
# ### 3.1. Compute the term vectors using two principal concepts
# Hint: you can reuse a method from the above

# %%
# term_vecs_freq is a matrix of size (num_terms, 2)
term_vecs_freq = # YOUR CODE HERE

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import *

plt.scatter(term_vecs_freq[:, 0], term_vecs_freq[:, 1])
for i, t in enumerate(vocab_freq):
    plt.annotate(t, (term_vecs_freq[i, 0], term_vecs_freq[i, 1]))
plt.show()

# %% [markdown]
# ### 3.2. Explain the scatter plot of the term vectors

# %% [markdown]
# Hint: Do you see any outliers? What is a possible explanation?

# %% [markdown]
# *YOUR ANSWER HERE*
