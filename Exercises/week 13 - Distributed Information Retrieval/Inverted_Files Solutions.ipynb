# %% [markdown]
# ## 📚 Exercise 2: Inverted Files - SOLUTIONS
#
# In this exercise, we will understand the functioning of the Inverted Files and how implement them using MapReduce.
#
# ### Overview
#
# We learnt in the lecture that terms are typically stored in an inverted list. Now, in the inverted list, instead of only storing document identifiers of the documents in which the term appears, assume we also store an *offset* of the appearance of a term in a document. An $offset$ of a term $l_k$ given a document is defined as the number of words between the start of the document and $l_k$. Thus our inverted list is now:
#
# $l_k= \langle f_k: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# \{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# \{d_{i_k} \rightarrow [o_1,\ldots,o_{n_{i_k}}]\} \rangle$
#
# This means that in document $d_{i_1}$ term $l_k$ appears $n_{i_1}$ times and at offset $[o_1,\ldots,o_{n_{i_1}}]$, where $[o_1,\ldots,o_{n_{i_1}}]$ are sorted in ascending order, these type of indices are also known as term-offset indices. An example of a term-offset index is as follows:
#
# **Obama** = $⟨4 : {1 → [3]},{2 → [6]},{3 → [2,17]},{4 → [1]}⟩$
#
# **Governor** = $⟨2 : {4 → [3]}, {7 → [14]}⟩$
#
# **Election** = $⟨4 : {1 → [1]},{2 → [1,21]},{3 → [3]},{5 → [16,22,51]}⟩$
#
# Which is to say that the term **Governor** appear in 2 documents. In document 4 at offset 3, in document 7 at offset 14. Now let us consider the *SLOP/x* operator in text retrieval. This operator has the syntax: *QueryTerm1 SLOP/x QueryTerm2* finds occurrences of *QueryTerm1* within $x$ (but not necessarily in that order) words of *QueryTerm2*, where $x$ is a positive integer argument ($x \geq 1$). Thus $x = 1$ demands that *QueryTerm1* be adjacent to *QueryTerm2*.
#
# ### Questions
#
# 1. List the set of documents that satisfy the query **Obama** *SLOP/2* **Election**.
# 2. List each set of values for which the query **Obama** *SLOP/x* **Election** has a different set of documents as answers (starting from $x = 1$).
# 3. Consider the general procedure for "merging" two term-offset inverted lists for a given document, to determine where the document satisfies a *SLOP/x* clause (since in general there will be many offsets at which each term occurs in a document). Let $L$ denote the total number of occurrences of the two terms in the document. Assume we have a pointer to the list of occurrences of each term and can move the pointer along this list. As we do so we check whether we have a hit for $SLOP/x$ (i.e. the $SLOP/x$ clause is satisfied). Each move of either pointer counts as a step. Based on this assumption is there a general "merging" procedure to determine whether the document satisfies a $SLOP/x$ clause, for which the following is true? Justify your answer.
#
#     1. The merge can be accomplished in a number of steps linear in $L$ regardless of $x$, and we can ensure that each pointer moves only to the right (i.e. forward).
#     2. The merge can be accomplished in a number of steps linear in $L$, but a pointer may be forced to move to the left (i.e. backwards).
#     3. The merge can require $x \times L$ steps in some cases.
#
# **Solution in pdf.**

# %% [markdown]
# ## Create inverted files using MapReduce
# In this exercise, we want to create the inverted files using the MapReduce framework. Write the **map** and **reduce** function.
# Note that the code of **run_mapreduce** is just a simulation of the behavior of  map-reduce system.
#
# ## Goal:
# - Create inverted files using the MapReduce framework.
# - Test the implementation on `epfldocs.txt` data.
#
# ### What you are learning in this exercise:
# - Having a better understanding of inverted files.
# - Learn how to implement inverted files using the MapReduce framework.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
import numpy as np
nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()

# Tokenize, stem a document
def tokenize(text):
    """
    It tokenizes and stems an input text.
    
    :param text: str, with the input text
    :return: list, of the tokenized and stemmed tokens.
    """
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d).split() for d in original_documents]
docs_n_doc_ids = list(zip(range(len(documents)), documents))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anandchoudhary/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/anandchoudhary/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#MAP
m = (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
mmap = map(lambda x: (x,m[0]), m[1])
list(mmap)
# Out:
# [('how', 0),
#  ('to', 0),
#  ('bake', 0),
#  ('bread', 0),
#  ('without', 0),
#  ('bake', 0),
#  ('recip', 0)]

# %%
# Take a pair (doc_id, content). Example: (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
#Return: list of (word, doc_id). Example: ('bake', 0)
# For simplicity, we assume each mapper handles a document
def map_function(doc_id, content):
    keyvals = []
    for word in content:
        keyvals.append((word, doc_id))
    return keyvals

# %%
map_function(m[0],m[1])
# Out:
# [('how', 0),
#  ('to', 0),
#  ('bake', 0),
#  ('bread', 0),
#  ('without', 0),
#  ('bake', 0),
#  ('recip', 0)]

# %%
#REDUCE
m2 = [('bake', 0), ('bake', 0), ('bake', 3)]
mmap2 = list(map(lambda x: x[1],m2))
mmap2 = (m2[0][0],len(mmap2),mmap2)
mmap2
# Out:
# ('bake', 3, [0, 0, 3])

# %%
# Take a list of pairs (word, doc_id). Example:  [('bake', 0), ('bake', 0), ('bake', 3)]
# Return: (word, frequency, list of document ids). Example ('bake', 3, [0, 0, 3])
# For simplicity, we assume each reducer handles a word
def reduce_function(lst):
    total = 0
    word = lst[0][0]
    doc_ids = []
    for w, doc_id in lst:
        assert(word==w)
        total += 1
        doc_ids.append(doc_id)
    return (word,total, doc_ids)

# %%
# We simulate the mapreduce framework by this function
def run_mapreduce(docs_n_doc_ids):
    # Map phase
    key_values = []
    for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
    # Shuffle phase
    values = set(map(lambda x:x[0], key_values))
    grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
    # Reduce phase
    inverted_files = []
    for grouped_key_value in grouped_key_values:
        word, total, doc_ids = reduce_function(grouped_key_value)
        inverted_files.append((word, total, doc_ids))
    return inverted_files

# %%
run_mapreduce(docs_n_doc_ids)
# Out:
# [('httpstcohpfqgy1yuf', 1, [304]),
#  ('httpstcos6uszeucpm', 1, [907]),
#  ('pecub', 1, [1035]),
#  ('award',
#   13,
#   [48, 77, 137, 179, 230, 237, 293, 380, 403, 434, 489, 688, 767]),
#  ('neuen', 2, [188, 822]),
#  ('ug', 1, [1011]),
#  ('impressionnant', 1, [947]),
#  ('étoil', 1, [665]),
#  ('httpstcoulurhrsqwi', 1, [353]),
#  ('epflalumni', 2, [490, 1017]),
#  ('avoir', 2, [752, 939]),
#  ('biomedia', 1, [176]),
#  ('bruit', 2, [571, 571]),
#  ('httpstcoy3ixctmmey', 1, [1024]),
#  ('teashop', 1, [192]),
#  ('trump', 3, [556, 620, 1054]),
#  ('verantwortung', 1, [105]),
#  ('dexpo', 1, [194]),
#  ('httpstcotfckevyktq', 1, [89]),
#  ('sdg', 1, [1007]),
#  ('sportscrunchind', 1, [291]),
#  ('childcar', 2, [60, 308]),
#  ('exoplanet', 1, [768]),
#  ('line', 4, [93, 589, 686, 1061]),
#  ('amélior', 1, [149]),
#  ('temperatur', 1, [769]),
#  ('meetlausann', 1, [744]),
#  ('itenova', 1, [530]),
#  ('mountain', 3, [358, 526, 836]),
#  ('httpstcozxoxqotnii', 1, [714]),
#  ('codeweekch', 1, [333]),
#  ('the',
#   400,
#   [13,
#    13,
#    13,
#    14,
#    27,
#    27,
#    27,
#    31,
#    31,
#    32,
#    33,
#    40,
#    41,
#    44,
#    57,
#    60,
#    65,
#    65,
#    69,
#    71,
#    77,
#    80,
#    80,
#    80,
#    84,
#    87,
#    89,
#    95,
#    95,
#    95,
#    98,
#    98,
#    101,
#    103,
#    103,
#    104,
#    106,
#    108,
#    108,
#    108,
#    109,
#    121,
#    124,
#    125,
#    126,
#    126,
#    126,
#    134,
#    135,
#    136,
#    137,
#    139,
#    139,
#    141,
#    141,
#    148,
#    150,
#    150,
#    150,
#    154,
#    158,
#    158,
#    164,
#    175,
#    175,
#    178,
#    180,
#    180,
#    187,
#    187,
#    189,
#    191,
#    191,
#    195,
#    196,
#    203,
#    212,
#    215,
#    218,
#    221,
#    223,
#    223,
#    225,
#    228,
#    230,
#    232,
#    232,
#    236,
#    237,
#    237,
#    245,
#    245,
#    245,
#    254,
#    255,
#    257,
#    257,
#    260,
#    264,
#    269,
#    270,
#    272,
#    272,
#    275,
#    276,
#    278,
#    278,
#    288,
#    290,
#    293,
#    294,
#    295,
#    296,
#    298,
#    301,
#    301,
#    303,
#    306,
#    306,
#    310,
#    312,
#    328,
#    334,
#    339,
#    339,
#    341,
#    341,
#    343,
#    346,
#    364,
#    364,
#    375,
#    375,
#    380,
#    381,
#    386,
#    390,
#    390,
#    393,
#    393,
#    400,
#    407,
#    407,
#    409,
#    410,
#    410,
#    411,
#    412,
#    413,
#    413,
#    416,
#    418,
#    419,
#    419,
#    422,
#    427,
#    428,
#    434,
#    435,
#    441,
#    444,
#    447,
#    449,
#    455,
#    455,
#    457,
#    459,
#    459,
#    460,
#    461,
#    464,
#    464,
#    466,
#    468,
#    469,
#    474,
#    480,
#    481,
#    485,
#    485,
#    485,
#    486,
#    487,
#    491,
#    496,
#    497,
#    499,
#    501,
#    502,
#    504,
#    504,
#    506,
#    512,
#    512,
#    512,
#    512,
#    513,
#    519,
#    527,
#    531,
#    533,
#    533,
#    534,
#    536,
#    537,
#    541,
#    547,
#    550,
#    552,
#    557,
#    559,
#    560,
#    562,
#    563,
#    564,
#    572,
#    572,
#    573,
#    575,
#    575,
#    575,
#    577,
#    579,
#    586,
#    589,
#    589,
#    591,
#    594,
#    597,
#    598,
#    600,
#    601,
#    601,
#    601,
#    601,
#    605,
#    606,
#    607,
#    607,
#    612,
#    613,
#    614,
#    620,
#    622,
#    623,
#    624,
#    624,
#    626,
#    629,
#    632,
#    634,
#    639,
#    640,
#    641,
#    641,
#    643,
#    645,
#    646,
#    649,
#    655,
#    655,
#    656,
#    667,
#    669,
#    669,
#    669,
#    671,
#    671,
#    672,
#    674,
#    677,
#    679,
#    685,
#    686,
#    688,
#    691,
#    696,
#    697,
#    698,
#    699,
#    699,
#    703,
#    703,
#    703,
#    704,
#    704,
#    711,
#    718,
#    719,
#    724,
#    724,
#    724,
#    725,
#    726,
#    730,
#    732,
#    736,
#    736,
#    741,
#    741,
#    743,
#    746,
#    747,
#    747,
#    748,
#    748,
#    749,
#    755,
#    759,
#    759,
#    759,
#    760,
#    760,
#    762,
#    762,
#    762,
#    767,
#    767,
#    770,
#    770,
#    776,
#    776,
#    778,
#    786,
#    787,
#    787,
#    790,
#    790,
#    804,
#    804,
#    807,
#    808,
#    817,
#    818,
#    830,
#    831,
#    846,
#    850,
#    858,
#    859,
#    863,
#    865,
#    865,
#    868,
#    871,
#    873,
#    875,
#    878,
#    883,
#    884,
#    887,
#    898,
#    899,
#    903,
#    905,
#    908,
#    910,
#    917,
#    918,
#    919,
#    931,
#    934,
#    936,
#    937,
#    938,
#    938,
#    943,
#    944,
#    948,
#    950,
#    950,
#    950,
#    952,
#    957,
#    959,
#    963,
#    965,
#    971,
#    973,
#    979,
#    981,
#    984,
#    987,
#    990,
#    991,
#    992,
#    995,
#    999,
#    1003,
#    1003,
#    1005,
#    1008,
#    1012,
#    1013,
#    1013,
#    1014,
#    1032,
#    1056,
#    1056,
#    1060]),
#  ('w', 8, [36, 88, 106, 138, 196, 400, 555, 784]),
#  ('thank',
#   27,
#   [108,
#    113,
#    218,
#    232,
#    245,
#    247,
#    259,
#    307,
#    315,
#    337,
#    341,
#    353,
#    399,
#    446,
#    460,
#    496,
#    516,
#    522,
#    552,
#    724,
#    747,
#    764,
#    810,
#    938,
#    938,
#    1002,
#    1005]),
#  ('atomtron', 1, [431]),
#  ('age', 4, [184, 186, 508, 833]),
#  ('1315th', 1, [102]),
#  ('healthcar', 1, [897]),
#  ('lymph', 1, [696]),
#  ('inject', 1, [303]),
#  ('lintellig', 2, [118, 942]),
#  ('anim', 2, [22, 149]),
#  ('molsystbiol', 1, [629]),
#  ('read',
#   13,
#   [109, 109, 150, 236, 262, 278, 546, 550, 577, 820, 935, 981, 986]),
#  ('conférenc', 7, [12, 243, 633, 782, 958, 967, 1048]),
#  ('eu', 5, [18, 71, 319, 556, 965]),
#  ('httpstcoarslxzoshq', 1, [4]),
#  ('hwurcc', 1, [575]),
#  ('stellar', 1, [269]),
#  ('onlythegood', 2, [802, 915]),
#  ('sexualharass', 1, [163]),
#  ('blond', 1, [746]),
#  ('10th', 2, [0, 859]),
#  ('cosandey', 1, [360]),
#  ('wieder', 1, [701]),
#  ('httpstcojlnocxclmg', 1, [868]),
#  ('httpstcolyyuk5w3yp', 1, [150]),
#  ('crucial', 1, [548]),
#  ('möglich', 1, [701]),
#  ('autonom', 2, [292, 1008]),
#  ('httpstco6eo2nbfqg0', 1, [327]),
#  ('cold', 1, [661]),
#  ('human',
#   20,
#   [21,
#    21,
#    84,
#    107,
#    114,
#    198,
#    290,
#    292,
#    324,
#    352,
#    507,
#    613,
#    647,
#    692,
#    692,
#    768,
#    832,
#    850,
#    866,
#    958]),
#  ('inspect', 1, [53]),
#  ('renew', 1, [442]),
#  ('smartgrid', 1, [510]),
#  ('exoskeleton', 2, [486, 871]),
#  ('gründet', 1, [384]),
#  ('httpstcob2tct924cp', 1, [160]),
#  ('neg', 1, [103]),
#  ('swisstech', 1, [992]),
#  ('httpstcocmujlvakjl', 1, [422]),
#  ('gainde2000', 1, [559]),
#  ('mechdev', 1, [607]),
#  ('pattaroni', 1, [1069]),
#  ('parti', 2, [592, 875]),
#  ('condit', 1, [986]),
#  ('lornecanc', 1, [32]),
#  ('gehendragurung', 1, [350]),
#  ('campus…', 1, [326]),
#  ('httpstcosca1n4ayuq', 1, [624]),
#  ('😷😝', 1, [919]),
#  ('giulia', 1, [633]),
#  ('particl', 5, [44, 328, 527, 754, 908]),
#  ('26th', 1, [447]),
#  ('usd', 1, [499]),
#  ('httpstconum7njo85j', 1, [450]),
#  ('httpstcoepymyqckzw', 1, [1048]),
#  ('avril', 2, [633, 894]),
#  ('flyabil', 1, [1036]),
#  ('httpstcowsnmjekhmo', 1, [770]),
#  ('sciencevalai', 1, [743]),
#  ('lch', 1, [400]),
#  ('httpstco9d256rj7ct', 1, [769]),
#  ('cholera', 1, [738]),
#  ('theyll', 1, [269]),
#  ('molecul', 1, [547]),
#  ('relat', 1, [103]),
#  ('embarqu', 1, [1025]),
#  ('➡️httpstcofek8vok2dn', 1, [878]),
#  ('etudesantedusoir', 2, [266, 1031]),
#  ('🎉', 2, [341, 719]),
#  ('nestl', 1, [522]),
#  ('turn', 4, [333, 360, 396, 722]),
#  ('worldvrforum', 1, [247]),
#  ('yourself', 3, [7, 50, 260]),
#  ('httpstcomjqcrfiqkb', 1, [30]),
#  ('httpstcoy2s3hz1817', 1, [796]),
#  ('cisco', 1, [33]),
#  ('jattali', 1, [827]),
#  ('cryo', 1, [526]),
#  ('usa', 2, [963, 1067]),
#  ('restitut', 1, [63]),
#  ('laupm', 1, [709]),
#  ('swissstartup', 2, [102, 963]),
#  ('shashank', 1, [748]),
#  ('httpstcoszzjjmc71', 1, [770]),
#  ('greater', 1, [754]),
#  ('listen', 1, [21]),
#  ('forget', 1, [90]),
#  ('idiapch', 1, [507]),
#  ('fischerconnect', 1, [492]),
#  ('dmp', 1, [756]),
#  ('poster', 6, [77, 97, 434, 484, 642, 807]),
#  ('scientif', 2, [13, 103]),
#  ('httpstcokjzgnss9y0', 1, [265]),
#  ('httpstcoun7wlrhkna', 1, [156]),
#  ('httpstco462ghoecml', 1, [1033]),
#  ('httpstcodcuyrn9fng', 1, [606]),
#  ('ecologi', 1, [644]),
#  ('trekkinglemon', 2, [60, 310]),
#  ('vol', 1, [345]),
#  ('worldbrailleday', 1, [878]),
#  ('httpstcovhhnid4xqm', 1, [944]),
#  ('cours', 6, [165, 493, 515, 600, 790, 798]),
#  ('past', 1, [296]),
#  ('httpstconavczrnhl3', 1, [1053]),
#  ('ye', 1, [664]),
#  ('oset2017', 1, [329]),
#  ('zurich', 7, [107, 200, 391, 759, 767, 844, 873]),
#  ('directeur', 3, [182, 304, 958]),
#  ('httpstcocbsxy8wduh', 1, [252]),
#  ('httpstcodkgmxia7tq', 1, [985]),
#  ('httpstcopqslfajac', 1, [289]),
#  ('take',
#   17,
#   [27,
#    125,
#    137,
#    341,
#    422,
#    613,
#    628,
#    719,
#    765,
#    772,
#    873,
#    886,
#    937,
#    963,
#    979,
#    1004,
#    1009]),
#  ('httpstco7wrh9tmlak', 1, [627]),
#  ('eight', 1, [984]),
#  ('thi',
#   38,
#   [58,
#    64,
#    66,
#    75,
#    103,
#    142,
#    151,
#    236,
#    240,
#    260,
#    267,
#    273,
#    278,
#    340,
#    374,
#    483,
#    516,
#    526,
#    576,
#    577,
#    585,
#    691,
#    717,
#    764,
#    765,
#    770,
#    802,
#    812,
#    816,
#    845,
#    869,
#    886,
#    909,
#    941,
#    946,
#    984,
#    999,
#    1002]),
#  ('microbiolog', 1, [378]),
#  ('far', 1, [834]),
#  ('insectmicrob', 1, [991]),
#  ('httpstconr3dbkmysp', 1, [399]),
#  ('doesnt', 1, [1002]),
#  ('photographi', 3, [202, 325, 964]),
#  ('epuck', 1, [343]),
#  ('httpstcohpzanzzkzi', 1, [900]),
#  ('foe', 1, [270]),
#  ('takahama', 1, [88]),
#  ('grâce', 1, [882]),
#  ('digit', 12, [46, 226, 316, 525, 573, 640, 643, 820, 863, 957, 958, 1032]),
#  ('cciliv', 3, [80, 100, 685]),
#  ('httpstcov3tojtyjqd', 1, [3]),
#  ('environ', 4, [104, 171, 292, 442]),
#  ('httpstcohmtp66wt6w', 1, [916]),
#  ('fleshandblood', 2, [216, 634]),
#  ('httpstcoyifg5issu', 1, [746]),
#  ('avril4', 1, [202]),
#  ('httpstcoevlw3kf6v', 1, [998]),
#  ('3', 7, [53, 538, 555, 840, 894, 989, 1064]),
#  ('nou', 4, [51, 197, 282, 610]),
#  ('témoignag', 1, [955]),
#  ('httpstcotaqkhp22jf', 1, [777]),
#  ('view', 3, [99, 310, 335]),
#  ('falsafi', 1, [533]),
#  ('braintovehicl', 1, [387]),
#  ('rejouit', 1, [437]),
#  ('detect', 3, [695, 926, 1008]),
#  ('regierungbw', 3, [1057, 1058, 1059]),
#  ('sxswiss', 5, [50, 198, 580, 581, 722]),
#  ('bra', 1, [584]),
#  ('six', 2, [536, 927]),
#  ('worri', 1, [103]),
#  ('subscrib', 1, [637]),
#  ('prevent', 1, [486]),
#  ('site', 5, [342, 705, 770, 800, 1039]),
#  ('iitmadra', 2, [748, 748]),
#  ('inspector', 1, [163]),
#  ('climatechang', 2, [474, 1025]),
#  ('dashboard', 1, [776]),
#  ('httpstcojcpt6xyjzm', 1, [832]),
#  ('httpstcowb1xbztqqn', 1, [842]),
#  ('unifr', 7, [83, 163, 200, 391, 489, 705, 979]),
#  ('chromatin', 3, [378, 378, 959]),
#  ('1112', 1, [642]),
#  ('down', 5, [173, 307, 719, 736, 854]),
#  ('bepa', 1, [1070]),
#  ('facil', 1, [98]),
#  ('neurosci', 6, [84, 131, 131, 340, 436, 454]),
#  ('musi', 2, [688, 801]),
#  ('theatredevidi', 1, [604]),
#  ('loan', 1, [53]),
#  ('unineuchatel', 1, [402]),
#  ('whipton', 1, [175]),
#  ('1200cet', 1, [992]),
#  ('jesusmessiah7', 1, [52]),
#  ('durabl', 1, [996]),
#  ('most', 12, [139, 187, 308, 407, 589, 631, 632, 759, 817, 903, 912, 934]),
#  ('ca', 2, [475, 475]),
#  ('physicien', 1, [70]),
#  ('softwar', 4, [314, 485, 562, 831]),
#  ('nanocrystallit', 1, [303]),
#  ('sall', 1, [894]),
#  ('👌🏻', 1, [1032]),
#  ('whole', 2, [95, 691]),
#  ('manquer', 1, [902]),
#  ('ailleur', 1, [896]),
#  ('par',
#   22,
#   [157,
#    160,
#    172,
#    197,
#    261,
#    327,
#    382,
#    383,
#    404,
#    495,
#    627,
#    633,
#    651,
#    665,
#    844,
#    862,
#    955,
#    1010,
#    1018,
#    1022,
#    1054,
#    1068]),
#  ('villar', 1, [601]),
#  ('httpstcoe2ogm9ze7v', 1, [992]),
#  ('appoint', 3, [579, 875, 950]),
#  ('httpstco1espabvvxp', 1, [379]),
#  ('oxid', 1, [334]),
#  ('httpstcojb7mkkvqdd', 1, [20]),
#  ('httpstcornarscdjil', 1, [496]),
#  ('number', 1, [519]),
#  ('genet', 1, [494]),
#  ('danss', 1, [1030]),
#  ('laureat', 1, [434]),
#  ('httpstcoehgkchyud6', 1, [183]),
#  ('some',
#   15,
#   [100,
#    100,
#    185,
#    189,
#    262,
#    323,
#    457,
#    458,
#    466,
#    474,
#    640,
#    722,
#    836,
#    937,
#    1056]),
#  ('civil', 1, [842]),
#  ('stefanotempesta', 1, [127]),
#  ('stil', 1, [902]),
#  ('director', 7, [107, 293, 490, 503, 606, 640, 905]),
#  ('httpstcorkcvwo6k2p', 1, [182]),
#  ('martinvetterli',
#   26,
#   [49,
#    57,
#    60,
#    82,
#    263,
#    330,
#    346,
#    369,
#    390,
#    470,
#    477,
#    563,
#    565,
#    573,
#    612,
#    643,
#    652,
#    665,
#    665,
#    672,
#    776,
#    779,
#    819,
#    940,
#    974,
#    996]),
#  ('aprèsmidi', 1, [345]),
#  ('printedelectron', 1, [642]),
#  ('add', 1, [812]),
#  ('httpstco2va71avjyg', 1, [841]),
#  ('luckili', 1, [1013]),
#  ('jobinfoforum', 1, [309]),
#  ('httpstcoihd8nqh1u9', 1, [113]),
#  ('prison', 1, [122]),
#  ('étudiant',
#   16,
#   [81,
#    161,
#    168,
#    197,
#    244,
#    287,
#    403,
#    467,
#    495,
#    687,
#    744,
#    842,
#    862,
#    961,
#    1017,
#    1037]),
#  ('professorship', 1, [850]),
#  ('traditionalcathol', 1, [936]),
#  ('wysssupport', 1, [114]),
#  ('particular', 2, [869, 903]),
#  ('sinspir', 1, [874]),
#  ('shortliv', 1, [66]),
#  ('nicolli', 3, [138, 570, 829]),
#  ('sexualabus', 1, [163]),
#  ('lhumanité', 1, [602]),
#  ('sequenc', 1, [34]),
#  ('sierr', 1, [707]),
#  ('registr', 4, [441, 590, 730, 898]),
#  ('fair', 9, [51, 168, 197, 291, 530, 610, 1039, 1039, 1051]),
#  ('httpstco15wpb7m1bb', 1, [935]),
#  ('tech4dev', 1, [1007]),
#  ('mechatron', 1, [407]),
#  ('tonight', 4, [427, 553, 652, 974]),
#  ('httpstcoum0imlludj', 1, [361]),
#  ('leuga', 1, [1018]),
#  ('httpstcoovcxbizfdj', 1, [466]),
#  ('irak', 1, [1067]),
#  ('httpstco2vdekx9yhv', 1, [341]),
#  ('1717', 1, [513]),
#  ('career', 1, [116]),
#  ('less', 6, [64, 323, 531, 778, 809, 979]),
#  ('httpstcoftcnk40ssm', 1, [948]),
#  ('mustread', 1, [573]),
#  ('maladi', 1, [149]),
#  ('hackathon', 5, [420, 587, 656, 730, 873]),
#  ('httpstcovgetzu1k9z', 1, [323]),
#  ('sciencebiencomm', 1, [393]),
#  ('further', 2, [525, 697]),
#  ('3dprinter', 1, [544]),
#  ('httpstcoztbmsxxp3x', 1, [36]),
#  ('httpstcofhw6avwslu', 1, [525]),
#  ('httpstco9j5gplmcoi', 1, [481]),
#  ('cole', 1, [579]),
#  ('respond', 1, [507]),
#  ('euronew', 1, [419]),
#  ('brighten', 1, [870]),
#  ('httpstcogyvwr4hg0h', 1, [385]),
#  ('httpstcotu6j8j44kl', 1, [42]),
#  ('bluebrain', 1, [796]),
#  ('httpstcogdesyev6cc', 1, [391]),
#  ('artmyn', 1, [849]),
#  ('nationaltrust', 1, [630]),
#  ('httpstcokrppxbgqqk', 1, [537]),
#  ('23rdthing', 1, [678]),
#  ('fit', 1, [286]),
#  ('readi', 5, [189, 554, 772, 786, 859]),
#  ('newdawn', 1, [608]),
#  ('chaîn', 1, [12]),
#  ('session', 5, [223, 294, 393, 468, 991]),
#  ('httpstcoyrndlr6zh0', 1, [187]),
#  ('avc', 1, [43]),
#  ('silent➕accur', 1, [971]),
#  ('salad', 1, [951]),
#  ('httpstcoq7lhmg9bmb', 1, [661]),
#  ('résistent', 1, [543]),
#  ('proprio', 1, [61]),
#  ('besuch', 1, [619]),
#  ('kingconrad', 2, [240, 637]),
#  ('pierr', 2, [741, 837]),
#  ('larchiv', 1, [844]),
#  ('machinelearn', 10, [127, 165, 165, 503, 587, 610, 667, 733, 765, 999]),
#  ('unistra', 1, [334]),
#  ('input', 1, [65]),
#  ('httpstcosx2wyozlpj', 1, [168]),
#  ('funprog', 1, [224]),
#  ('rlerigni', 4, [61, 199, 439, 939]),
#  ('rt', 8, [69, 144, 566, 566, 573, 573, 732, 1029]),
#  ('laserplasma', 1, [164]),
#  ('impost', 2, [249, 414]),
#  ('retinai', 1, [447]),
#  ('exécutif', 1, [63]),
#  ('httpstcoqdj5vmkuwu', 1, [1049]),
#  ('dure', 10, [89, 107, 173, 245, 333, 341, 854, 931, 999, 1013]),
#  ('posent', 1, [823]),
#  ('potenti', 6, [69, 112, 158, 547, 677, 734]),
#  ('even', 10, [110, 111, 134, 278, 355, 556, 620, 811, 957, 979]),
#  ('jetzt', 1, [167]),
#  ('faessler', 1, [552]),
#  ('httpstcon4yqbge3m', 1, [438]),
#  ('energystrategi', 1, [608]),
#  ('epflen',
#   324,
#   [0,
#    1,
#    3,
#    10,
#    13,
#    15,
#    17,
#    19,
#    21,
#    22,
#    24,
#    30,
#    35,
#    36,
#    37,
#    38,
#    39,
#    41,
#    44,
#    45,
#    48,
#    50,
#    53,
#    54,
#    58,
#    64,
#    65,
#    65,
#    67,
#    71,
#    72,
#    73,
#    76,
#    78,
#    79,
#    82,
#    84,
#    89,
#    95,
#    109,
#    110,
#    111,
#    113,
#    114,
#    117,
#    119,
#    120,
#    121,
#    126,
#    127,
#    128,
#    132,
#    139,
#    142,
#    148,
#    152,
#    153,
#    155,
#    156,
#    159,
#    161,
#    169,
#    170,
#    173,
#    177,
#    179,
#    186,
#    187,
#    196,
#    200,
#    206,
#    211,
#    214,
#    215,
#    219,
#    222,
#    225,
#    227,
#    228,
#    238,
#    242,
#    251,
#    254,
#    256,
#    257,
#    258,
#    262,
#    270,
#    271,
#    280,
#    286,
#    288,
#    293,
#    294,
#    295,
#    298,
#    301,
#    312,
#    318,
#    319,
#    321,
#    324,
#    328,
#    332,
#    336,
#    337,
#    339,
#    349,
#    354,
#    355,
#    360,
#    361,
#    364,
#    365,
#    372,
#    376,
#    377,
#    379,
#    389,
#    394,
#    395,
#    398,
#    399,
#    406,
#    410,
#    414,
#    415,
#    418,
#    421,
#    425,
#    426,
#    430,
#    432,
#    434,
#    441,
#    442,
#    443,
#    445,
#    450,
#    457,
#    461,
#    464,
#    465,
#    468,
#    469,
#    473,
#    474,
#    478,
#    480,
#    482,
#    484,
#    486,
#    490,
#    493,
#    499,
#    501,
#    504,
#    505,
#    506,
#    507,
#    508,
#    510,
#    512,
#    513,
#    515,
#    517,
#    522,
#    524,
#    525,
#    527,
#    529,
#    532,
#    534,
#    535,
#    538,
#    539,
#    542,
#    546,
#    549,
#    557,
#    558,
#    562,
#    573,
#    580,
#    581,
#    587,
#    591,
#    593,
#    597,
#    600,
#    601,
#    605,
#    606,
#    608,
#    612,
#    613,
#    615,
#    616,
#    617,
#    620,
#    622,
#    623,
#    624,
#    630,
#    635,
#    639,
#    643,
#    645,
#    646,
#    649,
#    652,
#    656,
#    657,
#    660,
#    661,
#    668,
#    669,
#    670,
#    671,
#    675,
#    678,
#    686,
#    692,
#    693,
#    694,
#    698,
#    699,
#    700,
#    702,
#    703,
#    704,
#    707,
#    708,
#    709,
#    712,
#    717,
#    718,
#    722,
#    725,
#    732,
#    736,
#    741,
#    749,
#    753,
#    754,
#    758,
#    760,
#    764,
#    766,
#    771,
#    772,
#    777,
#    779,
#    787,
#    790,
#    790,
#    803,
#    809,
#    810,
#    810,
#    811,
#    816,
#    817,
#    818,
#    820,
#    830,
#    831,
#    833,
#    834,
#    838,
#    839,
#    846,
#    852,
#    853,
#    854,
#    856,
#    858,
#    859,
#    863,
#    865,
#    867,
#    875,
#    880,
#    883,
#    884,
#    888,
#    897,
#    898,
#    909,
#    910,
#    912,
#    914,
#    916,
#    917,
#    918,
#    932,
#    933,
#    934,
#    940,
#    943,
#    949,
#    965,
#    966,
#    968,
#    970,
#    972,
#    973,
#    974,
#    982,
#    984,
#    987,
#    994,
#    995,
#    997,
#    1000,
#    1002,
#    1006,
#    1007,
#    1012,
#    1027,
#    1029,
#    1055,
#    1056,
#    1074]),
#  ('16h', 1, [604]),
#  ('win', 5, [77, 175, 267, 272, 688]),
#  ('🚄', 1, [382]),
#  ('hts18', 1, [898]),
#  ('nation', 3, [54, 64, 480]),
#  ('httpstcosnrtupk8po', 1, [118]),
#  ('currenc', 2, [294, 468]),
#  ('engrxiv', 1, [608]),
#  ('erf2018', 1, [102]),
#  ('glückwunsch', 1, [954]),
#  ('fintech', 3, [19, 127, 538]),
#  ('qu', 1, [610]),
#  ('httpstcovuof6zibbm', 1, [473]),
#  ('7', 6, [167, 252, 390, 519, 631, 979]),
#  ('backdoor', 1, [314]),
#  ('que', 8, [342, 383, 439, 659, 659, 860, 1024, 1069]),
#  ('therapist', 1, [1029]),
#  ('submit', 2, [393, 642]),
#  ('spi', 3, [216, 254, 634]),
#  ('httpstcokkhkdgvbb1', 1, [567]),
#  ('court', 2, [475, 475]),
#  ('physilog®', 1, [786]),
#  ('natxopago', 1, [335]),
#  ('billard', 1, [118]),
#  ('slashandburn', 1, [808]),
#  ('robot',
#   50,
#   [9,
#    14,
#    17,
#    31,
#    86,
#    102,
#    102,
#    104,
#    169,
#    169,
#    208,
#    246,
#    249,
#    254,
#    292,
#    353,
#    379,
#    379,
#    407,
#    407,
#    407,
#    414,
#    414,
#    414,
#    414,
#    425,
#    440,
#    450,
#    585,
#    585,
#    599,
#    647,
#    651,
#    660,
#    703,
#    719,
#    774,
#    835,
#    835,
#    871,
#    897,
#    905,
#    924,
#    926,
#    942,
#    972,
#    1008,
#    1029,
#    1033,
#    1038]),
#  ('wissenschaftw', 1, [743]),
#  ('lot', 3, [903, 909, 933]),
#  ('httpstcoa1y1stv0lb', 1, [169]),
#  ('comechatwithm', 1, [765]),
#  ('face', 2, [112, 322]),
#  ('givaudan', 1, [522]),
#  ('pedagog', 1, [219]),
#  ('princeton', 1, [676]),
#  ('0203', 1, [569]),
#  ('sait', 2, [51, 860]),
#  ('httpstcocvhref9yhb', 1, [252]),
#  ('zhaw', 2, [16, 200]),
#  ('httpstcolakv7l5brm', 1, [290]),
#  ('bellon', 1, [419]),
#  ('car', 3, [292, 372, 815]),
#  ('cancertreat', 1, [529]),
#  ('scumbag', 1, [641]),
#  ('gtgt', 1, [1063]),
#  ('poursuit', 1, [568]),
#  ('httpstconr6udhtjm', 1, [211]),
#  ('rivoalti', 1, [70]),
#  ('httpstcoh8cjpqe2', 1, [744]),
#  ('bon', 3, [168, 325, 682]),
#  ('petit', 1, [467]),
#  ('httpstcowwogoegeac', 1, [780]),
#  ('pic', 2, [375, 1005]),
#  ('opticalsocieti', 1, [966]),
#  ('httpstcofs7tdpbfsp', 1, [636]),
#  ('yunchul', 1, [210]),
#  ('ins2017', 1, [114]),
#  ('httpstco5psizmobkn', 1, [321]),
#  ('particip', 11, [57, 301, 325, 339, 345, 390, 471, 572, 601, 724, 1007]),
#  ('gafa', 1, [921]),
#  ('httpstcos3gmguc9sf', 1, [997]),
#  ('difficult', 1, [115]),
#  ('f', 1, [107]),
#  ('use',
#   16,
#   [74,
#    116,
#    229,
#    303,
#    343,
#    395,
#    430,
#    466,
#    498,
#    661,
#    679,
#    685,
#    712,
#    907,
#    966,
#    1000]),
#  ('befor', 5, [90, 275, 504, 727, 751]),
#  ('chute', 1, [1050]),
#  ('seul', 1, [1022]),
#  ('thibgsana', 1, [591]),
#  ('œuvr', 1, [456]),
#  ('butterfli', 1, [112]),
#  ('httpstco4vuyimvgj', 1, [82]),
#  ('5g', 2, [212, 636]),
#  ('aug', 1, [422]),
#  ('httpstcoqid3m3t4fq', 1, [1037]),
#  ('besoin', 3, [118, 283, 1030]),
#  ('httpstco3rjiief5ag', 1, [995]),
#  ('framework', 2, [469, 519]),
#  ('hybridesdenken', 1, [105]),
#  ('astronaut', 2, [138, 493]),
#  ('httpstcon2fe3bxfzh', 1, [13]),
#  ('microcityn', 1, [402]),
#  ('httpstcoscnzxhptgu', 1, [303]),
#  ('hbpeduc', 1, [709]),
#  ('22march', 1, [898]),
#  ('kinemat', 1, [786]),
#  ('remind', 1, [735]),
#  ('extrêmement', 1, [742]),
#  ('durabili', 1, [961]),
#  ('she', 1, [270]),
#  ('silentparti', 2, [168, 197]),
#  ('voyagebachelor', 1, [369]),
#  ('revolution', 3, [69, 136, 856]),
#  ('teilen', 1, [49]),
#  ('httpstcogbdmfiztsk', 1, [53]),
#  ('uniofoxford', 1, [22]),
#  ('prendra', 1, [860]),
#  ('nutrit', 2, [606, 850]),
#  ('nanonmatériaux', 1, [978]),
#  ('httpstcokmuznuomey', 1, [501]),
#  ('apprendr', 5, [118, 311, 827, 827, 1026]),
#  ('httpstcot606fvecbz', 1, [963]),
#  ('digitaltrust', 3, [10, 182, 384]),
#  ('tetsurokitahara', 1, [418]),
#  ('assembl', 1, [378]),
#  ('httpstcojtheq7sb9d', 1, [491]),
#  ('opendatach', 3, [587, 621, 656]),
#  ('nanoparticl', 1, [577]),
#  ('httpstcomass98crri', 2, [328, 527]),
#  ('httpstcog09yb45hzq', 1, [254]),
#  ('0206', 1, [453]),
#  ('map', 1, [206]),
#  ('exhibit', 2, [93, 914]),
#  ('educ', 7, [143, 177, 310, 310, 614, 639, 652]),
#  ('pasc17', 1, [89]),
#  ('christianeuhau', 1, [552]),
#  ('uniqu', 3, [801, 883, 884]),
#  ('18', 4, [144, 223, 704, 963]),
#  ('worldwid', 1, [631]),
#  ('fourthrevolut', 1, [22]),
#  ('it4lif', 1, [521]),
#  ('fakenew', 1, [27]),
#  ('joshconstin', 1, [247]),
#  ('rehabilit', 3, [440, 693, 852]),
#  ('irrespect', 1, [1044]),
#  ('comfort', 2, [613, 867]),
#  ('swisseconom', 1, [1041]),
#  ('😉', 5, [209, 325, 735, 802, 1049]),
#  ('plane', 2, [108, 108]),
#  ('uni', 1, [1014]),
#  ('metastast', 1, [32]),
#  ('dévoil', 1, [651]),
#  ('httpstcomvsvcwdtxb', 1, [768]),
#  ('interpret', 1, [236]),
#  ('httpstcoybkxlwpuow', 1, [348]),
#  ('terrywinn', 1, [419]),
#  ('httpstcox8uurri5oy', 1, [27]),
#  ('httpstco1ismya7e0p', 1, [291]),
#  ('françai', 3, [244, 744, 939]),
#  ('may', 4, [263, 728, 732, 972]),
#  ('joystick', 1, [102]),
#  ('rampd', 1, [71]),
#  ('virtuel', 1, [386]),
#  ('httpstcovdczjrh87j', 1, [772]),
#  ('enough', 1, [965]),
#  ('recogn', 1, [547]),
#  ('union', 2, [294, 468]),
#  ('gelähmten', 1, [701]),
#  ('jure', 1, [557]),
#  ('httpstcodgxoj2dafk', 1, [219]),
#  ('ast', 1, [741]),
#  ('cement', 2, [133, 748]),
#  ('grand', 4, [602, 752, 823, 913]),
#  ('httpstcoqziorlabwr', 1, [421]),
#  ('httpstcol4gcxplvsi', 1, [688]),
#  ('robust', 1, [103]),
#  ('amparistech', 1, [654]),
#  ('close', 2, [32, 352]),
#  ('httpstcoz5czqofiyv', 1, [879]),
#  ('curti', 1, [148]),
#  ('changer', 1, [644]),
#  ('subject', 1, [4]),
#  ('lifeinnyon', 1, [192]),
#  ('tel', 1, [658]),
#  ('respons', 4, [13, 65, 314, 862]),
#  ('24heuresch', 5, [123, 282, 383, 1040, 1042]),
#  ('pleurobot', 1, [95]),
#  ('httpstcozyenraseir', 1, [5]),
#  ('grid', 1, [275]),
#  ('medic', 2, [514, 695]),
#  ('mental', 1, [627]),
#  ('energypoli', 1, [847]),
#  ('etr', 1, [26]),
#  ('httpstcogts6lu5tnr', 1, [989]),
#  ('evangelist', 1, [747]),
#  ('soir', 3, [710, 1016, 1052]),
#  ('multijunct', 2, [398, 681]),
#  ('socialmedia', 1, [27]),
#  ('liaison', 1, [821]),
#  ('bereich', 1, [822]),
#  ('httpstcopqqkry5ny9', 1, [69]),
#  ('michigan', 2, [294, 468]),
#  ('korrelieren', 1, [638]),
#  ('httpstcoclpyvpputz', 1, [854]),
#  ('brainstorm', 1, [658]),
#  ('mention', 2, [643, 869]),
#  ('cheat', 1, [240]),
#  ('concept', 3, [136, 275, 1061]),
#  ('httpstcoju8ess8cuj', 1, [798]),
#  ('hydro', 1, [400]),
#  ('marchand', 1, [1068]),
#  ('autour', 1, [584]),
#  ('httpstcobdowqoqx', 1, [308]),
#  ('httpstco6uzlxnhwvr', 1, [434]),
#  ('ebugnion', 2, [10, 25]),
#  ('sefaward', 1, [721]),
#  ('didn', 1, [692]),
#  ('cesmichigan', 2, [294, 468]),
#  ('privat', 2, [499, 957]),
#  ('seen', 2, [691, 751]),
#  ('traversé', 1, [11]),
#  ('uzhscienc', 1, [489]),
#  ('connect', 1, [62]),
#  ('httpstconzhkfztpx', 1, [207]),
#  ('perditab', 1, [661]),
#  ('httpstcox7ibz3xuhm', 1, [1065]),
#  ('tetranucleosom', 1, [66]),
#  ('httpstcoicjzbgikkg', 1, [331]),
#  ('photovolta', 2, [757, 1004]),
#  ('often', 1, [134]),
#  ('bringt', 1, [105]),
#  ('thesi', 6, [401, 469, 502, 743, 808, 867]),
#  ('httpstco2vqqgqhact', 1, [11]),
#  ('magistral', 1, [257]),
#  ('httpstcocmiyfgtdn0', 1, [435]),
#  ('reduc', 2, [718, 907]),
#  ('flaviacorda', 1, [530]),
#  ('raconté', 1, [1022]),
#  ('httpstcooswxdojogr', 1, [362]),
#  ('symbionthost', 1, [55]),
#  ('30th', 1, [762]),
#  ('steigert', 1, [425]),
#  ('matter', 6, [110, 111, 280, 355, 704, 811]),
#  ('physicaltherapi', 1, [444]),
#  ('eröffnungsred', 1, [1015]),
#  ('httpstcomxk2y5brhf', 1, [339]),
#  ('tile', 1, [770]),
#  ('thymioii', 5, [20, 554, 554, 652, 735]),
#  ('maiti', 1, [748]),
#  ('carbon', 2, [575, 918]),
#  ('travail', 4, [11, 63, 93, 996]),
#  ('embiontech', 1, [1027]),
#  ('suivi', 1, [265]),
#  ('parrot', 1, [318]),
#  ('heterogen', 2, [734, 766]),
#  ('compos', 2, [452, 942]),
#  ('jeffrey', 1, [260]),
#  ('jurist', 2, [199, 993]),
#  ('jusquau', 1, [844]),
#  ('protéin', 2, [405, 424]),
#  ('httpstcoynay98tg4b', 1, [622]),
#  ('method', 6, [166, 332, 377, 551, 638, 786]),
#  ('sestrin1', 1, [35]),
#  ('françou', 1, [535]),
#  ('limb', 1, [970]),
#  ('gewch2017', 2, [72, 623]),
#  ('partir', 1, [840]),
#  ('valeur', 2, [325, 844]),
#  ('1st', 7, [114, 126, 269, 316, 984, 1003, 1064]),
#  ('journal', 2, [552, 1003]),
#  ('la',
#   102,
#   [11,
#    11,
#    11,
#    12,
#    12,
#    16,
#    20,
#    26,
#    26,
#    26,
#    26,
#    26,
#    47,
#    51,
#    56,
#    61,
#    61,
#    81,
#    94,
#    118,
#    149,
#    149,
#    149,
#    157,
#    168,
#    182,
#    183,
#    197,
#    199,
#    202,
#    244,
#    252,
#    287,
#    300,
#    304,
#    304,
#    322,
#    325,
#    342,
#    345,
#    357,
#    362,
#    382,
#    383,
#    386,
#    386,
#    392,
#    404,
#    404,
#    452,
#    463,
#    526,
#    565,
#    566,
#    568,
#    584,
#    592,
#    603,
#    604,
#    610,
#    636,
#    644,
#    659,
#    706,
#    723,
#    766,
#    783,
#    784,
#    788,
#    788,
#    800,
#    806,
#    842,
#    844,
#    860,
#    874,
#    894,
#    895,
#    901,
#    902,
#    913,
#    919,
#    923,
#    929,
#    958,
#    958,
#    961,
#    976,
#    977,
#    978,
#    988,
#    996,
#    1016,
#    1016,
#    1018,
#    1022,
#    1030,
#    1030,
#    1042,
#    1054,
#    1066,
#    1066]),
#  ('ensmmofficiel', 1, [304]),
#  ('restart', 1, [1034]),
#  ('227', 1, [628]),
#  ('httpstcoyjkjnlqnyw', 1, [87]),
#  ('april', 4, [30, 479, 642, 990]),
#  ('leman', 1, [672]),
#  ('synthesi', 2, [334, 807]),
#  ('cio', 2, [1037, 1042]),
#  ('lemantourism', 1, [192]),
#  ('flourish', 1, [432]),
#  ('erfahrung', 1, [309]),
#  ('httpstcoxgw221z7zq', 1, [677]),
#  ('didnt', 2, [409, 938]),
#  ('einfach', 1, [890]),
#  ('intent', 1, [277]),
#  ('reef', 1, [814]),
#  ('embojourn', 1, [694]),
#  ('risqu', 2, [185, 1048]),
#  ('gluon', 1, [34]),
#  ('brain',
#   15,
#   [6, 28, 84, 449, 497, 524, 534, 616, 713, 741, 741, 755, 755, 818, 904]),
#  ('5gppp', 1, [549]),
#  ('madonna', 2, [240, 582]),
#  ('httpstcomtl9l8rnev', 1, [280]),
#  ('fujilove30', 1, [455]),
#  ('euh2020', 1, [931]),
#  ('wave', 5, [44, 328, 527, 534, 908]),
#  ('soin', 1, [386]),
#  ('balanc', 1, [581]),
#  ('inscrit', 1, [161]),
#  ('entrepreun', 1, [910]),
#  ('esmtelecom', 1, [559]),
#  ('httpstcobpnpc47k3l', 1, [746]),
#  ('socibiz', 1, [791]),
#  ('bbcradio4', 1, [22]),
#  ('170', 1, [697]),
#  ('gordon', 1, [88]),
#  ('setzt', 2, [49, 721]),
#  ('top', 10, [93, 98, 187, 220, 536, 560, 631, 767, 934, 995]),
#  ('must', 1, [292]),
#  ('httpstcoxcrufbsg5a', 1, [524]),
#  ('treatment', 2, [166, 547]),
#  ('elektrotechnik', 1, [309]),
#  ('httpstconok4aklk3a', 1, [557]),
#  ('convers', 3, [681, 863, 911]),
#  ('unplug', 1, [333]),
#  ('wellunderstood', 1, [809]),
#  ('brevet', 1, [923]),
#  ('pratiqu', 4, [61, 252, 265, 342]),
#  ('vie', 2, [266, 705]),
#  ('everyon', 2, [59, 589]),
#  ('httpstcohblrytdmtt', 1, [6]),
#  ('sofc', 1, [1013]),
#  ('life', 4, [30, 201, 593, 849]),
#  ('interdisciplinair', 1, [183]),
#  ('considér', 1, [62]),
#  ('weekend', 6, [168, 307, 337, 342, 626, 899]),
#  ('conseil', 1, [857]),
#  ('httpstcotjqhmyuz6i', 1, [244]),
#  ('maxplanckpress', 1, [303]),
#  ('edxonlin', 2, [164, 493]),
#  ('🇨🇭merci', 1, [26]),
#  ('httpstcome5kez2lh2', 1, [542]),
#  ('broadspectrum', 1, [577]),
#  ('aussi', 3, [51, 610, 925]),
#  ('httpstcoxfn5abbrit', 1, [138]),
#  ('valai', 5, [43, 130, 676, 742, 743]),
#  ('mobilis', 1, [541]),
#  ('novel', 6, [159, 469, 469, 668, 708, 864]),
#  ('plongé', 1, [456]),
#  ('1980', 1, [1069]),
#  ('countdown', 1, [868]),
#  ('cancervaccin', 1, [529]),
#  ('2018',
#   30,
#   [27,
#    28,
#    30,
#    32,
#    46,
#    137,
#    144,
#    168,
#    197,
#    202,
#    250,
#    263,
#    277,
#    350,
#    390,
#    393,
#    464,
#    465,
#    466,
#    512,
#    560,
#    586,
#    642,
#    688,
#    709,
#    719,
#    719,
#    801,
#    898,
#    1007]),
#  ('acetyl', 1, [622]),
#  ('httpstcoxwoypkslri', 1, [221]),
#  ('gdanezi', 1, [68]),
#  ('scnatch', 1, [201]),
#  ('informatik', 1, [309]),
#  ('httpstcoiwtbu2mfyr', 1, [554]),
#  ('tesla', 1, [209]),
#  ('c', 7, [175, 294, 294, 468, 468, 627, 627]),
#  ('move', 1, [556]),
#  ('constraint', 1, [260]),
#  ('wcsj2017', 1, [594]),
#  ('co', 1, [188]),
#  ('httpstcobzdpdlwf40', 1, [675]),
#  ('selfsuffici', 2, [83, 155]),
#  ('20', 3, [175, 734, 1054]),
#  ('siggraph', 1, [615]),
#  ('test', 3, [80, 354, 564]),
#  ('httpstcorpg0ytemsu', 1, [176]),
#  ('epfldur', 1, [82]),
#  ('joe', 1, [620]),
#  ('httpstcog0hzwjpurg', 1, [465]),
#  ('colab', 1, [176]),
#  ('httpstcozie2dckwsg', 1, [1055]),
#  ('japan', 3, [144, 342, 715]),
#  ('pvalu', 1, [329]),
#  ('timko', 1, [210]),
#  ('magnet', 1, [558]),
#  ('storag', 3, [117, 558, 575]),
#  ('magistretti', 1, [741]),
#  ('httpstcojokzxoverh', 1, [929]),
#  ('cors', 1, [906]),
#  ('httpstco5tmqyjekih', 1, [110]),
#  ('alumnu', 1, [741]),
#  ('fmondada', 4, [20, 343, 382, 735]),
#  ('httpstcodenokqywrc', 1, [404]),
#  ('débrouillé', 1, [548]),
#  ('streamlin', 1, [98]),
#  ('side', 1, [620]),
#  ('current', 5, [242, 307, 731, 903, 903]),
#  ('jorgensundberg', 1, [232]),
#  ('httpstcoriozv4axxn', 1, [131]),
#  ('hey', 2, [358, 369]),
#  ('ête', 1, [197]),
#  ('ressourc', 2, [539, 939]),
#  ('pan', 1, [172]),
#  ('prenant', 1, [794]),
#  ('vleadersfintech', 1, [148]),
#  ('market', 5, [397, 448, 628, 726, 870]),
#  ('xma', 1, [263]),
#  ('httpstcojz7tpghojn', 1, [771]),
#  ('wed', 1, [301]),
#  ('lieu', 4, [243, 252, 902, 958]),
#  ('classifi', 1, [734]),
#  ('httpstco6utnj68psc', 1, [5]),
#  ('📆', 1, [102]),
#  ('venu', 2, [601, 626]),
#  ('bbca', 1, [1070]),
#  ('srf', 1, [576]),
#  ('ouvert', 1, [801]),
#  ('httpstcoxvevamgjgi', 1, [299]),
#  ('healthyag', 1, [588]),
#  ('antiag', 1, [156]),
#  ('work',
#   32,
#   [14,
#    76,
#    86,
#    88,
#    151,
#    262,
#    296,
#    301,
#    323,
#    352,
#    414,
#    428,
#    500,
#    507,
#    526,
#    591,
#    655,
#    667,
#    667,
#    717,
#    761,
#    791,
#    855,
#    856,
#    864,
#    897,
#    931,
#    935,
#    938,
#    960,
#    1046,
#    1065]),
#  ('httpstcolliavntc9r', 1, [831]),
#  ('httpstcoeek6g1vnm5', 1, [970]),
#  ('nanopattern', 1, [949]),
#  ('abbschweizag', 1, [425]),
#  ('québec', 1, [1030]),
#  ('httpstcoysim9d7hdi', 1, [384]),
#  ('sae', 1, [574]),
#  ('httpstcold04jbxpsw', 1, [978]),
#  ('sixleg', 1, [379]),
#  ('raclett', 1, [587]),
#  ('tank', 1, [63]),
#  ('il', 8, [12, 325, 659, 682, 939, 1049, 1049, 1071]),
#  ('hr', 1, [301]),
#  ('brillant', 1, [246]),
#  ('seront', 1, [554]),
#  ('walk', 9, [74, 169, 373, 537, 647, 693, 835, 852, 1029]),
#  ('serious', 2, [519, 573]),
#  ('mendeleïev', 1, [311]),
#  ('frederickaplan', 5, [183, 501, 592, 925, 958]),
#  ('1ère', 1, [56]),
#  ('séduisent', 1, [388]),
#  ('42born2cod', 1, [561]),
#  ('zizi', 1, [988]),
#  ('httpstcofc9t0gbuhx', 1, [689]),
#  ('httpstcoveig9f8bpl', 1, [35]),
#  ('httpstco39urk8zhu9', 1, [905]),
#  ('excit',
#   21,
#   [4,
#    60,
#    106,
#    343,
#    358,
#    387,
#    419,
#    427,
#    445,
#    464,
#    474,
#    515,
#    563,
#    576,
#    608,
#    629,
#    951,
#    984,
#    999,
#    1046,
#    1065]),
#  ('fiveminut', 1, [564]),
#  ('fabriqu', 1, [877]),
#  ('plasmon', 1, [113]),
#  ('eaten', 1, [1033]),
#  ('flowersinria', 1, [735]),
#  ('vegan', 1, [253]),
#  ('httpstcofiymwvlnar', 1, [512]),
#  ('enquêt', 1, [821]),
#  ('digitalshap', 1, [295]),
#  ('httpstco06jmxdae2h', 1, [59]),
#  ('incontro', 1, [851]),
#  ('planvélo', 1, [687]),
#  ('chem', 1, [807]),
#  ('cryogen', 1, [916]),
#  ('lor', 3, [543, 569, 874]),
#  ('httpstcod7ylxqyt2a', 1, [549]),
#  ('httpstcookq8sxesiv', 1, [642]),
#  ('danser', 2, [168, 197]),
#  ('rtscqfd', 2, [172, 172]),
#  ('helmholtzmuc', 1, [745]),
#  ('practic', 4, [318, 539, 937, 960]),
#  ('territori', 1, [261]),
#  ('httpstcod8i7iov05c', 1, [652]),
#  ('httpstcoluq7bwf0mh', 1, [386]),
#  ('doe', 3, [260, 613, 736]),
#  ('near', 1, [957]),
#  ('moschaer', 1, [474]),
#  ('knecht', 2, [137, 506]),
#  ('boschglob', 1, [522]),
#  ('addit', 3, [327, 883, 884]),
#  ('millan', 1, [459]),
#  ('solar',
#   24,
#   [29,
#    40,
#    83,
#    152,
#    296,
#    299,
#    317,
#    364,
#    396,
#    398,
#    406,
#    419,
#    473,
#    517,
#    595,
#    681,
#    684,
#    705,
#    771,
#    853,
#    913,
#    968,
#    1002,
#    1004]),
#  ('microscopi', 4, [265, 286, 332, 680]),
#  ('accesspoint', 1, [321]),
#  ('pfurrer', 1, [346]),
#  ('million', 6, [23, 43, 53, 499, 546, 614]),
#  ('emad', 1, [193]),
#  ('rather', 1, [580]),
#  ('driverless', 1, [1044]),
#  ('moëll', 1, [1030]),
#  ('while', 2, [938, 960]),
#  ('httpstcoycdl2qklni', 1, [643]),
#  ('serment', 2, [862, 862]),
#  ('glare', 1, [770]),
#  ('opensci', 6, [78, 125, 238, 329, 466, 799]),
#  ('inaugur', 3, [106, 273, 826]),
#  ('bepo', 1, [1070]),
#  ('learn',
#   27,
#   [33,
#    60,
#    176,
#    194,
#    208,
#    229,
#    231,
#    337,
#    347,
#    347,
#    390,
#    390,
#    411,
#    426,
#    464,
#    587,
#    600,
#    613,
#    623,
#    747,
#    859,
#    872,
#    888,
#    899,
#    974,
#    1009,
#    1048]),
#  ('seulement', 1, [265]),
#  ('vrtmedialab', 1, [428]),
#  ('weed', 1, [31]),
#  ('advantag', 1, [341]),
#  ('recrut', 1, [592]),
#  ('articles…', 1, [103]),
#  ('bauingenieurwissenschaften', 1, [309]),
#  ('httpstcof6us6yutfq', 1, [448]),
#  ('special', 1, [259]),
#  ('cdfdanslapress', 1, [282]),
#  ('httpstcousyuegvzb9', 1, [410]),
#  ('lematindimanch', 1, [1038]),
#  ('soiré', 1, [1016]),
#  ('—', 1, [260]),
#  ('httpstcoa6lliu7txb', 1, [1055]),
#  ('war', 1, [890]),
#  ('davantag', 1, [244]),
#  ('upmc', 1, [311]),
#  ('httpstcoli5nturtjh', 1, [596]),
#  ('zuerich', 1, [1011]),
#  ('scrutini', 1, [564]),
#  ('passion', 1, [143]),
#  ('httpstcobxrhpamqlx', 1, [367]),
#  ('httpstcoxuzpa1rzzt', 1, [591]),
#  ('ecargobik', 1, [430]),
#  ('lematinch', 1, [901]),
#  ('archaïqu', 1, [843]),
#  ('httpstcofmf9ged4km', 1, [901]),
#  ('factori', 3, [141, 534, 619]),
#  ('18h30', 1, [782]),
#  ('webot', 1, [74]),
#  ('lhiver', 1, [877]),
#  ('5060', 1, [1068]),
#  ('hk–chic', 1, [90]),
#  ('run', 3, [166, 490, 539]),
#  ('fast', 3, [233, 495, 941]),
#  ('garcia', 1, [490]),
#  ('httpstcor14llnhb2w', 1, [252]),
#  ('and',
#   215,
#   [0,
#    10,
#    10,
#    13,
#    27,
#    27,
#    28,
#    34,
#    42,
#    44,
#    59,
#    64,
#    65,
#    65,
#    66,
#    68,
#    68,
#    68,
#    68,
#    78,
#    80,
#    86,
#    101,
#    103,
#    103,
#    108,
#    108,
#    108,
#    109,
#    112,
#    116,
#    121,
#    121,
#    124,
#    125,
#    126,
#    126,
#    138,
#    139,
#    142,
#    150,
#    164,
#    166,
#    166,
#    170,
#    171,
#    175,
#    176,
#    185,
#    190,
#    191,
#    193,
#    195,
#    210,
#    210,
#    217,
#    220,
#    229,
#    250,
#    250,
#    258,
#    259,
#    262,
#    263,
#    263,
#    264,
#    269,
#    272,
#    284,
#    290,
#    290,
#    291,
#    292,
#    292,
#    294,
#    296,
#    299,
#    301,
#    307,
#    308,
#    313,
#    315,
#    321,
#    328,
#    334,
#    336,
#    337,
#    339,
#    339,
#    341,
#    341,
#    348,
#    352,
#    352,
#    376,
#    376,
#    390,
#    390,
#    401,
#    409,
#    416,
#    419,
#    419,
#    427,
#    440,
#    442,
#    449,
#    458,
#    458,
#    464,
#    468,
#    469,
#    485,
#    498,
#    501,
#    507,
#    513,
#    515,
#    518,
#    518,
#    525,
#    526,
#    526,
#    527,
#    531,
#    545,
#    547,
#    557,
#    561,
#    561,
#    575,
#    575,
#    577,
#    585,
#    589,
#    598,
#    606,
#    613,
#    623,
#    625,
#    626,
#    628,
#    639,
#    639,
#    641,
#    641,
#    642,
#    650,
#    658,
#    660,
#    662,
#    663,
#    666,
#    671,
#    671,
#    671,
#    675,
#    678,
#    679,
#    686,
#    688,
#    689,
#    690,
#    694,
#    699,
#    699,
#    703,
#    719,
#    724,
#    733,
#    734,
#    741,
#    743,
#    743,
#    745,
#    745,
#    756,
#    777,
#    785,
#    798,
#    807,
#    813,
#    820,
#    820,
#    830,
#    830,
#    845,
#    847,
#    850,
#    858,
#    859,
#    866,
#    869,
#    873,
#    898,
#    905,
#    908,
#    928,
#    933,
#    938,
#    941,
#    959,
#    960,
#    973,
#    981,
#    982,
#    995,
#    1014,
#    1036,
#    1036,
#    1036,
#    1046,
#    1060,
#    1065,
#    1072]),
#  ('rang', 1, [499]),
#  ('larchitectur', 2, [462, 1068]),
#  ('diminué', 1, [266]),
#  ('sensor', 3, [151, 642, 786]),
#  ('professionnel', 2, [244, 261]),
#  ('femal', 1, [709]),
#  ('6pm', 1, [320]),
#  ('materi', 6, [34, 132, 176, 545, 663, 669]),
#  ('chercheur', 1, [383]),
#  ('maltraité', 1, [840]),
#  ('httpstco8hh2xacpdn', 1, [139]),
#  ('void', 1, [410]),
#  ('thankyou', 1, [413]),
#  ('northwesterneng', 1, [805]),
#  ('stéphane', 1, [962]),
#  ('isabel', 1, [801]),
#  ('httpstcoyyoucaecgq', 1, [503]),
#  ('premièr', 2, [842, 958]),
#  ('kakkoii', 1, [715]),
#  ('xaviercoad', 1, [472]),
#  ('dachat', 1, [325]),
#  ('wikipedia', 4, [134, 469, 935, 935]),
#  ('cant', 1, [359]),
#  ('certificat', 1, [742]),
#  ('polair', 1, [636]),
#  ('said', 1, [938]),
#  ('andrisilbi', 1, [954]),
#  ('fate', 1, [607]),
#  ('solarpow', 1, [870]),
#  ('fwd', 1, [951]),
#  ('eawag', 2, [167, 252]),
#  ('borgesjorgel', 1, [846]),
#  ('attain', 1, [580]),
#  ('httpstcok7ndmjyqbi', 1, [233]),
#  ('exosom', 1, [529]),
#  ('tweet', 1, [160]),
#  ('enthusiast', 1, [138]),
#  ('big', 4, [315, 442, 625, 731]),
#  ('15h15', 1, [569]),
#  ('prospérité', 1, [26]),
#  ('tsinghuauni', 1, [106]),
#  ('solvingproblem', 1, [714]),
#  ('camera', 1, [514]),
#  ('httpstco9fgitpnf', 1, [572]),
#  ('mbryzek', 1, [427]),
#  ('httpstcooueqdvczdd', 1, [878]),
#  ('cour', 11, [20, 157, 161, 252, 252, 304, 627, 742, 752, 827, 1001]),
#  ('diaspora', 1, [746]),
#  ('dtsbourg', 2, [65, 312]),
#  ('httpstcoxtxseusdj9', 1, [310]),
#  ('haben', 2, [443, 451]),
#  ('keep', 3, [14, 91, 1013]),
#  ('done', 5, [591, 691, 761, 948, 1006]),
#  ('them', 11, [109, 259, 458, 577, 641, 679, 679, 691, 778, 899, 938]),
#  ('overhead', 1, [909]),
#  ('time',
#   20,
#   [2,
#    12,
#    44,
#    68,
#    125,
#    164,
#    323,
#    326,
#    361,
#    397,
#    448,
#    497,
#    586,
#    719,
#    720,
#    830,
#    858,
#    888,
#    958,
#    1056]),
#  ('httpstcoaodxrekih3', 1, [243]),
#  ('7047', 1, [161]),
#  ('httpstcov8xuiirj87', 1, [703]),
#  ('nextgen', 1, [558]),
#  ('körper', 1, [638]),
#  ('held', 1, [126]),
#  ('guid', 6, [20, 259, 435, 539, 739, 993]),
#  ('neighborhood', 1, [513]),
#  ('24', 2, [265, 990]),
#  ('httpstco81jojeidzx', 1, [299]),
#  ('hit', 2, [411, 808]),
#  ('chemic', 1, [743]),
#  ('httpstcowzdrbf6q3m', 1, [876]),
#  ('jeuness', 1, [893]),
#  ('martin', 3, [568, 643, 863]),
#  ('edinburghuni', 1, [777]),
#  ('fairi', 1, [491]),
#  ('knowledgecomscor', 1, [262]),
#  ('réservez', 1, [1048]),
#  ('progenitor', 1, [734]),
#  ('sich', 4, [49, 583, 721, 954]),
#  ('tune', 5, [78, 125, 374, 432, 813]),
#  ('honneur', 1, [843]),
#  ('station', 2, [671, 1063]),
#  ('clinic', 1, [352]),
#  ('just', 11, [59, 85, 144, 409, 714, 869, 941, 951, 957, 1007, 1014]),
#  ('fabric', 2, [327, 1000]),
#  ('ration', 1, [739]),
#  ('moniqu', 1, [1021]),
#  ('fds2017', 1, [766]),
#  ('you',
#   58,
#   [50,
#    50,
#    68,
#    80,
#    215,
#    236,
#    245,
#    260,
#    260,
#    262,
#    263,
#    278,
#    307,
#    307,
#    315,
#    337,
#    340,
#    341,
#    367,
#    393,
#    397,
#    397,
#    411,
#    422,
#    445,
#    448,
#    448,
#    482,
#    509,
#    531,
#    537,
#    540,
#    540,
#    559,
#    620,
#    621,
#    635,
#    635,
#    640,
#    654,
#    655,
#    671,
#    691,
#    691,
#    692,
#    791,
#    791,
#    791,
#    791,
#    810,
#    820,
#    938,
#    940,
#    963,
#    973,
#    987,
#    1033,
#    1074]),
#  ('httpstcodoe5shp9xr', 1, [477]),
#  ('break', 3, [726, 820, 951]),
#  ('cosplay', 1, [715]),
#  ('engin', 12, [17, 69, 352, 485, 560, 647, 743, 975, 995, 1014, 1034, 1055]),
#  ('dieser', 1, [105]),
#  ('smile', 1, [894]),
#  ('hpk42', 1, [68]),
#  ('compétitivité', 1, [26]),
#  ('encourag', 3, [233, 910, 987]),
#  ('brantut', 1, [431]),
#  ('power', 6, [396, 400, 486, 736, 736, 928]),
#  ('✌🏽🌱', 1, [253]),
#  ('delay', 1, [108]),
#  ('epflfood', 1, [253]),
#  ('httpstcopiz1hi72jt', 1, [623]),
#  ('cortex', 1, [290]),
#  ('ferdinand', 1, [927]),
#  ('warm', 2, [245, 1013]),
#  ('mattia', 1, [154]),
#  ('httpstcow4ax9gcawo', 1, [440]),
#  ('httpstcokmp1urxpuo', 1, [156]),
#  ('veuillez', 1, [988]),
#  ('scienc',
#   34,
#   [4,
#    30,
#    49,
#    109,
#    131,
#    183,
#    201,
#    210,
#    250,
#    300,
#    301,
#    358,
#    393,
#    420,
#    420,
#    426,
#    443,
#    524,
#    544,
#    593,
#    600,
#    616,
#    688,
#    710,
#    713,
#    730,
#    743,
#    764,
#    778,
#    810,
#    904,
#    969,
#    1054,
#    1056]),
#  ('httpstcoacnn5znc95', 1, [801]),
#  ('pride', 1, [264]),
#  ('httpstcos1t6jccyoj', 1, [398]),
#  ('theworldin', 1, [231]),
#  ('unterworfen', 1, [638]),
#  ('examen', 2, [161, 495]),
#  ('iciq', 1, [237]),
#  ('swissskil', 1, [346]),
#  ('reatch', 1, [572]),
#  ('commeric', 1, [628]),
#  ('notr', 7, [63, 243, 362, 565, 710, 821, 927]),
#  ('swisslitho', 1, [949]),
#  ('entier', 1, [644]),
#  ('courtin', 1, [114]),
#  ('delà', 1, [1043]),
#  ('datteindr', 1, [996]),
#  ('mal', 2, [96, 789]),
#  ('paralysi', 1, [114]),
#  ('httpstcotdwglg6tpw', 1, [721]),
#  ('httpstcomfrjlnuopt', 1, [662]),
#  ('such', 4, [60, 390, 641, 768]),
#  ('michaelgonin', 1, [338]),
#  ('solair', 4, [51, 268, 913, 1023]),
#  ('httpstcojyucag59jq', 1, [277]),
#  ('pavilion', 1, [770]),
#  ('hand', 5, [76, 76, 596, 725, 941]),
#  ('aesthet', 1, [156]),
#  ('httpstcoz9peeqtzc', 1, [788]),
#  ('eng', 1, [319]),
#  ('way', 8, [108, 203, 450, 533, 542, 589, 662, 835]),
#  ('venture2017', 2, [445, 974]),
#  ('mécaniqu', 2, [627, 710]),
#  ('jordimontserrat', 2, [120, 953]),
#  ('perspect', 2, [562, 831]),
#  ('iitalk', 1, [878]),
#  ('somat', 1, [734]),
#  ('dernièr', 1, [12]),
#  ('packag', 1, [624]),
#  ('qualiti', 5, [86, 103, 259, 428, 466]),
#  ('compon', 2, [256, 389]),
#  ('branch', 1, [189]),
#  ('directli', 2, [30, 44]),
#  ('smartspecialis', 1, [704]),
#  ('explain', 3, [275, 481, 699]),
#  ('businessinsider…', 1, [897]),
#  ('airbnb', 6, [324, 507, 507, 692, 692, 832]),
#  ('recommand', 1, [603]),
#  ('reconnu', 1, [665]),
#  ('httpstcody437yk4su', 1, [364]),
#  ('deliv', 2, [124, 223]),
#  ('polici', 5, [71, 126, 236, 262, 541]),
#  ('perrin', 1, [919]),
#  ('httpstcoqygdqtlvgt', 1, [159]),
#  ('techeu', 1, [140]),
#  ('francosuiss', 1, [304]),
#  ('hrff', 1, [107]),
#  ('nanotechnolog', 1, [196]),
#  ('forschung', 1, [822]),
#  ('élément', 1, [311]),
#  ('ubisim', 1, [386]),
#  ('httpstco6rcktsojc7', 1, [610]),
#  ...]
